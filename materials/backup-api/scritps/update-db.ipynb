# %%
from pins import board_connect
import pandas as pd

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
board = board_connect(server_url='https://colorado.posit.co/rsc/')
df = board.pin_read("sam.edwardes/chicago-business-license-data-validated")
df
# Out:
#                        id license_id account_number site_number  \
# 0        1000000-20020221    1000000         200001           1
# 1        1000049-20010816    1162772         200068           1
# 2        1000049-20020516    1233615          10141           2
# 3        1000049-20020816    1265665         200068           1
# 4        1000049-20030516    1342680          10141           2
# ...                   ...        ...            ...         ...
# 1021679     9999-20140916    2343163          26256           1
# 1021680     9999-20160916    2478055          26256           1
# 1021681     9999-20180916    2610578          26256           1
# 1021682     9999-20200916    2739432          26256           1
# 1021683     9999-20220916    2858021          26256           1
#
#                              legal_name          doing_business_as_name  \
# 0                           MARK BOSTON                COLORS IN MOTION
# ...

# %%
df["license_description"].value_counts().head(40)
# Out:
# Limited Business License                         415006
# Retail Food Establishment                        168114
# Tobacco                                           51802
# Regulated Business License                        44747
# Consumption on Premises - Incidental Activity     36362
# Home Occupation                                   27099
# Tavern                                            18563
# Package Goods                                     17186
# Home Repair                                       16895
# Manufacturing Establishments                      13923
# Special Event Food                                12736
# Motor Vehicle Services License                    10916
# Hazardous Materials                               10877
# Motor Vehicle Repair : Engine Only (Class II)     10036
# Wholesale Food Establishment                       9825
# Public Place of Amusement                          8469
# Commercial Garage                                  8188
# ...

# %%
df["business_activity"].value_counts().head(20)
# Out:
# Retail Sales of Perishable Foods                                             137561
# Retail Sale of Tobacco                                                        44470
# Consumption of Liquor on Premises                                             35681
# Tavern - Consumption of Liquor on Premise                                     18283
# Retail Sales of Packaged Liquor                                               15720
# Preparation of Food and Dining on Premise With Seating                        10046
# Other Home Based Businesses                                                    9012
# Wholesale Food Sales                                                           8969
# Special Event Food                                                             8832
# Hair Services                                                                  8045
# Not-For-Profit Selling Raffles for Prizes of $50 or More                       7759
# ...

# %%
from ipywidgets import HTML

from ipyleaflet import Map, Marker, Popup

center = (52.204793, 360.121558)

m = Map(center=center, zoom=9, close_popup_on_click=False)

marker = Marker(location=(52.1, 359.9))
m.add_layer(marker)

message1 = HTML()
message2 = HTML()
message1.value = "Try clicking the marker!"
message2.value = "Hello <b>World</b>"
message2.placeholder = "Some HTML"
message2.description = "Some HTML"

# Popup with a given location on the map:
popup = Popup(
    location=center,
    child=message1,
    close_button=False,
    auto_close=False,
    close_on_escape_key=False
)
m.add_layer(popup)

# Popup associated to a layer
marker.popup = message2

m
# Out:
# Map(center=[52.204793, 360.121558], close_popup_on_click=False, controls=(ZoomControl(options=['position', 'zo…
