# %% [markdown]
# # Raw Data Ingestion
#
# This workshop will use data from the City of Chicago Open Data Portal: <https://data.cityofchicago.org>. The following datasets will be used:
#
# 1. Business license data: <https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr>
# 2. Food inspections: <https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5>

# %% [markdown]
# ## Setup

# %%
import os
import requests
import re
from urllib.parse import urlencode

import pandas as pd
from sqlalchemy import create_engine, text

# %%
# Jupyter / Pandas settings
pd.options.display.max_columns = 999

# %%
# Set up postgresql connection
db_user = "posit"
db_password = os.environ["CONF23_DB_PASSWORD"]
db_host = os.environ["CONF23_DB_HOST"]
db_port = 5432
db_database = "conf23_python"
engine = create_engine(f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_database}")
engine
# Out:
# Engine(postgresql+psycopg2://posit:***@database.conf23workflows.training.posit.co/conf23_python)

# %% [markdown]
# Set dyanmic variables. To ensure that we do not have overload the database or the server, only the instructors scripts will run on the full data set.

# %%
connect_username = requests.get(
    f"{os.environ['CONNECT_SERVER']}/__api__/v1/user",
    headers={"Authorization": f"Key {os.environ['CONNECT_API_KEY']}"}
).json()["username"]

connect_username
# Out:
# 'sam.edwardes'

# %%
if connect_username == "sam.edwardes":
    max_rows = 99_999_999
else:
    max_rows = 10_000

max_rows
# Out:
# 99999999

# %% [markdown]
# ## Data set (1): Food inspections
#
# <https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5>

# %% [markdown]
# **Step 1:** Gew the raw data from the data portal

# %%
base_url = "https://data.cityofchicago.org/resource/4ijn-s7e5.csv"
params = {"$order": "inspection_date", "$limit": max_rows}
url = f"{base_url}?{urlencode(params)}"
url
# Out:
# 'https://data.cityofchicago.org/resource/4ijn-s7e5.csv?%24order=inspection_date&%24limit=99999999'

# %%
# Read everything as a string so that the formatting is preserved. We will use 
# pandera later to convert everything to the correct type.
food_inspection_data = pd.read_csv(url, dtype=str)
food_inspection_data
# Out:
#        inspection_id                       dba_name  \
# 0              52234                       Cafe 608
# 1              70269                    mr.daniel's
# 2              67733                      WOLCOTT'S
# 3              67732                      WOLCOTT'S
# 4             104236                     TEMPO CAFE
# ...              ...                            ...
# 258048       2579943                   EGGSPERIENCE
# 258049       2579952        MAXWELL STREET HARRISON
# 258050       2579939               LA FIESTA BAKERY
# 258051       2579946               GROTA RESTAURANT
# 258052       2579951  TEPALCATES RESTAURANT COMPANY
#
#                          aka_name license_ facility_type             risk  \
# 0                        Cafe 608  2013328    Restaurant    Risk 1 (High)
# 1                     mr.daniel's  1899292    Restaurant    Risk 1 (High)
# 2                         TROQUET  1992040    Restaurant    Risk 1 (High)
# 3                         TROQUET  1992039    Restaurant    Risk 1 (High)
# 4                      TEMPO CAFE    80916    Restaurant    Risk 1 (High)
# ...                           ...      ...           ...              ...
# 258048               EGGSPERIENCE  2583306    Restaurant    Risk 1 (High)
# 258049    ORIGINAL MAXWELL STREET  2247280    Restaurant  Risk 2 (Medium)
# 258050  LA FIESTA BAKERY/TAQUERIA  1488177    Restaurant    Risk 1 (High)
# 258051           GROTA RESTAURANT     6753    Restaurant    Risk 1 (High)
# 258052                 TEPALCATES  2924439    Restaurant    Risk 1 (High)
#
#                          address     city state    zip  \
# 0               608 W BARRY AVE   CHICAGO    IL  60657
# 1            5645 W BELMONT AVE   CHICAGO    IL  60634
# 2           1834 W MONTROSE AVE   CHICAGO    IL  60613
# 3           1834 W MONTROSE AVE   CHICAGO    IL  60613
# 4               6 E CHESTNUT ST   CHICAGO    IL  60611
# ...                          ...      ...   ...    ...
# 258048     3231-3233 N BROADWAY   CHICAGO    IL  60657
# 258049       3801 W HARRISON ST   CHICAGO    IL  60624
# 258050        6424 S PULASKI RD   CHICAGO    IL  60629
# 258051  3108-3112 N CENTRAL AVE   CHICAGO    IL  60634
# 258052       2326 W BELMONT AVE   CHICAGO    IL  60618
#
#                 inspection_date          inspection_type             results  \
# 0       2010-01-04T00:00:00.000    License Re-Inspection                Pass
# 1       2010-01-04T00:00:00.000    License Re-Inspection                Pass
# 2       2010-01-04T00:00:00.000    License Re-Inspection                Pass
# 3       2010-01-04T00:00:00.000    License Re-Inspection                Pass
# 4       2010-01-04T00:00:00.000                  Canvass                Fail
# ...                         ...                      ...                 ...
# 258048  2023-08-11T00:00:00.000    Canvass Re-Inspection                Pass
# 258049  2023-08-11T00:00:00.000  Complaint Re-Inspection                Pass
# 258050  2023-08-11T00:00:00.000                  Canvass                Pass
# 258051  2023-08-11T00:00:00.000    Canvass Re-Inspection                Pass
# 258052  2023-08-11T00:00:00.000                  License  Pass w/ Conditions
#
#                                                violations            latitude  \
# 0                                                     NaN  41.938006880423615
# 1                                                     NaN   41.93844282365204
# 2                                                     NaN  41.961605669949854
# 3                                                     NaN  41.961605669949854
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...   41.89843137207629
# ...                                                   ...                 ...
# 258048  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.941021951821966
# 258049  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...   41.87340464534467
# 258050  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...   41.77607320206961
# 258051                                                NaN   41.93706710815131
# 258052  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.939581685727795
#
#                  longitude                                  location
# 0        -87.6447545707008   (41.938006880423615, -87.6447545707008)
# 1       -87.76831838068422   (41.93844282365204, -87.76831838068422)
# 2       -87.67596676683779  (41.961605669949854, -87.67596676683779)
# 3       -87.67596676683779  (41.961605669949854, -87.67596676683779)
# 4        -87.6280091630558    (41.89843137207629, -87.6280091630558)
# ...                    ...                                       ...
# 258048  -87.64428253705525  (41.941021951821966, -87.64428253705525)
# 258049  -87.72039962829741   (41.87340464534467, -87.72039962829741)
# 258050  -87.72284124538348   (41.77607320206961, -87.72284124538348)
# 258051  -87.76659233846347   (41.93706710815131, -87.76659233846347)
# 258052  -87.68666227599451  (41.939581685727795, -87.68666227599451)
#
# [258053 rows x 17 columns]

# %% [markdown]
# **Step 2:** Save to data to Postgres

# %% [markdown]
# Determine a prefix for the table name so that we do not overwrite eachothers data.

# %%
# determine the table name
if connect_username == "sam.edwardes":
    table_name_prefix = ""
else:
    table_name_prefix = re.sub('[^0-9a-zA-Z]+', '_', connect_username) + "_"

# %%
table_name = f"{table_name_prefix}food_inspection_raw"
table_name
# Out:
# 'food_inspection_raw'

# %%
# Insert the data into postgres. Inserting large amounts of data can be slow, so
# iterate over 10,000 rows at a time.

n_rows = food_inspection_data.shape[0]
step_size = 10_000

for i in range(0, n_rows, step_size):
    index_start = i
    index_end = min(n_rows, i + step_size - 1)
    
    if i == 0:
        if_exists = "replace"
    else:
        if_exists = "append"

    print(f"Inserting rows: {index_start:,} - {index_end:,}")

    food_inspection_data \
        .loc[index_start:index_end, :] \
        .to_sql(table_name, engine, if_exists=if_exists, index=False)
# Out:
# Inserting rows: 0 - 9,999
# Inserting rows: 10,000 - 19,999
# Inserting rows: 20,000 - 29,999
# Inserting rows: 30,000 - 39,999
# Inserting rows: 40,000 - 49,999
# Inserting rows: 50,000 - 59,999
# Inserting rows: 60,000 - 69,999
# Inserting rows: 70,000 - 79,999
# Inserting rows: 80,000 - 89,999
# Inserting rows: 90,000 - 99,999
# Inserting rows: 100,000 - 109,999
# Inserting rows: 110,000 - 119,999
# Inserting rows: 120,000 - 129,999
# Inserting rows: 130,000 - 139,999
# Inserting rows: 140,000 - 149,999
# Inserting rows: 150,000 - 159,999
# Inserting rows: 160,000 - 169,999
# Inserting rows: 170,000 - 179,999
# Inserting rows: 180,000 - 189,999
# Inserting rows: 190,000 - 199,999
# Inserting rows: 200,000 - 209,999
# Inserting rows: 210,000 - 219,999
# Inserting rows: 220,000 - 229,999
# Inserting rows: 230,000 - 239,999
# Inserting rows: 240,000 - 249,999
# Inserting rows: 250,000 - 258,053

# %%
# Confirm number of rows
with engine.begin() as conn:
    query = text(f"SELECT COUNT(*) FROM {table_name}")
    data_from_sql = pd.read_sql_query(query, conn)

print(data_from_sql)
# Out:
#     count
# 0  258053

# %% [markdown]
# ## Data set (2): Business License Data
#
# <https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr>

# %% [markdown]
# **Step 1:** Gew the raw data from the data portal

# %%
base_url = "https://data.cityofchicago.org/resource/r5kz-chrr.csv"
params = {"$order": "id", "$limit": max_rows}
url = f"{base_url}?{urlencode(params)}"
url
# Out:
# 'https://data.cityofchicago.org/resource/r5kz-chrr.csv?%24order=id&%24limit=99999999'

# %%
# Read everything as a string so that the formatting is preserved. We will use 
# pandera later to convert everything to the correct type.
business_license_data = pd.read_csv(url, dtype=str)
business_license_data
# Out:
#                        id license_id account_number site_number  \
# 0        1000000-20020221    1000000         200001           1
# 1        1000049-20010816    1162772         200068           1
# 2        1000049-20020516    1233615          10141           2
# 3        1000049-20020816    1265665         200068           1
# 4        1000049-20030516    1342680          10141           2
# ...                   ...        ...            ...         ...
# 1108776     9999-20140916    2343163          26256           1
# 1108777     9999-20160916    2478055          26256           1
# 1108778     9999-20180916    2610578          26256           1
# 1108779     9999-20200916    2739432          26256           1
# 1108780     9999-20220916    2858021          26256           1
#
#                              legal_name          doing_business_as_name  \
# 0                           MARK BOSTON                COLORS IN MOTION
# 1                     ANTONIA CASTREJON           ILLUSIONS HAIR DESIGN
# 2             PEPE"S RETAIL MEATS, INC.              PEREZ MEXICAN FOOD
# 3                     ANTONIA CASTREJON           ILLUSIONS HAIR DESIGN
# 4             PEPE"S RETAIL MEATS, INC.              PEREZ MEXICAN FOOD
# ...                                 ...                             ...
# 1108776  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1108777  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1108778  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1108779  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1108780  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
#
#                            address     city state zip_code ward precinct  \
# 0                 6421 N DAMEN AVE  CHICAGO    IL    60645   50       28
# 1              3800 W DIVERSEY AVE  CHICAGO    IL    60647   31      999
# 2        853-855 W RANDOLPH ST 1ST  CHICAGO    IL    60607   27        1
# 3              3800 W DIVERSEY AVE  CHICAGO    IL    60647   31      999
# 4        853-855 W RANDOLPH ST 1ST  CHICAGO    IL    60607   27        1
# ...                            ...      ...   ...      ...  ...      ...
# 1108776       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
# 1108777       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
# 1108778       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
# 1108779       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
# 1108780       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
#
#         ward_precinct police_district license_code        license_description  \
# 0               50-28              24         1011                Home Repair
# 1              31-999              25         1010   Limited Business License
# 2                27-1              12         1006  Retail Food Establishment
# 3              31-999              25         1010   Limited Business License
# 4                27-1              12         1006  Retail Food Establishment
# ...               ...             ...          ...                        ...
# 1108776         36-17              12         1010   Limited Business License
# 1108777         36-17              12         1010   Limited Business License
# 1108778         36-17              12         1010   Limited Business License
# 1108779         36-17              12         1010   Limited Business License
# 1108780         36-17              12         1010   Limited Business License
#
#         business_activity_id                 business_activity license_number  \
# 0                        NaN                               NaN        1000000
# 1                        NaN                               NaN        1000049
# 2                        775  Retail Sales of Perishable Foods        1000049
# 3                        NaN                               NaN        1000049
# 4                        775  Retail Sales of Perishable Foods        1000049
# ...                      ...                               ...            ...
# 1108776                  NaN                               NaN           9999
# 1108777                  NaN                               NaN           9999
# 1108778                  NaN                               NaN           9999
# 1108779                  NaN                               NaN           9999
# 1108780                  NaN                               NaN           9999
#
#         application_type application_created_date  \
# 0                  ISSUE  2000-06-19T00:00:00.000
# 1                  RENEW                      NaN
# 2                  RENEW                      NaN
# 3                  RENEW                      NaN
# 4                  RENEW                      NaN
# ...                  ...                      ...
# 1108776            RENEW                      NaN
# 1108777            RENEW                      NaN
# 1108778            RENEW                      NaN
# 1108779            RENEW                      NaN
# 1108780            RENEW                      NaN
#
#         application_requirements_complete             payment_date  \
# 0                 2002-02-15T00:00:00.000  2002-02-15T00:00:00.000
# 1                 2001-06-25T00:00:00.000  2001-08-20T00:00:00.000
# 2                 2002-03-27T00:00:00.000  2002-04-17T00:00:00.000
# 3                 2002-06-28T00:00:00.000  2002-08-13T00:00:00.000
# 4                 2003-03-25T00:00:00.000  2003-04-17T00:00:00.000
# ...                                   ...                      ...
# 1108776           2014-07-15T00:00:00.000  2014-12-26T00:00:00.000
# 1108777           2016-07-15T00:00:00.000  2016-09-08T00:00:00.000
# 1108778           2018-07-15T00:00:00.000  2018-09-10T00:00:00.000
# 1108779           2020-07-15T00:00:00.000  2020-08-05T00:00:00.000
# 1108780           2022-07-15T00:00:00.000  2022-08-08T00:00:00.000
#
#         conditional_approval       license_start_date  \
# 0                          N  2002-02-21T00:00:00.000
# 1                          N  2001-08-16T00:00:00.000
# 2                          N  2002-05-16T00:00:00.000
# 3                          N  2002-08-16T00:00:00.000
# 4                          N  2003-05-16T00:00:00.000
# ...                      ...                      ...
# 1108776                    N  2014-09-16T00:00:00.000
# 1108777                    N  2016-09-16T00:00:00.000
# 1108778                    N  2018-09-16T00:00:00.000
# 1108779                    N  2020-09-16T00:00:00.000
# 1108780                    N  2022-09-16T00:00:00.000
#
#                  expiration_date license_approved_for_issuance  \
# 0        2002-11-15T00:00:00.000       2002-02-21T00:00:00.000
# 1        2002-08-15T00:00:00.000       2001-08-20T00:00:00.000
# 2        2003-05-15T00:00:00.000       2002-04-17T00:00:00.000
# 3        2003-08-15T00:00:00.000       2002-08-13T00:00:00.000
# 4        2004-05-15T00:00:00.000       2003-04-17T00:00:00.000
# ...                          ...                           ...
# 1108776  2016-09-15T00:00:00.000       2014-12-26T00:00:00.000
# 1108777  2018-09-15T00:00:00.000       2016-09-08T00:00:00.000
# 1108778  2020-09-15T00:00:00.000       2018-09-10T00:00:00.000
# 1108779  2022-09-15T00:00:00.000       2020-08-05T00:00:00.000
# 1108780  2024-09-15T00:00:00.000       2022-08-08T00:00:00.000
#
#                      date_issued license_status license_status_change_date  \
# 0        2002-02-22T00:00:00.000            AAI                        NaN
# 1        2002-04-30T00:00:00.000            AAI                        NaN
# 2        2002-04-18T00:00:00.000            AAI                        NaN
# 3        2002-08-14T00:00:00.000            AAI                        NaN
# 4        2003-04-18T00:00:00.000            AAI                        NaN
# ...                          ...            ...                        ...
# 1108776  2014-12-29T00:00:00.000            AAI                        NaN
# 1108777  2016-09-09T00:00:00.000            AAI                        NaN
# 1108778  2018-09-11T00:00:00.000            AAI                        NaN
# 1108779  2020-08-06T00:00:00.000            AAI                        NaN
# 1108780  2022-09-13T00:00:00.000            AAI                        NaN
#
#          ssa      latitude      longitude  \
# 0        NaN  41.998514371  -87.680010905
# 1        NaN  41.931960333  -87.722150366
# 2        NaN  41.884261422  -87.649534131
# 3        NaN  41.931960333  -87.722150366
# 4        NaN  41.884261422  -87.649534131
# ...      ...           ...            ...
# 1108776  NaN  41.892720807  -87.692331754
# 1108777  NaN  41.892720807  -87.692331754
# 1108778  NaN  41.892720807  -87.692331754
# 1108779  NaN  41.892720807  -87.692331754
# 1108780  NaN  41.892720807  -87.692331754
#
#                                                 location
# 0         \n,  \n(41.99851437112669, -87.68001090539342)
# 1        \n,  \n(41.931960332638006, -87.72215036594574)
# 2          \n,  \n(41.88426142200001, -87.6495341312589)
# 3        \n,  \n(41.931960332638006, -87.72215036594574)
# 4          \n,  \n(41.88426142200001, -87.6495341312589)
# ...                                                  ...
# 1108776   \n,  \n(41.89272080716665, -87.69233175444906)
# 1108777   \n,  \n(41.89272080716665, -87.69233175444906)
# 1108778   \n,  \n(41.89272080716665, -87.69233175444906)
# 1108779   \n,  \n(41.89272080716665, -87.69233175444906)
# 1108780   \n,  \n(41.89272080716665, -87.69233175444906)
#
# [1108781 rows x 34 columns]

# %%
# To speed things up, we will only keep the license data for establishments
# that have food inspection data.
business_license_data = pd.merge(
    business_license_data,
    food_inspection_data[["license_"]].drop_duplicates(),
    how="inner",
    left_on="license_id",
    right_on="license_"
).drop(
    columns="license_"
)

business_license_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34928 entries, 0 to 34927
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 34928 non-null  object
#  1   license_id                         34928 non-null  object
#  2   account_number                     34928 non-null  object
#  3   site_number                        34928 non-null  object
#  4   legal_name                         34928 non-null  object
#  5   doing_business_as_name             34928 non-null  object
#  6   address                            34928 non-null  object
#  7   city                               34928 non-null  object
#  8   state                              34928 non-null  object
#  9   zip_code                           34898 non-null  object
#  10  ward                               34791 non-null  object
#  11  precinct                           30594 non-null  object
#  12  ward_precinct                      34791 non-null  object
#  13  police_district                    30907 non-null  object
#  14  license_code                       34928 non-null  object
#  15  license_description                34928 non-null  object
#  16  business_activity_id               33277 non-null  object
#  17  business_activity                  33277 non-null  object
#  18  license_number                     34928 non-null  object
#  19  application_type                   34928 non-null  object
#  20  application_created_date           32277 non-null  object
#  21  application_requirements_complete  34120 non-null  object
#  22  payment_date                       33974 non-null  object
#  23  conditional_approval               34928 non-null  object
#  24  license_start_date                 34795 non-null  object
#  25  expiration_date                    34911 non-null  object
#  26  license_approved_for_issuance      33832 non-null  object
#  27  date_issued                        34928 non-null  object
#  28  license_status                     34928 non-null  object
#  29  license_status_change_date         2248 non-null   object
#  30  ssa                                11068 non-null  object
#  31  latitude                           34654 non-null  object
#  32  longitude                          34654 non-null  object
#  33  location                           34654 non-null  object
# dtypes: object(34)
# memory usage: 9.3+ MB

# %% [markdown]
# **Step 2:** Save data to Postgres

# %%
table_name = f"{table_name_prefix}business_license_raw"
table_name
# Out:
# 'business_license_raw'

# %%
# Insert the data into postgres. Inserting large amounts of data can be slow, so
# iterate over 10,000 rows at a time.

# TODO: dynamically insert user name into table if not PROD

n_rows = business_license_data.shape[0]
step_size = 10_000

for i in range(0, n_rows, step_size):
    index_start = i
    index_end = min(n_rows, i + step_size - 1)
    
    if i == 0:
        if_exists = "replace"
    else:
        if_exists = "append"

    print(f"Inserting rows: {index_start:,} - {index_end:,}")
    
    business_license_data \
        .loc[index_start:index_end, :] \
        .to_sql(table_name, engine, if_exists=if_exists, index=False)
# Out:
# Inserting rows: 0 - 9,999
# Inserting rows: 10,000 - 19,999
# Inserting rows: 20,000 - 29,999
# Inserting rows: 30,000 - 34,928

# %%
# Confirm number of rows
with engine.begin() as conn:
    query = text(f"SELECT COUNT(*) FROM {table_name}")
    data_from_sql = pd.read_sql_query(query, conn)

print(data_from_sql)
# Out:
#    count
# 0  34928
