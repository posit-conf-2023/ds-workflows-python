# %%
# import required libraries
import os
from datetime import datetime, timedelta

import ibis
import numpy as np
import pandas as pd
import pins
import requests
import rsconnect
import vetiver
import xgboost as xgb
from dotenv import load_dotenv
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine

# %%
# setup local environment
load_dotenv()
# Out:
# False

# %%
connect_username = requests.get(
    f"{os.environ['CONNECT_SERVER']}/__api__/v1/user",
    headers={"Authorization": f"Key {os.environ['CONNECT_API_KEY']}"}
).json()["username"]

connect_username
# Out:
# 'sam.edwardes'

# %%
# read inspection data from the database
con = ibis.postgres.connect(
    user="posit",
    password=os.environ["CONF23_DB_PASSWORD"],
    host=os.environ["CONF23_DB_HOST"],
    port=5432,
    database="conf23_python",
)

inspection_data = con.table("food_inspection_validated").to_pandas()

# %%
inspection_data
# Out:
#        inspection_id                       dba_name  \
# 0              52234                       CAFE 608
# 1              70269                    MR.DANIEL'S
# 2              67733                      WOLCOTT'S
# 3              67732                      WOLCOTT'S
# 4             104236                     TEMPO CAFE
# ...              ...                            ...
# 257513       2579937                    LA BAGUETTE
# 257514       2579958     SOUTH SHORE FOOD MART INC.
# 257515       2579939               LA FIESTA BAKERY
# 257516       2579946               GROTA RESTAURANT
# 257517       2579951  TEPALCATES RESTAURANT COMPANY
#
#                           aka_name license_  facility_type           risk  \
# 0                         CAFE 608  2013328     RESTAURANT  RISK 1 (HIGH)
# 1                      MR.DANIEL'S  1899292     RESTAURANT  RISK 1 (HIGH)
# 2                          TROQUET  1992040     RESTAURANT  RISK 1 (HIGH)
# 3                          TROQUET  1992039     RESTAURANT  RISK 1 (HIGH)
# 4                       TEMPO CAFE    80916     RESTAURANT  RISK 1 (HIGH)
# ...                            ...      ...            ...            ...
# 257513  ALEX CAFE/TORTA FUTBOLERAS  2008113     RESTAURANT  RISK 1 (HIGH)
# 257514       SOUTH SHORE FOOD MART  2340833  GROCERY STORE  RISK 1 (HIGH)
# 257515   LA FIESTA BAKERY/TAQUERIA  1488177     RESTAURANT  RISK 1 (HIGH)
# 257516            GROTA RESTAURANT     6753     RESTAURANT  RISK 1 (HIGH)
# 257517                  TEPALCATES  2924439     RESTAURANT  RISK 1 (HIGH)
#
#           zip inspection_date        inspection_type             results  \
# 0       60657      2010-01-04  LICENSE RE-INSPECTION                PASS
# 1       60634      2010-01-04  LICENSE RE-INSPECTION                PASS
# 2       60613      2010-01-04  LICENSE RE-INSPECTION                PASS
# 3       60613      2010-01-04  LICENSE RE-INSPECTION                PASS
# 4       60611      2010-01-04                CANVASS                FAIL
# ...       ...             ...                    ...                 ...
# 257513  60623      2023-08-11  CANVASS RE-INSPECTION                PASS
# 257514  60617      2023-08-11                CANVASS                FAIL
# 257515  60629      2023-08-11                CANVASS                PASS
# 257516  60634      2023-08-11  CANVASS RE-INSPECTION                PASS
# 257517  60618      2023-08-11                LICENSE  PASS W/ CONDITIONS
#
#                                                violations
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4       {"18. NO EVIDENCE OF RODENT OR INSECT OUTER OP...
# ...                                                   ...
# 257513  {"53. TOILET FACILITIES: PROPERLY CONSTRUCTED,...
# 257514  {"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL...
# 257515  {"37. FOOD PROPERLY LABELED; ORIGINAL CONTAINE...
# 257516                                               None
# 257517  {"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL...
#
# [257518 rows x 11 columns]

# %% [markdown]
# #### Exploratory Data Analysis

# %%
# (Uncomment to run some analysis)
#
# inspection_data.columns
# inspection_data.dtypes
# inspection_data.groupby("facility_type").count()["inspection_id"].sort_values(ascending=False)
# inspection_data.groupby("results").count()["inspection_id"]
# inspection_data['results'].unique()
# inspection_data.groupby("risk").count()["inspection_id"]
# inspection_data['violations']

# %% [markdown]
# #### Feature Engineering

# %%
inspection_data
# Out:
#        inspection_id                       dba_name  \
# 0              52234                       CAFE 608
# 1              70269                    MR.DANIEL'S
# 2              67733                      WOLCOTT'S
# 3              67732                      WOLCOTT'S
# 4             104236                     TEMPO CAFE
# ...              ...                            ...
# 257513       2579937                    LA BAGUETTE
# 257514       2579958     SOUTH SHORE FOOD MART INC.
# 257515       2579939               LA FIESTA BAKERY
# 257516       2579946               GROTA RESTAURANT
# 257517       2579951  TEPALCATES RESTAURANT COMPANY
#
#                           aka_name license_  facility_type           risk  \
# 0                         CAFE 608  2013328     RESTAURANT  RISK 1 (HIGH)
# 1                      MR.DANIEL'S  1899292     RESTAURANT  RISK 1 (HIGH)
# 2                          TROQUET  1992040     RESTAURANT  RISK 1 (HIGH)
# 3                          TROQUET  1992039     RESTAURANT  RISK 1 (HIGH)
# 4                       TEMPO CAFE    80916     RESTAURANT  RISK 1 (HIGH)
# ...                            ...      ...            ...            ...
# 257513  ALEX CAFE/TORTA FUTBOLERAS  2008113     RESTAURANT  RISK 1 (HIGH)
# 257514       SOUTH SHORE FOOD MART  2340833  GROCERY STORE  RISK 1 (HIGH)
# 257515   LA FIESTA BAKERY/TAQUERIA  1488177     RESTAURANT  RISK 1 (HIGH)
# 257516            GROTA RESTAURANT     6753     RESTAURANT  RISK 1 (HIGH)
# 257517                  TEPALCATES  2924439     RESTAURANT  RISK 1 (HIGH)
#
#           zip inspection_date        inspection_type             results  \
# 0       60657      2010-01-04  LICENSE RE-INSPECTION                PASS
# 1       60634      2010-01-04  LICENSE RE-INSPECTION                PASS
# 2       60613      2010-01-04  LICENSE RE-INSPECTION                PASS
# 3       60613      2010-01-04  LICENSE RE-INSPECTION                PASS
# 4       60611      2010-01-04                CANVASS                FAIL
# ...       ...             ...                    ...                 ...
# 257513  60623      2023-08-11  CANVASS RE-INSPECTION                PASS
# 257514  60617      2023-08-11                CANVASS                FAIL
# 257515  60629      2023-08-11                CANVASS                PASS
# 257516  60634      2023-08-11  CANVASS RE-INSPECTION                PASS
# 257517  60618      2023-08-11                LICENSE  PASS W/ CONDITIONS
#
#                                                violations
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4       {"18. NO EVIDENCE OF RODENT OR INSECT OUTER OP...
# ...                                                   ...
# 257513  {"53. TOILET FACILITIES: PROPERLY CONSTRUCTED,...
# 257514  {"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL...
# 257515  {"37. FOOD PROPERLY LABELED; ORIGINAL CONTAINE...
# 257516                                               None
# 257517  {"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL...
#
# [257518 rows x 11 columns]

# %%
# clean up input data for modelling

inspection_data_for_training = (
    inspection_data
    # remove NA licenses
    .loc[inspection_data["license_"] != 0]
    # select only Restaurant, Bakery, Grocery Store
    .loc[
        inspection_data["facility_type"].isin(["RESTAURANT", "BAKERY", "GROCERY STORE"])
    ]
    .pipe(
        lambda inspection_data: pd.get_dummies(
            inspection_data, columns=["facility_type"], prefix=[""], dtype=int
        )
    )
    .rename(
        columns={
            "_BAKERY": "BAKERY",
            "_RESTAURANT": "RESTAURANT",
            "_GROCERY STORE": "GROCERY_STORE",
        }
    )
    # filter out relavant inspection results
    .loc[inspection_data["results"].isin(["FAIL", "PASS", "PASS W/ CONDITIONS"])]
    # make Pass with Conditions results as Fail, since they are not completely pass
    .assign(results=(lambda x: x["results"].replace(["PASS W/ CONDITIONS"], "FAIL")))
    .assign(RESULTS=(lambda x: x["results"].map({"PASS": 1, "FAIL": 0}).astype(int)))
    .drop(columns=["results"])
    # filter out valid risk entries
    .loc[
        inspection_data["risk"].isin(
            ["RISK 1 (HIGH)", "RISK 2 (MEDIUM)", "RISK 3 (LOW)"]
        )
    ]
    # create dummy variables for risk
    .pipe(
        lambda inspection_data: pd.get_dummies(
            inspection_data, columns=["risk"], prefix=[""], dtype=int
        )
    )
    .rename(
        columns={
            "_RISK 1 (HIGH)": "HIGH_RISK",
            "_RISK 2 (MEDIUM)": "MEDIUM_RISK",
            "_RISK 3 (LOW)": "LOW_RISK",
        }
    )
    # sort results by business and inspection date
    .sort_values(by=["license_", "inspection_date"])
)

# %%
# count violations for each inspection
inspection_data_for_training["count_violations"] = (
    inspection_data_for_training["violations"]
    .apply(lambda x: len(x[1:-1].split('","')) if x is not None else None)
    .fillna(0)
)
# count cumilative violations for each date for a license
inspection_data_for_training["CUM_VIOLATIONS"] = inspection_data_for_training.groupby(
    ["license_"]
)["count_violations"].cumsum()

# %%
inspection_data_for_training
# Out:
#        inspection_id                        dba_name  \
# 101           120273               QUITEFRANKLY,LTD.
# 2987           68320                     TACOS REYNA
# 5896           74431          MICHAEL'S FRESH MARKET
# 14764         335339               VRJ FOOD MART CO.
# 15834         428224  IRISH AMERICAN HERITAGE CENTER
# ...              ...                             ...
# 152795       2064867                   FALCO'S PIZZA
# 186652       2285869                   FALCO'S PIZZA
# 211803       2401917                   FALCO'S PIZZA
# 225041       2528308                   FALCO'S PIZZA
# 225061       2528447                   FALCO'S PIZZA
#
#                               aka_name license_    zip inspection_date  \
# 101                      UPS CAFETERIA        0  60607      2010-01-06
# 2987                              None        0  60617      2010-03-02
# 5896            MICHAEL'S FRESH MARKET        0  60615      2010-05-03
# 14764                VRJ FOOD MART CO.        0  60637      2010-10-13
# 15834   IRISH AMERICAN HERITAGE CENTER        0  60630      2010-10-28
# ...                                ...      ...    ...             ...
# 152795                   FALCO'S PIZZA      990  60632      2017-06-23
# 186652                   FALCO'S PIZZA      990  60632      2019-04-26
# 211803                   FALCO'S PIZZA      990  60632      2020-10-01
# 225041                   FALCO'S PIZZA      990  60632      2021-08-20
# 225061                   FALCO'S PIZZA      990  60632      2021-08-24
#
#               inspection_type  \
# 101                   CANVASS
# 2987             CONSULTATION
# 5896             CONSULTATION
# 14764                 CANVASS
# 15834             TAG REMOVAL
# ...                       ...
# 152795  CANVASS RE-INSPECTION
# 186652                CANVASS
# 211803              COMPLAINT
# 225041                CANVASS
# 225061  CANVASS RE-INSPECTION
#
#                                                violations  BAKERY  \
# 101     {"33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTEN...       0
# 2987                                                 None       0
# 5896    {"6. HANDS WASHED AND CLEANED, GOOD HYGIENIC P...       0
# 14764   {"9. WATER SOURCE: SAFE, HOT & COLD UNDER CITY...       0
# 15834   {"32. FOOD AND NON-FOOD CONTACT SURFACES PROPE...       0
# ...                                                   ...     ...
# 152795  {"32. FOOD AND NON-FOOD CONTACT SURFACES PROPE...       0
# 186652  {"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL...       0
# 211803  {"51. PLUMBING INSTALLED; PROPER BACKFLOW DEVI...       0
# 225041  {"16. FOOD-CONTACT SURFACES: CLEANED & SANITIZ...       0
# 225061  {"36. THERMOMETERS PROVIDED & ACCURATE - COMME...       0
#
#         GROCERY_STORE  RESTAURANT  RESULTS  HIGH_RISK  MEDIUM_RISK  LOW_RISK  \
# 101                 0           1        1          1            0         0
# 2987                0           1        0          1            0         0
# 5896                1           0        0          1            0         0
# 14764               1           0        0          0            1         0
# 15834               0           1        0          1            0         0
# ...               ...         ...      ...        ...          ...       ...
# 152795              0           1        1          1            0         0
# 186652              0           1        0          1            0         0
# 211803              0           1        1          1            0         0
# 225041              0           1        0          1            0         0
# 225061              0           1        1          1            0         0
#
#         count_violations  CUM_VIOLATIONS
# 101                  4.0             4.0
# 2987                 0.0             4.0
# 5896                 8.0            12.0
# 14764               13.0            25.0
# 15834                6.0            31.0
# ...                  ...             ...
# 152795               3.0           100.0
# 186652              12.0           112.0
# 211803               3.0           115.0
# 225041               4.0           119.0
# 225061               3.0           122.0
#
# [181570 rows x 17 columns]

# %%
# Save the inspection data for training to SQL so that it can be
# used by the Shiny App.
db_user = "posit"
db_password = os.environ["CONF23_DB_PASSWORD"]
db_host = os.environ["CONF23_DB_HOST"]
db_port = 5432
db_database = "conf23_python"
engine = create_engine(f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_database}")
print(f"{engine=}")

# Determine the table name
if connect_username == "sam.edwardes":
    table_name_prefix = ""
else:
    table_name_prefix = re.sub('[^0-9a-zA-Z]+', '_', connect_username) + "_"

table_name = f"{table_name_prefix}model_features"
print(f"{table_name=}")


# Insert the data into postgres. Inserting large amounts of data can be slow, so
# iterate over 10,000 rows at a time.
n_rows = inspection_data_for_training.shape[0]
step_size = 10_000

for i in range(0, n_rows, step_size):
    index_start = i
    index_end = min(n_rows, i + step_size - 1)
    
    if i == 0:
        if_exists = "replace"
    else:
        if_exists = "append"

    print(f"Inserting rows: {index_start:,} - {index_end:,}")

    inspection_data_for_training \
        .reset_index(drop=True) \
        .loc[index_start:index_end, :] \
        .to_sql(table_name, engine, if_exists=if_exists, index=False)
# Out:
# engine=Engine(postgresql+psycopg2://posit:***@database.conf23workflows.training.posit.co/conf23_python)
# table_name='model_features'
# Inserting rows: 0 - 9,999
# Inserting rows: 10,000 - 19,999
# Inserting rows: 20,000 - 29,999
# Inserting rows: 30,000 - 39,999
# Inserting rows: 40,000 - 49,999
# Inserting rows: 50,000 - 59,999
# Inserting rows: 60,000 - 69,999
# Inserting rows: 70,000 - 79,999
# Inserting rows: 80,000 - 89,999
# Inserting rows: 90,000 - 99,999
# Inserting rows: 100,000 - 109,999
# Inserting rows: 110,000 - 119,999
# Inserting rows: 120,000 - 129,999
# Inserting rows: 130,000 - 139,999
# Inserting rows: 140,000 - 149,999
# Inserting rows: 150,000 - 159,999
# Inserting rows: 160,000 - 169,999
# Inserting rows: 170,000 - 179,999
# Inserting rows: 180,000 - 181,570

# %% [markdown]
# ##### Modelling

# %%
# Create training and test split
X = inspection_data_for_training.drop(
    columns=[
        "license_",
        "RESULTS",
        "inspection_id",
        "dba_name",
        "aka_name",
        "inspection_type",
        "violations",
        "count_violations",
        "inspection_date",
        "zip",
    ]
)
y = inspection_data_for_training[["RESULTS"]]

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Train a random forest model
clf = RandomForestClassifier(max_depth=10, random_state=0)
clf.fit(X_train, np.ravel(y_train))
# Out:
# RandomForestClassifier(max_depth=10, random_state=0)

# %%
# test predictions
y_pred = clf.predict(X_test)
mse = metrics.mean_squared_error(y_test, y_pred)

print(np.sqrt(mse))
# Out:
# 0.6365490032462582

# %% [markdown]
# ### Model deployment using Vetiver

# %%
# Create a vetiver model object
v = vetiver.VetiverModel(
    model=clf, 
    model_name=f"{connect_username}/inspection_results", 
    prototype_data=X_train[:1]
)

v

# %%
# Write the vetiver model as a pin for versioning
model_board = pins.board_connect(
    os.getenv("CONNECT_SERVER"),
    api_key=os.getenv("CONNECT_API_KEY"),
    allow_pickle_read=True
)
vetiver.vetiver_pin_write(model_board, model=v)
# Out:
# Model Cards provide a framework for transparent, responsible reporting.
#  Use the vetiver `.qmd` Quarto template as a place to start,
#  with vetiver.model_card()
# Writing pin:
# Name: 'sam.edwardes/inspection_results'
# Version: 20230815T194307Z-2a4f4

# %%
# Deploy the vetiver model as an API on Posit Connect
rsc_server = os.getenv("CONNECT_SERVER")
rsc_key = os.getenv("CONNECT_API_KEY")
connect_server = rsconnect.api.RSConnectServer(url=rsc_server, api_key=rsc_key)


vetiver.deploy_rsconnect(
    connect_server=connect_server,
    board=model_board,
    pin_name=f"{connect_username}/inspection_results",
)
# Out:
#     Warning: Capturing the environment using 'pip freeze'.
#              Consider creating a requirements.txt file instead.
# /home/sam.edwardes/ds-workflows-python/materials/solutions/03-model-training/.venv/lib/python3.11/site-packages/vetiver/write_fastapi.py:21: UserWarning: Pinned vetiver model has no active version and no datetime on versions,
#               Do you need to check your pinned model?
#               Using version 2
#   warnings.warn(
# Validating server... 	[OK]
# Validating app mode... 	[OK]
# Making bundle ... 	[OK]
# Deploying bundle ... 	[OK]
# Saving deployed information... 	[OK]
# Building FastAPI application...
# Bundle created with Python version 3.11.3 is compatible with environment Local with Python version 3.11.3 from /opt/python/3.11.3/bin/python3.11
# Bundle requested Python version 3.11.3; using /opt/python/3.11.3/bin/python3.11 which has version 3.11.3
# 2023/08/15 19:43:15.894316717 [rsc-session] Content GUID: 21431834-84e4-48d9-a850-4c6521e03ec2
# 2023/08/15 19:43:15.894362884 [rsc-session] Content ID: 12
# 2023/08/15 19:43:15.894373189 [rsc-session] Bundle ID: 18
# 2023/08/15 19:43:15.897930009 arguments: /opt/python/3.11.3/bin/python3.11 /opt/rstudio-connect/python/build_environment.py
# 2023/08/15 19:43:15.897938434
# 2023/08/15 19:43:16.179137787 Running on host: ip-10-0-15-107
# 2023/08/15 19:43:16.191814780 Linux distribution: Ubuntu 22.04.2 LTS (jammy)
# 2023/08/15 19:43:16.193576149 Running as user: uid=997(rstudio-connect) gid=998(rstudio-connect) groups=998(rstudio-connect)
# 2023/08/15 19:43:16.193604400 Connect version: 2023.07.0
# 2023/08/15 19:43:16.193631108 LANG: C.UTF-8
# 2023/08/15 19:43:16.193798108 Working directory: /opt/rstudio-connect/mnt/app
# 2023/08/15 19:43:16.193800284 Building environment using Python 3.11.3 (main, Jun  4 2023, 22:34:28) [GCC 11.3.0] at /opt/python/3.11.3/bin/python3.11
# 2023/08/15 19:43:16.195266648 Using cached environment: 2VCFTQwGXJljGdeSZu6Unw
# 2023/08/15 19:43:17.191424595 Packages in the environment: aiofiles==22.1.0, aiohttp==3.8.5, aiosignal==1.3.1, aiosqlite==0.19.0, anyio==3.7.0, appdirs==1.4.4, argcomplete==3.1.1, argon2-cffi==21.3.0, argon2-cffi-bindings==21.2.0, arrow==1.2.3, asgiref==3.7.2, asttokens==2.2.1, async-timeout==4.0.2, atpublic==4.0, attrs==23.1.0, Babel==2.12.1, backcall==0.2.0, beautifulsoup4==4.12.2, bidict==0.22.1, black==23.7.0, bleach==6.0.0, branca==0.6.0, build==0.10.0, certifi==2023.5.7, cffi==1.15.1, charset-normalizer==3.1.0, click==8.1.3, comm==0.1.3, contextvars==2.4, contourpy==1.1.0, cycler==0.11.0, debugpy==1.6.7, decorator==5.1.1, defusedxml==0.7.1, entrypoints==0.4, exceptiongroup==1.1.1, executing==1.2.0, fastapi==0.98.0, fastjsonschema==2.18.0, filelock==3.12.2, fonttools==4.42.0, fqdn==1.5.1, frozenlist==1.4.0, fsspec==2023.6.0, greenlet==2.0.2, h11==0.14.0, htmltools==0.3.0, httpcore==0.17.2, httptools==0.6.0, httpx==0.24.1, humanize==4.7.0, ibis-framework==6.0.0, idna==3.4, immutables==0.19, importlib-meta
# data==6.7.0, importlib-resources==5.12.0, ipykernel==6.23.3, ipyleaflet==0.17.3, ipython==8.14.0, ipython-genutils==0.2.0, ipywidgets==7.7.5, isoduration==20.11.0, jedi==0.18.2, Jinja2==3.1.2, joblib==1.2.0, json5==0.9.14, jsonpointer==2.4, jsonschema==4.18.6, jsonschema-specifications==2023.7.1, jupyter==1.0.0, jupyter-console==6.6.3, jupyter-events==0.7.0, jupyter-server==1.24.0, jupyter-ydoc==0.2.5, jupyter_client==8.3.0, jupyter_core==5.3.1, jupyter_server_fileid==0.9.0, jupyter_server_proxy==4.0.0, jupyter_server_ydoc==0.8.0, jupyterlab==3.6.5, jupyterlab-pygments==0.2.2, jupyterlab-widgets==1.1.5, jupyterlab_server==2.24.0, kiwisolver==1.4.4, linkify-it-py==2.0.2, markdown-it-py==3.0.0, MarkupSafe==2.1.3, matplotlib==3.7.2, matplotlib-inline==0.1.6, mdit-py-plugins==0.4.0, mdurl==0.1.2, mistune==3.0.1, multidict==6.0.4, multimethod==1.9.1, multipledispatch==1.0.0, mypy-extensions==1.0.0, nbclassic==1.0.0, nbclient==0.8.0, nbconvert==7.7.3, nbformat==5.9.2, nest-asyncio==1.5.6, notebook==6.5.5, notebook_
# shim==0.2.3, numpy==1.25.0, packaging==23.1, pandas==2.0.2, pandera==0.15.1, pandocfilters==1.5.0, parso==0.8.3, parsy==2.1, pathspec==0.11.2, pexpect==4.8.0, pickleshare==0.7.5, Pillow==10.0.0, pins==0.8.1, pip-tools==6.13.0, pipx==1.2.0, platformdirs==3.8.0, plotly==5.15.0, pooch==1.7.0, prometheus-client==0.17.1, prompt-toolkit==3.0.38, psutil==5.9.5, psycopg2==2.9.6, psycopg2-binary==2.9.6, ptyprocess==0.7.0, pure-eval==0.2.2, pyarrow==12.0.1, pycparser==2.21, pydantic==1.10.9, Pygments==2.15.1, PyJWT==2.7.0, pyparsing==3.0.9, pyproject_hooks==1.0.0, python-dateutil==2.8.2, python-dotenv==1.0.0, python-json-logger==2.0.7, python-multipart==0.0.6, pytz==2023.3, PyYAML==6.0, pyzmq==25.1.0, qtconsole==5.4.3, QtPy==2.3.1, referencing==0.30.1, requests==2.31.0, rfc3339-validator==0.1.4, rfc3986-validator==0.1.1, rich==13.4.2, rpds-py==0.9.2, rsconnect-jupyter==1.8.0, rsconnect-python==1.19.0, rsp-jupyter==1.5.0, scikit-learn==1.2.2, scipy==1.11.0, semver==2.13.0, Send2Trash==1.8.2, shiny==0.4.0, shinyswatch==0
# .2.4, shinywidgets==0.2.1, simpervisor==1.0.0, six==1.16.0, sniffio==1.3.0, soupsieve==2.4.1, SQLAlchemy==2.0.18, sqlalchemy-views==0.3.2, sqlglot==17.3.0, stack-data==0.6.2, starlette==0.27.0, tenacity==8.2.2, terminado==0.17.1, threadpoolctl==3.1.0, tinycss2==1.2.1, tokenize-rt==5.2.0, tomli==2.0.1, toolz==0.12.0, tornado==6.3.2, tqdm==4.65.0, traitlets==5.9.0, traittypes==0.2.1, typeguard==4.1.0, typing-inspect==0.9.0, typing_extensions==4.6.3, tzdata==2023.3, uc-micro-py==1.0.2, uri-template==1.3.0, urllib3==2.0.3, userpath==1.9.0, uvicorn==0.22.0, uvloop==0.17.0, vetiver==0.2.0, watchfiles==0.19.0, wcwidth==0.2.6, webcolors==1.13, webencodings==0.5.1, websocket-client==1.6.1, websockets==11.0.3, widgetsnbextension==3.6.5, workbench-jupyterlab==1.1.315, wrapt==1.15.0, xgboost==1.7.6, XStatic-bootswatch==3.3.7.0, xxhash==3.2.0, xyzservices==2023.7.0, y-py==0.6.0, yarl==1.9.2, ypy-websocket==0.8.4, zipp==3.15.0,
# 2023/08/15 19:43:17.191456506 Creating lockfile: python/requirements.txt.lock
# Completed Python build against Python version: '3.11.3'
# Launching FastAPI application...
# Deployment completed successfully.
# 	 Dashboard content URL: https://connect.conf23workflows.training.posit.co/connect/#/apps/21431834-84e4-48d9-a850-4c6521e03ec2
# 	 Direct content URL: https://connect.conf23workflows.training.posit.co/content/21431834-84e4-48d9-a850-4c6521e03ec2/

# %% [markdown]
# #### Model monitoring

# %%
# Simulate multiple days of input data
data = X_test.copy()
data["RESULTS"] = y_test
data["date_obs"] = ""
data
# Out:
#         BAKERY  GROCERY_STORE  RESTAURANT  HIGH_RISK  MEDIUM_RISK  LOW_RISK  \
# 194128       0              0           1          1            0         0
# 13480        0              0           1          1            0         0
# 212770       0              0           1          0            1         0
# 35496        0              0           1          1            0         0
# 63397        0              0           1          0            1         0
# ...        ...            ...         ...        ...          ...       ...
# 150357       0              0           1          1            0         0
# 193651       0              0           1          1            0         0
# 76412        0              0           1          1            0         0
# 88299        0              0           1          1            0         0
# 69484        1              0           0          1            0         0
#
#         CUM_VIOLATIONS  RESULTS date_obs
# 194128            73.0        1
# 13480              4.0        1
# 212770            34.0        1
# 35496             13.0        1
# 63397              0.0        0
# ...                ...      ...      ...
# 150357             7.0        1
# 193651             9.0        1
# 76412              3.0        1
# 88299             35.0        0
# 69484             11.0        1
#
# [45393 rows x 9 columns]

# %%
endpoint = "https://colorado.posit.co/rsc/inspection_results/predict"
data["preds"] = vetiver.predict(endpoint, data).iloc[:, 0].values

# %%
# add last three dates
day_list = [
    (pd.Timestamp.today() - timedelta(days=2)).strftime("%Y-%m-%d"),
    (pd.Timestamp.today() - timedelta(days=1)).strftime("%Y-%m-%d"),
    (pd.Timestamp.today().strftime("%Y-%m-%d")),
]
day_list
# Out:
# ['2023-08-13', '2023-08-14', '2023-08-15']

# %%
data["date_obs"] = np.random.choice(day_list, size=len(data))

# %%
data
# Out:
#         BAKERY  GROCERY_STORE  RESTAURANT  HIGH_RISK  MEDIUM_RISK  LOW_RISK  \
# 194128       0              0           1          1            0         0
# 13480        0              0           1          1            0         0
# 212770       0              0           1          0            1         0
# 35496        0              0           1          1            0         0
# 63397        0              0           1          0            1         0
# ...        ...            ...         ...        ...          ...       ...
# 150357       0              0           1          1            0         0
# 193651       0              0           1          1            0         0
# 76412        0              0           1          1            0         0
# 88299        0              0           1          1            0         0
# 69484        1              0           0          1            0         0
#
#         CUM_VIOLATIONS  RESULTS    date_obs  preds
# 194128            73.0        1  2023-08-15      0
# 13480              4.0        1  2023-08-14      1
# 212770            34.0        1  2023-08-13      1
# 35496             13.0        1  2023-08-15      1
# 63397              0.0        0  2023-08-15      1
# ...                ...      ...         ...    ...
# 150357             7.0        1  2023-08-14      1
# 193651             9.0        1  2023-08-14      1
# 76412              3.0        1  2023-08-15      1
# 88299             35.0        0  2023-08-15      1
# 69484             11.0        1  2023-08-14      1
#
# [45393 rows x 10 columns]

# %%
# pin this dataset for use in model card
model_board.pin_write(data, f"{connect_username}/inspection_results_monitoring",type="parquet")
# Out:
# Writing pin:
# Name: 'sam.edwardes/inspection_results_monitoring'
# Version: 20230815T194324Z-571d5
# Meta(title='inspection_results_monitoring: a pinned 45393 x 10 DataFrame', description=None, created='20230815T194324Z', pin_hash='571d5dab390ea6e4', file='inspection_results_monitoring.parquet', file_size=420705, type='parquet', api_version=1, version=VersionRaw(version='19'), tags=None, name='sam.edwardes/inspection_results_monitoring', user={}, local={})

# %%
# define which metrics to track
metric_set = [metrics.mean_absolute_error, metrics.mean_squared_error, metrics.r2_score]

# choose time period to track over
td = timedelta(days=1)

# calculate metrics
original_metrics = vetiver.compute_metrics(
    data=data,
    date_var="date_obs",
    period=td,
    metric_set=metric_set,
    truth="RESULTS",
    estimate="preds",
)

# %%
original_metrics
# Out:
#        index      n               metric  estimate
# 0 2023-08-13  15117  mean_absolute_error  0.403188
# 1 2023-08-13  15117   mean_squared_error  0.403188
# 2 2023-08-13  15117             r2_score -0.655279
# 3 2023-08-14  15096  mean_absolute_error  0.395800
# 4 2023-08-14  15096   mean_squared_error  0.395800
# 5 2023-08-14  15096             r2_score -0.636891

# %%
# Write metrics as a pin
model_board.pin_write(original_metrics, f"{connect_username}/inspection_model_metrics", type="csv")
# Out:
# Writing pin:
# Name: 'sam.edwardes/inspection_model_metrics'
# Version: 20230815T194326Z-da2fc
# Meta(title='inspection_model_metrics: a pinned 6 x 4 DataFrame', description=None, created='20230815T194326Z', pin_hash='da2fca6e7cfb802b', file='inspection_model_metrics.csv', file_size=338, type='csv', api_version=1, version=VersionRaw(version='20'), tags=None, name='sam.edwardes/inspection_model_metrics', user={}, local={})

# %%
# Model card
vetiver.model_card(path=".")
# Out:
# './model_card.qmd'
