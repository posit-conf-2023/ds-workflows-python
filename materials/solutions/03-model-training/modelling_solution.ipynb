# %%
# import required libraries
import os
from datetime import datetime, timedelta

import ibis
import numpy as np
import pandas as pd
import pins
import requests
import rsconnect
import vetiver
import xgboost as xgb
from dotenv import load_dotenv
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine
import re

# %%
# setup local environment
load_dotenv()
# Out:
# True

# %%
# get username on Connect
connect_username = requests.get(
    f"{os.environ['CONNECT_SERVER']}/__api__/v1/user",
    headers={"Authorization": f"Key {os.environ['CONNECT_API_KEY']}"}
).json()["username"]

connect_username
# Out:
# 'gagan'

# %%
# read inspection data from the database
con = ibis.postgres.connect(
    user="posit",
    password=os.environ["CONF23_DB_PASSWORD"],
    host=os.environ["CONF23_DB_HOST"],
    port=5432,
    database="conf23_python",
)

inspection_data = con.table("food_inspection_validated").to_pandas()

# %%
inspection_data
# Out:
#        inspection_id                             dba_name  \
# 0              52234                             CAFE 608
# 1             104236                           TEMPO CAFE
# 2              67757         DUNKIN DONUTS/BASKIN-ROBBINS
# 3              67732                            WOLCOTT'S
# 4              67733                            WOLCOTT'S
# ...              ...                                  ...
# 258140       2580700  HERITAGE OUTPOST LAWRENCE HOUSE LLC
# 258141       2580727                         MR CHILAQUIL
# 258142       2580738                  HANCOCK HIGH SCHOOL
# 258143       2580799                         TERRA E MARE
# 258144       2580768                   FINEST FOOD & SUBS
#
#                             aka_name license_  facility_type             risk  \
# 0                           CAFE 608  2013328     RESTAURANT    RISK 1 (HIGH)
# 1                         TEMPO CAFE    80916     RESTAURANT    RISK 1 (HIGH)
# 2       DUNKIN DONUTS/BASKIN-ROBBINS  1380279     RESTAURANT  RISK 2 (MEDIUM)
# 3                            TROQUET  1992039     RESTAURANT    RISK 1 (HIGH)
# 4                            TROQUET  1992040     RESTAURANT    RISK 1 (HIGH)
# ...                              ...      ...            ...              ...
# 258140              HERITAGE OUTPOST  2476946     RESTAURANT  RISK 2 (MEDIUM)
# 258141                  MR CHILAQUIL  2911975     RESTAURANT    RISK 1 (HIGH)
# 258142           HANCOCK HIGH SCHOOL  4025868         SCHOOL    RISK 1 (HIGH)
# 258143                  TERRA E MARE  2817542     RESTAURANT    RISK 1 (HIGH)
# 258144            FINEST FOOD & SUBS  2501127  GROCERY STORE  RISK 2 (MEDIUM)
#
#           zip inspection_date        inspection_type results  \
# 0       60657      2010-01-04  LICENSE RE-INSPECTION    PASS
# 1       60611      2010-01-04                CANVASS    FAIL
# 2       60601      2010-01-04            TAG REMOVAL    PASS
# 3       60613      2010-01-04  LICENSE RE-INSPECTION    PASS
# 4       60613      2010-01-04  LICENSE RE-INSPECTION    PASS
# ...       ...             ...                    ...     ...
# 258140  60640      2023-08-25                CANVASS    FAIL
# 258141  60632      2023-08-25  CANVASS RE-INSPECTION    PASS
# 258142  60638      2023-08-25                CANVASS    PASS
# 258143  60607      2023-08-28  LICENSE RE-INSPECTION    PASS
# 258144  60640      2023-08-28                CANVASS    PASS
#
#                                                violations
# 0                                                    None
# 1       {"18. NO EVIDENCE OF RODENT OR INSECT OUTER OP...
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 258140  {"2. CITY OF CHICAGO FOOD SERVICE SANITATION C...
# 258141  {"51. PLUMBING INSTALLED; PROPER BACKFLOW DEVI...
# 258142  {"10. ADEQUATE HANDWASHING SINKS PROPERLY SUPP...
# 258143                                               None
# 258144  {"36. THERMOMETERS PROVIDED & ACCURATE - COMME...
#
# [258145 rows x 11 columns]

# %% [markdown]
# #### Exploratory Data Analysis

# %%
# (Uncomment to run some analysis)
#
# inspection_data.columns
# inspection_data.dtypes
# inspection_data.groupby("facility_type").count()["inspection_id"].sort_values(ascending=False)
# inspection_data.groupby("results").count()["inspection_id"]
# inspection_data['results'].unique()
# inspection_data.groupby("risk").count()["inspection_id"]
# inspection_data['violations']

# %% [markdown]
# #### Feature Engineering

# %%
# clean up input data for modelling

inspection_data_for_training = (
    inspection_data
    # remove NA licenses
    .loc[inspection_data["license_"] != 0]
    # only use inspections in the last year
    .loc[inspection_data["inspection_date"]>=(inspection_data["inspection_date"].max() - timedelta(days=365))]
    # select only Restaurant, Bakery, Grocery Store
    .loc[
        inspection_data["facility_type"].isin(["RESTAURANT", "BAKERY", "GROCERY STORE"])
    ]
    .pipe(
        lambda inspection_data: pd.get_dummies(
            inspection_data, columns=["facility_type"], prefix=[""], dtype=int
        )
    )
    .rename(
        columns={
            "_BAKERY": "BAKERY",
            "_RESTAURANT": "RESTAURANT",
            "_GROCERY STORE": "GROCERY_STORE",
        }
    )
    # filter out relavant inspection results
    .loc[inspection_data["results"].isin(["FAIL", "PASS", "PASS W/ CONDITIONS"])]
    # make Pass with Conditions results as Fail, since they are not completely pass
    .assign(results=(lambda x: x["results"].replace(["PASS W/ CONDITIONS"], "FAIL")))
    .assign(RESULTS=(lambda x: x["results"].map({"PASS": 1, "FAIL": 0}).astype(int)))
    .drop(columns=["results"])
    # filter out valid risk entries
    .loc[
        inspection_data["risk"].isin(
            ["RISK 1 (HIGH)", "RISK 2 (MEDIUM)", "RISK 3 (LOW)"]
        )
    ]
    # create dummy variables for risk
    .pipe(
        lambda inspection_data: pd.get_dummies(
            inspection_data, columns=["risk"], prefix=[""], dtype=int
        )
    )
    .rename(
        columns={
            "_RISK 1 (HIGH)": "HIGH_RISK",
            "_RISK 2 (MEDIUM)": "MEDIUM_RISK",
            "_RISK 3 (LOW)": "LOW_RISK",
        }
    )
    # sort results by business and inspection date
    .sort_values(by=["license_", "inspection_date"])
)

# %%
# count violations for each inspection
inspection_data_for_training["count_violations"] = (
    inspection_data_for_training["violations"]
    .apply(lambda x: len(x[1:-1].split('","')) if x is not None else None)
    .fillna(0)
)
# count cumilative violations for each date for a license
inspection_data_for_training["CUM_VIOLATIONS"] = inspection_data_for_training.groupby(
    ["license_"]
)["count_violations"].cumsum()

# %%
inspection_data_for_training
# Out:
#        inspection_id                        dba_name  \
# 245090       2566654                 FAB'S NUTRITION
# 245410       2566988                 FAB'S NUTRITION
# 248027       2569691                        SBARRO'S
# 246429       2570167        JOE'S BARBEQ AND FISH #1
# 243480       2573601    PENNINGTON'S FOOD AND SNACKS
# ...              ...                             ...
# 240461       2575179           COLLETTI'S RESTAURANT
# 251759       2573480           FURAMA RESTAURANT INC
# 257922       2580332           FURAMA RESTAURANT INC
# 251705       2573397  L & M STARLIGHT RESTAURANT INC
# 251979       2573730  L & M STARLIGHT RESTAURANT INC
#
#                               aka_name license_    zip inspection_date  \
# 245090                 FAB'S NUTRITION        0  60639      2022-11-07
# 245410                 FAB'S NUTRITION        0  60639      2022-11-14
# 248027                        SBARRO'S        0  60612      2023-01-13
# 246429        JOE'S BARBEQ AND FISH #1        0  60644      2023-01-24
# 243480    PENNINGTON'S FOOD AND SNACKS        0  60619      2023-04-03
# ...                                ...      ...    ...             ...
# 240461           COLLETTI'S RESTAURANT     9567  60646      2023-05-01
# 251759               FURAMA RESTAURANT     9821  60640      2023-03-30
# 257922               FURAMA RESTAURANT     9821  60640      2023-08-18
# 251705  L & M STARLIGHT RESTAURANT INC     9890  60652      2023-03-29
# 251979  L & M STARLIGHT RESTAURANT INC     9890  60652      2023-04-05
#
#               inspection_type  \
# 245090                CANVASS
# 245410  CANVASS RE-INSPECTION
# 248027                CANVASS
# 246429              COMPLAINT
# 243480              COMPLAINT
# ...                       ...
# 240461  CANVASS RE-INSPECTION
# 251759                CANVASS
# 257922              COMPLAINT
# 251705                CANVASS
# 251979  CANVASS RE-INSPECTION
#
#                                                violations  BAKERY  \
# 245090  {"2. CITY OF CHICAGO FOOD SERVICE SANITATION C...       0
# 245410  {"45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROP...       0
# 248027  {"1. PERSON IN CHARGE PRESENT, DEMONSTRATES KN...       0
# 246429  {"2. CITY OF CHICAGO FOOD SERVICE SANITATION C...       0
# 243480  {"2. CITY OF CHICAGO FOOD SERVICE SANITATION C...       0
# ...                                                   ...     ...
# 240461  {"58. ALLERGEN TRAINING AS REQUIRED - COMMENTS...       0
# 251759  {"10. ADEQUATE HANDWASHING SINKS PROPERLY SUPP...       0
# 257922  {"47. FOOD & NON-FOOD CONTACT SURFACES CLEANAB...       0
# 251705  {"9. NO BARE HAND CONTACT WITH RTE FOOD OR A P...       0
# 251979  {"55. PHYSICAL FACILITIES INSTALLED, MAINTAINE...       0
#
#         GROCERY_STORE  RESTAURANT  RESULTS  HIGH_RISK  MEDIUM_RISK  LOW_RISK  \
# 245090              0           1        0          0            1         0
# 245410              0           1        1          0            1         0
# 248027              0           1        0          1            0         0
# 246429              0           1        0          1            0         0
# 243480              0           1        0          1            0         0
# ...               ...         ...      ...        ...          ...       ...
# 240461              0           1        1          1            0         0
# 251759              0           1        0          1            0         0
# 257922              0           1        1          1            0         0
# 251705              0           1        0          1            0         0
# 251979              0           1        1          1            0         0
#
#         count_violations  CUM_VIOLATIONS
# 245090               8.0             8.0
# 245410               4.0            12.0
# 248027               5.0            17.0
# 246429              19.0            36.0
# 243480              16.0            52.0
# ...                  ...             ...
# 240461               1.0             5.0
# 251759               8.0             8.0
# 257922               3.0            11.0
# 251705               5.0             5.0
# 251979               1.0             6.0
#
# [11416 rows x 17 columns]

# %%
# Save the inspection data for training to SQL so that it can be
# used by the Shiny App.
db_user = "posit"
db_password = os.environ["CONF23_DB_PASSWORD"]
db_host = os.environ["CONF23_DB_HOST"]
db_port = 5432
db_database = "conf23_python"
engine = create_engine(f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_database}")
print(f"{engine=}")

# Determine the table name
if connect_username == "sam.edwardes":
    table_name_prefix = ""
else:
    table_name_prefix = re.sub('[^0-9a-zA-Z]+', '_', connect_username) + "_"

table_name = f"{table_name_prefix}model_features"
print(f"{table_name=}")


# Insert the data into postgres. Inserting large amounts of data can be slow, so
# iterate over 10,000 rows at a time.
n_rows = inspection_data_for_training.shape[0]
step_size = 10_000

for i in range(0, n_rows, step_size):
    index_start = i
    index_end = min(n_rows, i + step_size - 1)
    
    if i == 0:
        if_exists = "replace"
    else:
        if_exists = "append"

    print(f"Inserting rows: {index_start:,} - {index_end:,}")

    inspection_data_for_training \
        .reset_index(drop=True) \
        .loc[index_start:index_end, :] \
        .to_sql(table_name, engine, if_exists=if_exists, index=False)
# Out:
# engine=Engine(postgresql+psycopg2://posit:***@database.conf23workflows.training.posit.co/conf23_python)
# table_name='gagan_model_features'
# Inserting rows: 0 - 9,999
# Inserting rows: 10,000 - 11,416

# %% [markdown]
# ##### Modelling

# %%
# Create training and test split
X = inspection_data_for_training.drop(
    columns=[
        "license_",
        "RESULTS",
        "inspection_id",
        "dba_name",
        "aka_name",
        "inspection_type",
        "violations",
        "count_violations",
        "inspection_date",
        "zip",
    ]
)
y = inspection_data_for_training[["RESULTS"]]

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Train a random forest model
clf = RandomForestClassifier(max_depth=10, random_state=0)
clf.fit(X_train, np.ravel(y_train))
# Out:
# RandomForestClassifier(max_depth=10, random_state=0)

# %%
# test predictions
y_pred = clf.predict(X_test)
mse = metrics.mean_squared_error(y_test, y_pred)

print(np.sqrt(mse))
# Out:
# 0.6256041228847741

# %% [markdown]
# ### Model deployment using Vetiver

# %%
# Create a vetiver model object
v = vetiver.VetiverModel(
    model=clf, 
    model_name=f"{connect_username}/inspection_results", 
    prototype_data=X_train[:1]
)

v

# %%
# Write the vetiver model as a pin for versioning
model_board = pins.board_connect(
    os.getenv("CONNECT_SERVER"),
    api_key=os.getenv("CONNECT_API_KEY"),
    allow_pickle_read=True
)
vetiver.vetiver_pin_write(model_board, model=v)
# Out:
# Model Cards provide a framework for transparent, responsible reporting.
#  Use the vetiver `.qmd` Quarto template as a place to start,
#  with vetiver.model_card()
# Writing pin:
# Name: 'gagan/inspection_results'
# Version: 20230907T192848Z-da4f4

# %%
# Deploy the vetiver model as an API on Posit Connect
rsc_server = os.getenv("CONNECT_SERVER")
rsc_key = os.getenv("CONNECT_API_KEY")
connect_server = rsconnect.api.RSConnectServer(url=rsc_server, api_key=rsc_key)


vetiver.deploy_rsconnect(
    connect_server=connect_server,
    board=model_board,
    pin_name=f"{connect_username}/inspection_results",
)
# Out:
#     Warning: Capturing the environment using 'pip freeze'.
#              Consider creating a requirements.txt file instead.
# /home/gagan/ds-workflows-python/materials/solutions/03-model-training/.venv/lib/python3.11/site-packages/vetiver/write_fastapi.py:21: UserWarning: Pinned vetiver model has no active version and no datetime on versions,
#               Do you need to check your pinned model?
#               Using version 178
#   warnings.warn(
# Validating server... 	[OK]
# Validating app mode... 	[OK]
# Making bundle ... 	[OK]
# Deploying bundle ... 	[OK]
# Saving deployed information... 	[OK]
# Building FastAPI application...
# Bundle created with Python version 3.11.3 is compatible with environment Local with Python version 3.11.3 from /opt/python/3.11.3/bin/python3.11
# Bundle requested Python version 3.11.3; using /opt/python/3.11.3/bin/python3.11 which has version 3.11.3
# 2023/09/07 19:29:21.251717339 [rsc-session] Content GUID: b9fe48dd-4e2d-4b92-8be7-331da686bd9e
# 2023/09/07 19:29:21.251764523 [rsc-session] Content ID: 82
# 2023/09/07 19:29:21.251773248 [rsc-session] Bundle ID: 179
# 2023/09/07 19:29:21.254711168 arguments: /opt/python/3.11.3/bin/python3.11 /opt/rstudio-connect/python/build_environment.py
# 2023/09/07 19:29:21.254722592
# 2023/09/07 19:29:21.590131710 Running on host: ip-10-0-15-107
# 2023/09/07 19:29:21.599462627 Linux distribution: Ubuntu 22.04.2 LTS (jammy)
# 2023/09/07 19:29:21.601155910 Running as user: uid=997(rstudio-connect) gid=998(rstudio-connect) groups=998(rstudio-connect)
# 2023/09/07 19:29:21.601171371 Connect version: 2023.07.0
# 2023/09/07 19:29:21.601220524 LANG: C.UTF-8
# 2023/09/07 19:29:21.601222222 Working directory: /opt/rstudio-connect/mnt/app
# 2023/09/07 19:29:21.601250365 Building environment using Python 3.11.3 (main, Jun  4 2023, 22:34:28) [GCC 11.3.0] at /opt/python/3.11.3/bin/python3.11
# 2023/09/07 19:29:21.602758460 Creating environment: hm0CzfHUuFIz1zbP3SkA1Q
# 2023/09/07 19:29:26.778516018 Requirement already satisfied: pip in ./python/env/lib/python3.11/site-packages (22.3.1)
# 2023/09/07 19:29:26.962114904 Collecting pip
# 2023/09/07 19:29:26.979909280   Using cached pip-23.2.1-py3-none-any.whl (2.1 MB)
# 2023/09/07 19:29:26.999462864 Requirement already satisfied: setuptools in ./python/env/lib/python3.11/site-packages (65.5.0)
# 2023/09/07 19:29:27.296472259 Collecting setuptools
# 2023/09/07 19:29:27.386409139   Downloading setuptools-68.2.0-py3-none-any.whl (807 kB)
# 2023/09/07 19:29:27.456199288      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.8/807.8 kB 12.1 MB/s eta 0:00:00
# 2023/09/07 19:29:27.463113172 Requirement already satisfied: wheel in /opt/python/3.11.3/lib/python3.11/site-packages (0.41.1)
# 2023/09/07 19:29:27.508695628 Collecting wheel
# 2023/09/07 19:29:27.514435145   Downloading wheel-0.41.2-py3-none-any.whl (64 kB)
# 2023/09/07 19:29:27.521287129      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 13.7 MB/s eta 0:00:00
# 2023/09/07 19:29:29.419227931 Installing collected packages: wheel, setuptools, pip
# 2023/09/07 19:29:29.419452709   Attempting uninstall: wheel
# 2023/09/07 19:29:29.489487436     Found existing installation: wheel 0.41.1
# 2023/09/07 19:29:29.489982647     Not uninstalling wheel at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:29:29.490200303     Can't uninstall 'wheel'. No files were found to uninstall.
# 2023/09/07 19:29:29.544364090   Attempting uninstall: setuptools
# 2023/09/07 19:29:29.547017244     Found existing installation: setuptools 65.5.0
# 2023/09/07 19:29:29.680470735     Uninstalling setuptools-65.5.0:
# 2023/09/07 19:29:29.692591874       Successfully uninstalled setuptools-65.5.0
# 2023/09/07 19:29:30.274938875   Attempting uninstall: pip
# 2023/09/07 19:29:30.280014495     Found existing installation: pip 22.3.1
# 2023/09/07 19:29:30.565768572     Uninstalling pip-22.3.1:
# 2023/09/07 19:29:30.573057744       Successfully uninstalled pip-22.3.1
# 2023/09/07 19:29:32.273857304 Successfully installed pip-23.2.1 setuptools-68.2.0 wheel-0.41.2
# 2023/09/07 19:29:33.319055394 Requirement already satisfied: aiohttp==3.8.5 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 1)) (3.8.5)
# 2023/09/07 19:29:33.320506019 Requirement already satisfied: aiosignal==1.3.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 2)) (1.3.1)
# 2023/09/07 19:29:33.441868884 Collecting anyio==3.7.0 (from -r python/requirements.txt (line 3))
# 2023/09/07 19:29:33.442259408   Obtaining dependency information for anyio==3.7.0 from https://files.pythonhosted.org/packages/68/fe/7ce1926952c8a403b35029e194555558514b365ad77d75125f521a2bec62/anyio-3.7.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:33.444961956   Using cached anyio-3.7.0-py3-none-any.whl.metadata (4.7 kB)
# 2023/09/07 19:29:33.448601568 Requirement already satisfied: appdirs==1.4.4 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 4)) (1.4.4)
# 2023/09/07 19:29:33.531380486 Collecting argon2-cffi==23.1.0 (from -r python/requirements.txt (line 5))
# 2023/09/07 19:29:33.531730988   Obtaining dependency information for argon2-cffi==23.1.0 from https://files.pythonhosted.org/packages/a4/6a/e8a041599e78b6b3752da48000b14c8d1e8a04ded09c88c714ba047f34f5/argon2_cffi-23.1.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:33.614692257   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# 2023/09/07 19:29:33.621902563 Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 6)) (21.2.0)
# 2023/09/07 19:29:33.623349793 Requirement already satisfied: arrow==1.2.3 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 7)) (1.2.3)
# 2023/09/07 19:29:33.624735976 Requirement already satisfied: asttokens==2.2.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 8)) (2.2.1)
# 2023/09/07 19:29:33.642299915 Collecting async-lru==2.0.4 (from -r python/requirements.txt (line 9))
# 2023/09/07 19:29:33.642658898   Obtaining dependency information for async-lru==2.0.4 from https://files.pythonhosted.org/packages/fa/9f/3c3503693386c4b0f245eaf5ca6198e3b28879ca0a40bde6b0e319793453/async_lru-2.0.4-py3-none-any.whl.metadata
# 2023/09/07 19:29:33.647212318   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# 2023/09/07 19:29:33.673721402 Collecting async-timeout==4.0.2 (from -r python/requirements.txt (line 10))
# 2023/09/07 19:29:33.676396326   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# 2023/09/07 19:29:33.698557120 Collecting atpublic==4.0 (from -r python/requirements.txt (line 11))
# 2023/09/07 19:29:33.698778975   Obtaining dependency information for atpublic==4.0 from https://files.pythonhosted.org/packages/42/d5/f3c7110d3763af646150203b8bfe6932ab05a9b3e228c27d138babeb92ae/atpublic-4.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:33.701555547   Using cached atpublic-4.0-py3-none-any.whl.metadata (1.8 kB)
# 2023/09/07 19:29:33.704491858 Requirement already satisfied: attrs==23.1.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 12)) (23.1.0)
# 2023/09/07 19:29:33.705718306 Requirement already satisfied: Babel==2.12.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 13)) (2.12.1)
# 2023/09/07 19:29:33.706756543 Requirement already satisfied: backcall==0.2.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 14)) (0.2.0)
# 2023/09/07 19:29:33.708091940 Requirement already satisfied: beautifulsoup4==4.12.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 15)) (4.12.2)
# 2023/09/07 19:29:33.709588479 Requirement already satisfied: bidict==0.22.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 16)) (0.22.1)
# 2023/09/07 19:29:33.777103028 Collecting black==23.7.0 (from -r python/requirements.txt (line 17))
# 2023/09/07 19:29:33.777417666   Obtaining dependency information for black==23.7.0 from https://files.pythonhosted.org/packages/4d/24/06c20da91df8d0b0f67e2dd3ce0feedff0b0fa6792e24e3f83452f3c38a2/black-23.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# 2023/09/07 19:29:33.780065202   Using cached black-23.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (63 kB)
# 2023/09/07 19:29:33.791176735 Requirement already satisfied: bleach==6.0.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 18)) (6.0.0)
# 2023/09/07 19:29:33.792488718 Requirement already satisfied: build==0.10.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 19)) (0.10.0)
# 2023/09/07 19:29:33.821563840 Collecting certifi==2023.5.7 (from -r python/requirements.txt (line 20))
# 2023/09/07 19:29:33.824947665   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# 2023/09/07 19:29:33.828217216 Requirement already satisfied: cffi==1.15.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 21)) (1.15.1)
# 2023/09/07 19:29:33.939650481 Collecting charset-normalizer==3.1.0 (from -r python/requirements.txt (line 22))
# 2023/09/07 19:29:33.943111121   Using cached charset_normalizer-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (197 kB)
# 2023/09/07 19:29:33.978434319 Collecting click==8.1.3 (from -r python/requirements.txt (line 23))
# 2023/09/07 19:29:33.981634316   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# 2023/09/07 19:29:34.002425535 Collecting comm==0.1.3 (from -r python/requirements.txt (line 24))
# 2023/09/07 19:29:34.006411898   Using cached comm-0.1.3-py3-none-any.whl (6.6 kB)
# 2023/09/07 19:29:34.253663826 Collecting debugpy==1.6.7 (from -r python/requirements.txt (line 25))
# 2023/09/07 19:29:34.286693079   Using cached debugpy-1.6.7-py2.py3-none-any.whl (4.9 MB)
# 2023/09/07 19:29:34.314064257 Requirement already satisfied: decorator==5.1.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 26)) (5.1.1)
# 2023/09/07 19:29:34.316876543 Requirement already satisfied: defusedxml==0.7.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 27)) (0.7.1)
# 2023/09/07 19:29:34.341862898 Collecting exceptiongroup==1.1.1 (from -r python/requirements.txt (line 28))
# 2023/09/07 19:29:34.344270675   Using cached exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# 2023/09/07 19:29:34.347507382 Requirement already satisfied: executing==1.2.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 29)) (1.2.0)
# 2023/09/07 19:29:34.349847440 Requirement already satisfied: fastapi==0.98.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 30)) (0.98.0)
# 2023/09/07 19:29:34.351490441 Requirement already satisfied: fastjsonschema==2.18.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 31)) (2.18.0)
# 2023/09/07 19:29:34.382419292 Collecting filelock==3.12.2 (from -r python/requirements.txt (line 32))
# 2023/09/07 19:29:34.382742634   Obtaining dependency information for filelock==3.12.2 from https://files.pythonhosted.org/packages/00/45/ec3407adf6f6b5bf867a4462b2b0af27597a26bd3cd6e2534cb6ab029938/filelock-3.12.2-py3-none-any.whl.metadata
# 2023/09/07 19:29:34.384975765   Using cached filelock-3.12.2-py3-none-any.whl.metadata (2.7 kB)
# 2023/09/07 19:29:34.387638779 Requirement already satisfied: fqdn==1.5.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 33)) (1.5.1)
# 2023/09/07 19:29:34.389431362 Requirement already satisfied: frozenlist==1.4.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 34)) (1.4.0)
# 2023/09/07 19:29:34.391166072 Requirement already satisfied: fsspec==2023.6.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 35)) (2023.6.0)
# 2023/09/07 19:29:34.392767182 Requirement already satisfied: greenlet==2.0.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 36)) (2.0.2)
# 2023/09/07 19:29:34.394062124 Requirement already satisfied: h11==0.14.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 37)) (0.14.0)
# 2023/09/07 19:29:34.426813635 Collecting httpcore==0.17.2 (from -r python/requirements.txt (line 38))
# 2023/09/07 19:29:34.427040099   Obtaining dependency information for httpcore==0.17.2 from https://files.pythonhosted.org/packages/4d/32/b908f673ccef12b6425b848a541264ee3d95f5f571f18f6ab0d8c311442e/httpcore-0.17.2-py3-none-any.whl.metadata
# 2023/09/07 19:29:34.429508360   Using cached httpcore-0.17.2-py3-none-any.whl.metadata (17 kB)
# 2023/09/07 19:29:34.433789424 Requirement already satisfied: httpx==0.24.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 39)) (0.24.1)
# 2023/09/07 19:29:34.435284617 Requirement already satisfied: humanize==4.7.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 40)) (4.7.0)
# 2023/09/07 19:29:34.466799511 Collecting ibis-framework==6.0.0 (from -r python/requirements.txt (line 41))
# 2023/09/07 19:29:34.467038925   Obtaining dependency information for ibis-framework==6.0.0 from https://files.pythonhosted.org/packages/46/59/f83e854af47ab81062a5a07ac81956b2d4cdc150518fe4b8ea028dca146d/ibis_framework-6.0.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:34.469404479   Using cached ibis_framework-6.0.0-py3-none-any.whl.metadata (16 kB)
# 2023/09/07 19:29:34.474355208 Requirement already satisfied: idna==3.4 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 42)) (3.4)
# 2023/09/07 19:29:34.544316187 Collecting importlib-metadata==6.7.0 (from -r python/requirements.txt (line 43))
# 2023/09/07 19:29:34.544614066   Obtaining dependency information for importlib-metadata==6.7.0 from https://files.pythonhosted.org/packages/ff/94/64287b38c7de4c90683630338cf28f129decbba0a44f0c6db35a873c73c4/importlib_metadata-6.7.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:34.547064068   Using cached importlib_metadata-6.7.0-py3-none-any.whl.metadata (4.9 kB)
# 2023/09/07 19:29:34.641450284 Collecting importlib-resources==5.12.0 (from -r python/requirements.txt (line 44))
# 2023/09/07 19:29:34.645179898   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# 2023/09/07 19:29:34.724894412 Collecting ipykernel==6.23.3 (from -r python/requirements.txt (line 45))
# 2023/09/07 19:29:34.725364733   Obtaining dependency information for ipykernel==6.23.3 from https://files.pythonhosted.org/packages/e6/48/6b01a27e084f47652f110342a04856a9751be4536b1203254ac95e22015f/ipykernel-6.23.3-py3-none-any.whl.metadata
# 2023/09/07 19:29:34.728051957   Using cached ipykernel-6.23.3-py3-none-any.whl.metadata (6.3 kB)
# 2023/09/07 19:29:34.733063027 Requirement already satisfied: ipython==8.14.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 46)) (8.14.0)
# 2023/09/07 19:29:34.734387547 Requirement already satisfied: ipython-genutils==0.2.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 47)) (0.2.0)
# 2023/09/07 19:29:34.789273617 Collecting ipywidgets==8.1.0 (from -r python/requirements.txt (line 48))
# 2023/09/07 19:29:34.789603069   Obtaining dependency information for ipywidgets==8.1.0 from https://files.pythonhosted.org/packages/b8/d4/ce436660098b2f456e2b8fdf76d4f33cbc3766c874c4aa2f772c7a5e943f/ipywidgets-8.1.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:34.793282972   Downloading ipywidgets-8.1.0-py3-none-any.whl.metadata (2.4 kB)
# 2023/09/07 19:29:34.799480144 Requirement already satisfied: isoduration==20.11.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 49)) (20.11.0)
# 2023/09/07 19:29:34.827938723 Collecting jedi==0.18.2 (from -r python/requirements.txt (line 50))
# 2023/09/07 19:29:34.848991778   Using cached jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
# 2023/09/07 19:29:34.875944389 Requirement already satisfied: Jinja2==3.1.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 51)) (3.1.2)
# 2023/09/07 19:29:34.923834645 Collecting joblib==1.2.0 (from -r python/requirements.txt (line 52))
# 2023/09/07 19:29:34.928447186   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# 2023/09/07 19:29:34.934372237 Requirement already satisfied: json5==0.9.14 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 53)) (0.9.14)
# 2023/09/07 19:29:34.935830663 Requirement already satisfied: jsonpointer==2.4 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 54)) (2.4)
# 2023/09/07 19:29:34.990320840 Collecting jsonschema==4.18.6 (from -r python/requirements.txt (line 55))
# 2023/09/07 19:29:34.990722489   Obtaining dependency information for jsonschema==4.18.6 from https://files.pythonhosted.org/packages/b5/5c/ae834dd4160bbe9a4feb6e1f3e6189ab7772408823e294bd12eb6b4b4f44/jsonschema-4.18.6-py3-none-any.whl.metadata
# 2023/09/07 19:29:34.993434205   Using cached jsonschema-4.18.6-py3-none-any.whl.metadata (7.8 kB)
# 2023/09/07 19:29:34.997349935 Requirement already satisfied: jsonschema-specifications==2023.7.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 56)) (2023.7.1)
# 2023/09/07 19:29:34.998514571 Requirement already satisfied: jupyter==1.0.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 57)) (1.0.0)
# 2023/09/07 19:29:34.999961677 Requirement already satisfied: jupyter-console==6.6.3 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 58)) (6.6.3)
# 2023/09/07 19:29:35.002144554 Requirement already satisfied: jupyter-events==0.7.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 59)) (0.7.0)
# 2023/09/07 19:29:35.029973026 Collecting jupyter-lsp==2.2.0 (from -r python/requirements.txt (line 60))
# 2023/09/07 19:29:35.030291747   Obtaining dependency information for jupyter-lsp==2.2.0 from https://files.pythonhosted.org/packages/8f/b6/a1571e48550855a79898f851f57e5858b00eb36b09ea3b1a8bb65c53a290/jupyter_lsp-2.2.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:35.034961532   Downloading jupyter_lsp-2.2.0-py3-none-any.whl.metadata (1.8 kB)
# 2023/09/07 19:29:35.092051852 Collecting jupyter_client==8.3.0 (from -r python/requirements.txt (line 61))
# 2023/09/07 19:29:35.092337255   Obtaining dependency information for jupyter_client==8.3.0 from https://files.pythonhosted.org/packages/29/24/0491f7837cedf39ae0f96d9b3e4db2fae31cc4dd5eac00a98ab0db996c9b/jupyter_client-8.3.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:35.095425842   Using cached jupyter_client-8.3.0-py3-none-any.whl.metadata (8.5 kB)
# 2023/09/07 19:29:35.099211736 Requirement already satisfied: jupyter_core==5.3.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 62)) (5.3.1)
# 2023/09/07 19:29:35.179361241 Collecting jupyter_server==2.7.3 (from -r python/requirements.txt (line 63))
# 2023/09/07 19:29:35.179560852   Obtaining dependency information for jupyter_server==2.7.3 from https://files.pythonhosted.org/packages/96/a2/b432812537beaf22a9dbc0d50cb62471e57ef90df42738675760fb3dce98/jupyter_server-2.7.3-py3-none-any.whl.metadata
# 2023/09/07 19:29:35.187071371   Downloading jupyter_server-2.7.3-py3-none-any.whl.metadata (8.6 kB)
# 2023/09/07 19:29:35.217472219 Collecting jupyter_server_terminals==0.4.4 (from -r python/requirements.txt (line 64))
# 2023/09/07 19:29:35.222741070   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# 2023/09/07 19:29:35.507469822 Collecting jupyterlab==4.0.5 (from -r python/requirements.txt (line 65))
# 2023/09/07 19:29:35.507770148   Obtaining dependency information for jupyterlab==4.0.5 from https://files.pythonhosted.org/packages/71/a3/38b9d6492a393dcfdae9e82021655432a9fd6e8f4c03c30a7b55036c0d70/jupyterlab-4.0.5-py3-none-any.whl.metadata
# 2023/09/07 19:29:35.513735447   Downloading jupyterlab-4.0.5-py3-none-any.whl.metadata (15 kB)
# 2023/09/07 19:29:35.522490854 Requirement already satisfied: jupyterlab-pygments==0.2.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 66)) (0.2.2)
# 2023/09/07 19:29:35.556868719 Collecting jupyterlab-widgets==3.0.8 (from -r python/requirements.txt (line 67))
# 2023/09/07 19:29:35.557200428   Obtaining dependency information for jupyterlab-widgets==3.0.8 from https://files.pythonhosted.org/packages/74/5e/2475ac62faf2e342b2bf20b8d8e375f49400ecb38f52e4e0a7557eb1cedb/jupyterlab_widgets-3.0.8-py3-none-any.whl.metadata
# 2023/09/07 19:29:35.561796269   Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl.metadata (4.1 kB)
# 2023/09/07 19:29:35.567862004 Requirement already satisfied: jupyterlab_server==2.24.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 68)) (2.24.0)
# 2023/09/07 19:29:35.569624111 Requirement already satisfied: markdown-it-py==3.0.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 69)) (3.0.0)
# 2023/09/07 19:29:35.570960962 Requirement already satisfied: MarkupSafe==2.1.3 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 70)) (2.1.3)
# 2023/09/07 19:29:35.572263827 Requirement already satisfied: matplotlib-inline==0.1.6 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 71)) (0.1.6)
# 2023/09/07 19:29:35.573355098 Requirement already satisfied: mdurl==0.1.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 72)) (0.1.2)
# 2023/09/07 19:29:35.574455964 Requirement already satisfied: mistune==3.0.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 73)) (3.0.1)
# 2023/09/07 19:29:35.576525965 Requirement already satisfied: multidict==6.0.4 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 74)) (6.0.4)
# 2023/09/07 19:29:35.593464134 Collecting multipledispatch==1.0.0 (from -r python/requirements.txt (line 75))
# 2023/09/07 19:29:35.593771875   Obtaining dependency information for multipledispatch==1.0.0 from https://files.pythonhosted.org/packages/51/c0/00c9809d8b9346eb238a6bbd5f83e846a4ce4503da94a4c08cb7284c325b/multipledispatch-1.0.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:35.596204217   Using cached multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# 2023/09/07 19:29:35.598736051 Requirement already satisfied: mypy-extensions==1.0.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 76)) (1.0.0)
# 2023/09/07 19:29:35.600304769 Requirement already satisfied: nbclient==0.8.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 77)) (0.8.0)
# 2023/09/07 19:29:35.650842585 Collecting nbconvert==7.8.0 (from -r python/requirements.txt (line 78))
# 2023/09/07 19:29:35.651532076   Obtaining dependency information for nbconvert==7.8.0 from https://files.pythonhosted.org/packages/a4/a6/072b6fd04616f1409f37ef5967ea5bbbeea1447d4494c2d98658a95fc985/nbconvert-7.8.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:35.659114705   Downloading nbconvert-7.8.0-py3-none-any.whl.metadata (8.0 kB)
# 2023/09/07 19:29:35.666801325 Requirement already satisfied: nbformat==5.9.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 79)) (5.9.2)
# 2023/09/07 19:29:35.695628570 Collecting nest-asyncio==1.5.6 (from -r python/requirements.txt (line 80))
# 2023/09/07 19:29:35.698061945   Using cached nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# 2023/09/07 19:29:35.761030268 Collecting notebook==7.0.3 (from -r python/requirements.txt (line 81))
# 2023/09/07 19:29:35.761417678   Obtaining dependency information for notebook==7.0.3 from https://files.pythonhosted.org/packages/79/97/b803f9686fe25b40c8eca2d1ba440b2f878f23b87765d18fe93dd323f0b7/notebook-7.0.3-py3-none-any.whl.metadata
# 2023/09/07 19:29:35.765868700   Downloading notebook-7.0.3-py3-none-any.whl.metadata (10 kB)
# 2023/09/07 19:29:35.773335492 Requirement already satisfied: notebook_shim==0.2.3 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 82)) (0.2.3)
# 2023/09/07 19:29:36.110841066 Collecting numpy==1.25.0 (from -r python/requirements.txt (line 83))
# 2023/09/07 19:29:36.111184001   Obtaining dependency information for numpy==1.25.0 from https://files.pythonhosted.org/packages/f6/ae/546c18cad7525242d87def9ee1cba2e407028044f79c023ea8b2a11397d2/numpy-1.25.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# 2023/09/07 19:29:36.114211076   Using cached numpy-1.25.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# 2023/09/07 19:29:36.142538293 Collecting overrides==7.4.0 (from -r python/requirements.txt (line 84))
# 2023/09/07 19:29:36.142910223   Obtaining dependency information for overrides==7.4.0 from https://files.pythonhosted.org/packages/da/28/3fa6ef8297302fc7b3844980b6c5dbc71cdbd4b61e9b2591234214d5ab39/overrides-7.4.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:36.160804158   Downloading overrides-7.4.0-py3-none-any.whl.metadata (5.7 kB)
# 2023/09/07 19:29:36.167822523 Requirement already satisfied: packaging==23.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 85)) (23.1)
# 2023/09/07 19:29:36.433750763 Collecting pandas==2.0.2 (from -r python/requirements.txt (line 86))
# 2023/09/07 19:29:36.433881352   Obtaining dependency information for pandas==2.0.2 from https://files.pythonhosted.org/packages/e8/1d/9ee861bea351b6bc4d025ac9edbc765bac11239188561ebc3cf032d930fb/pandas-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# 2023/09/07 19:29:36.436332829   Using cached pandas-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# 2023/09/07 19:29:36.441303523 Requirement already satisfied: pandocfilters==1.5.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 87)) (1.5.0)
# 2023/09/07 19:29:36.443790422 Requirement already satisfied: parso==0.8.3 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 88)) (0.8.3)
# 2023/09/07 19:29:36.445632900 Requirement already satisfied: parsy==2.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 89)) (2.1)
# 2023/09/07 19:29:36.525815464 Collecting pathspec==0.11.2 (from -r python/requirements.txt (line 90))
# 2023/09/07 19:29:36.526225282   Obtaining dependency information for pathspec==0.11.2 from https://files.pythonhosted.org/packages/b4/2a/9b1be29146139ef459188f5e420a66e835dda921208db600b7037093891f/pathspec-0.11.2-py3-none-any.whl.metadata
# 2023/09/07 19:29:36.529090072   Using cached pathspec-0.11.2-py3-none-any.whl.metadata (19 kB)
# 2023/09/07 19:29:36.533055574 Requirement already satisfied: pexpect==4.8.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 91)) (4.8.0)
# 2023/09/07 19:29:36.534164771 Requirement already satisfied: pickleshare==0.7.5 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 92)) (0.7.5)
# 2023/09/07 19:29:36.535813027 Requirement already satisfied: pins==0.8.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 93)) (0.8.1)
# 2023/09/07 19:29:36.598955120 Collecting pip-tools==6.13.0 (from -r python/requirements.txt (line 94))
# 2023/09/07 19:29:36.602178744   Using cached pip_tools-6.13.0-py3-none-any.whl (53 kB)
# 2023/09/07 19:29:36.635472275 Collecting platformdirs==3.8.0 (from -r python/requirements.txt (line 95))
# 2023/09/07 19:29:36.635908615   Obtaining dependency information for platformdirs==3.8.0 from https://files.pythonhosted.org/packages/e7/61/7fde5beff25a0dae6c2056203696169bd29188b6cedefff8ba6e7b54417b/platformdirs-3.8.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:36.638517580   Using cached platformdirs-3.8.0-py3-none-any.whl.metadata (11 kB)
# 2023/09/07 19:29:36.706375501 Collecting plotly==5.15.0 (from -r python/requirements.txt (line 96))
# 2023/09/07 19:29:36.706807473   Obtaining dependency information for plotly==5.15.0 from https://files.pythonhosted.org/packages/a5/07/5bef9376c975ce23306d9217ab69ca94c07f2a3c90b17c03e3ae4db87170/plotly-5.15.0-py2.py3-none-any.whl.metadata
# 2023/09/07 19:29:36.732737904   Using cached plotly-5.15.0-py2.py3-none-any.whl.metadata (7.0 kB)
# 2023/09/07 19:29:36.736559002 Requirement already satisfied: pooch==1.7.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 97)) (1.7.0)
# 2023/09/07 19:29:36.738681197 Requirement already satisfied: prometheus-client==0.17.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 98)) (0.17.1)
# 2023/09/07 19:29:36.811322592 Collecting prompt-toolkit==3.0.38 (from -r python/requirements.txt (line 99))
# 2023/09/07 19:29:36.816921781   Using cached prompt_toolkit-3.0.38-py3-none-any.whl (385 kB)
# 2023/09/07 19:29:36.825848527 Requirement already satisfied: psutil==5.9.5 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 100)) (5.9.5)
# 2023/09/07 19:29:36.978449115 Collecting psycopg2==2.9.6 (from -r python/requirements.txt (line 101))
# 2023/09/07 19:29:36.978720211   Using cached psycopg2-2.9.6-cp311-cp311-linux_x86_64.whl
# 2023/09/07 19:29:36.984792533 Requirement already satisfied: ptyprocess==0.7.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 102)) (0.7.0)
# 2023/09/07 19:29:36.986248944 Requirement already satisfied: pure-eval==0.2.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 103)) (0.2.2)
# 2023/09/07 19:29:36.987411077 Requirement already satisfied: pyarrow==12.0.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 104)) (12.0.1)
# 2023/09/07 19:29:36.988514410 Requirement already satisfied: pycparser==2.21 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 105)) (2.21)
# 2023/09/07 19:29:37.238225196 Collecting pydantic==1.10.9 (from -r python/requirements.txt (line 106))
# 2023/09/07 19:29:37.238643520   Obtaining dependency information for pydantic==1.10.9 from https://files.pythonhosted.org/packages/ce/80/92bdb68e1fda29be502adfd0b95c4cdef41f498a35125d0d540d4696c091/pydantic-1.10.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# 2023/09/07 19:29:37.242079887   Using cached pydantic-1.10.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (147 kB)
# 2023/09/07 19:29:37.296429911 Collecting Pygments==2.15.1 (from -r python/requirements.txt (line 107))
# 2023/09/07 19:29:37.303279731   Using cached Pygments-2.15.1-py3-none-any.whl (1.1 MB)
# 2023/09/07 19:29:37.342710720 Collecting PyJWT==2.7.0 (from -r python/requirements.txt (line 108))
# 2023/09/07 19:29:37.345417077   Using cached PyJWT-2.7.0-py3-none-any.whl (22 kB)
# 2023/09/07 19:29:37.348419636 Requirement already satisfied: pyproject_hooks==1.0.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 109)) (1.0.0)
# 2023/09/07 19:29:37.349981269 Requirement already satisfied: python-dateutil==2.8.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 110)) (2.8.2)
# 2023/09/07 19:29:37.352093218 Requirement already satisfied: python-dotenv==1.0.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 111)) (1.0.0)
# 2023/09/07 19:29:37.353739463 Requirement already satisfied: python-json-logger==2.0.7 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 112)) (2.0.7)
# 2023/09/07 19:29:37.355555999 Requirement already satisfied: pytz==2023.3 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 113)) (2023.3)
# 2023/09/07 19:29:37.423392764 Collecting PyYAML==6.0 (from -r python/requirements.txt (line 114))
# 2023/09/07 19:29:37.432494652   Using cached PyYAML-6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
# 2023/09/07 19:29:37.774235764 Collecting pyzmq==25.1.0 (from -r python/requirements.txt (line 115))
# 2023/09/07 19:29:37.774559232   Obtaining dependency information for pyzmq==25.1.0 from https://files.pythonhosted.org/packages/66/f5/15db4c297957f049cd4dcd35eb7fbe9098a72489e0abdb289c529d7327cc/pyzmq-25.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
# 2023/09/07 19:29:37.776791486   Using cached pyzmq-25.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# 2023/09/07 19:29:37.806834906 Collecting qtconsole==5.4.4 (from -r python/requirements.txt (line 116))
# 2023/09/07 19:29:37.807185556   Obtaining dependency information for qtconsole==5.4.4 from https://files.pythonhosted.org/packages/24/e2/7f22137bbb7270b016f6b0efa55d7598fef6ef354ba77515956bb28e8e54/qtconsole-5.4.4-py3-none-any.whl.metadata
# 2023/09/07 19:29:37.813399572   Downloading qtconsole-5.4.4-py3-none-any.whl.metadata (5.0 kB)
# 2023/09/07 19:29:37.846402692 Collecting QtPy==2.4.0 (from -r python/requirements.txt (line 117))
# 2023/09/07 19:29:37.846936553   Obtaining dependency information for QtPy==2.4.0 from https://files.pythonhosted.org/packages/be/a1/13bdd2f6237379744c52cec33d417a5819a07455d880e3c5f517c13a0f21/QtPy-2.4.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:37.852406466   Downloading QtPy-2.4.0-py3-none-any.whl.metadata (12 kB)
# 2023/09/07 19:29:37.905277310 Collecting referencing==0.30.1 (from -r python/requirements.txt (line 118))
# 2023/09/07 19:29:37.905591856   Obtaining dependency information for referencing==0.30.1 from https://files.pythonhosted.org/packages/dd/95/eba31f9bd6d2a16246bce844c5ca7c5ba777f0b854cca05d75a2e4e78e09/referencing-0.30.1-py3-none-any.whl.metadata
# 2023/09/07 19:29:37.908568630   Using cached referencing-0.30.1-py3-none-any.whl.metadata (2.6 kB)
# 2023/09/07 19:29:37.911501441 Requirement already satisfied: requests==2.31.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 119)) (2.31.0)
# 2023/09/07 19:29:37.912784606 Requirement already satisfied: rfc3339-validator==0.1.4 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 120)) (0.1.4)
# 2023/09/07 19:29:37.914009239 Requirement already satisfied: rfc3986-validator==0.1.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 121)) (0.1.1)
# 2023/09/07 19:29:37.916046160 Requirement already satisfied: rich==13.4.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 122)) (13.4.2)
# 2023/09/07 19:29:37.917243424 Requirement already satisfied: rpds-py==0.9.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 123)) (0.9.2)
# 2023/09/07 19:29:38.066566959 Collecting scikit-learn==1.2.2 (from -r python/requirements.txt (line 124))
# 2023/09/07 19:29:38.137888113   Using cached scikit_learn-1.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
# 2023/09/07 19:29:38.384351289 Collecting scipy==1.11.0 (from -r python/requirements.txt (line 125))
# 2023/09/07 19:29:38.384685833   Obtaining dependency information for scipy==1.11.0 from https://files.pythonhosted.org/packages/27/10/985c0902929a424c8e0483f16ee54f92fc5e4fa07fbd83a36f3aa469b3fe/scipy-1.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# 2023/09/07 19:29:38.387420528   Using cached scipy-1.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (59 kB)
# 2023/09/07 19:29:38.402240094 Requirement already satisfied: semver==2.13.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 126)) (2.13.0)
# 2023/09/07 19:29:38.403519083 Requirement already satisfied: Send2Trash==1.8.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 127)) (1.8.2)
# 2023/09/07 19:29:38.404608918 Requirement already satisfied: six==1.16.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 128)) (1.16.0)
# 2023/09/07 19:29:38.406290900 Requirement already satisfied: sniffio==1.3.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 129)) (1.3.0)
# 2023/09/07 19:29:38.513769171 Collecting soupsieve==2.5 (from -r python/requirements.txt (line 130))
# 2023/09/07 19:29:38.514134799   Obtaining dependency information for soupsieve==2.5 from https://files.pythonhosted.org/packages/4c/f3/038b302fdfbe3be7da016777069f26ceefe11a681055ea1f7817546508e3/soupsieve-2.5-py3-none-any.whl.metadata
# 2023/09/07 19:29:38.518167969   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# 2023/09/07 19:29:39.023512546 Collecting SQLAlchemy==2.0.18 (from -r python/requirements.txt (line 131))
# 2023/09/07 19:29:39.023853084   Obtaining dependency information for SQLAlchemy==2.0.18 from https://files.pythonhosted.org/packages/17/0a/a92d6ac179153aa2b3e82bb50892397aec45150ead07573b53418e2578ce/SQLAlchemy-2.0.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# 2023/09/07 19:29:39.026177919   Using cached SQLAlchemy-2.0.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.4 kB)
# 2023/09/07 19:29:39.029869097 Requirement already satisfied: sqlalchemy-views==0.3.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 132)) (0.3.2)
# 2023/09/07 19:29:39.152498648 Collecting sqlglot==17.3.0 (from -r python/requirements.txt (line 133))
# 2023/09/07 19:29:39.152810850   Obtaining dependency information for sqlglot==17.3.0 from https://files.pythonhosted.org/packages/d9/12/4240c368d3bb8b0cd640b383737f59bf1b6f882edd07fff1f950a1326948/sqlglot-17.3.0-py3-none-any.whl.metadata
# 2023/09/07 19:29:39.155138814   Using cached sqlglot-17.3.0-py3-none-any.whl.metadata (15 kB)
# 2023/09/07 19:29:39.159514291 Requirement already satisfied: stack-data==0.6.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 134)) (0.6.2)
# 2023/09/07 19:29:39.160998383 Requirement already satisfied: starlette==0.27.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 135)) (0.27.0)
# 2023/09/07 19:29:39.189614447 Collecting tenacity==8.2.2 (from -r python/requirements.txt (line 136))
# 2023/09/07 19:29:39.193843125   Using cached tenacity-8.2.2-py3-none-any.whl (24 kB)
# 2023/09/07 19:29:39.197564269 Requirement already satisfied: terminado==0.17.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 137)) (0.17.1)
# 2023/09/07 19:29:39.219854081 Collecting threadpoolctl==3.1.0 (from -r python/requirements.txt (line 138))
# 2023/09/07 19:29:39.223017526   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# 2023/09/07 19:29:39.226808366 Requirement already satisfied: tinycss2==1.2.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 139)) (1.2.1)
# 2023/09/07 19:29:39.251856333 Collecting tokenize-rt==5.2.0 (from -r python/requirements.txt (line 140))
# 2023/09/07 19:29:39.252699814   Obtaining dependency information for tokenize-rt==5.2.0 from https://files.pythonhosted.org/packages/8d/35/78f03aa48cfebd13646707f64477bc7eacf1081edcdcd1b4d57cb1b5d0a8/tokenize_rt-5.2.0-py2.py3-none-any.whl.metadata
# 2023/09/07 19:29:39.255492647   Using cached tokenize_rt-5.2.0-py2.py3-none-any.whl.metadata (4.1 kB)
# 2023/09/07 19:29:39.287100231 Collecting tomli==2.0.1 (from -r python/requirements.txt (line 141))
# 2023/09/07 19:29:39.290243555   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# 2023/09/07 19:29:39.293518506 Requirement already satisfied: toolz==0.12.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 142)) (0.12.0)
# 2023/09/07 19:29:39.372267938 Collecting tornado==6.3.2 (from -r python/requirements.txt (line 143))
# 2023/09/07 19:29:39.373559274   Obtaining dependency information for tornado==6.3.2 from https://files.pythonhosted.org/packages/31/51/894f260c1380853cc268f661fe599a4523a47d07e867386abb58f1f11278/tornado-6.3.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# 2023/09/07 19:29:39.376065879   Using cached tornado-6.3.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# 2023/09/07 19:29:39.452169891 Collecting tqdm==4.65.0 (from -r python/requirements.txt (line 144))
# 2023/09/07 19:29:39.455092562   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# 2023/09/07 19:29:39.460234469 Requirement already satisfied: traitlets==5.9.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 145)) (5.9.0)
# 2023/09/07 19:29:39.485462167 Collecting typing_extensions==4.6.3 (from -r python/requirements.txt (line 146))
# 2023/09/07 19:29:39.485805438   Obtaining dependency information for typing_extensions==4.6.3 from https://files.pythonhosted.org/packages/5f/86/d9b1518d8e75b346a33eb59fa31bdbbee11459a7e2cc5be502fa779e96c5/typing_extensions-4.6.3-py3-none-any.whl.metadata
# 2023/09/07 19:29:39.487893890   Using cached typing_extensions-4.6.3-py3-none-any.whl.metadata (2.8 kB)
# 2023/09/07 19:29:39.512192801 Collecting tzdata==2023.3 (from -r python/requirements.txt (line 147))
# 2023/09/07 19:29:39.516448998   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# 2023/09/07 19:29:39.523727179 Requirement already satisfied: uri-template==1.3.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 148)) (1.3.0)
# 2023/09/07 19:29:39.575082076 Collecting urllib3==2.0.3 (from -r python/requirements.txt (line 149))
# 2023/09/07 19:29:39.575674100   Obtaining dependency information for urllib3==2.0.3 from https://files.pythonhosted.org/packages/8a/03/ad9306a50d05c166e3456fe810f33cee2b8b2a7a6818ec5d4908c4ec6b36/urllib3-2.0.3-py3-none-any.whl.metadata
# 2023/09/07 19:29:39.577866307   Using cached urllib3-2.0.3-py3-none-any.whl.metadata (6.6 kB)
# 2023/09/07 19:29:39.581033656 Requirement already satisfied: uvicorn==0.22.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 150)) (0.22.0)
# 2023/09/07 19:29:39.600084565 Collecting vetiver==0.2.0 (from -r python/requirements.txt (line 151))
# 2023/09/07 19:29:39.602796241   Using cached vetiver-0.2.0-py3-none-any.whl (104 kB)
# 2023/09/07 19:29:39.606461811 Requirement already satisfied: wcwidth==0.2.6 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 152)) (0.2.6)
# 2023/09/07 19:29:39.607875510 Requirement already satisfied: webcolors==1.13 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 153)) (1.13)
# 2023/09/07 19:29:39.609285705 Requirement already satisfied: webencodings==0.5.1 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 154)) (0.5.1)
# 2023/09/07 19:29:39.642054169 Collecting websocket-client==1.6.2 (from -r python/requirements.txt (line 155))
# 2023/09/07 19:29:39.642318203   Obtaining dependency information for websocket-client==1.6.2 from https://files.pythonhosted.org/packages/4b/4a/3176388095e5bae6e6a1fbee66c438809230ae0196e7de4af12c5e75c509/websocket_client-1.6.2-py3-none-any.whl.metadata
# 2023/09/07 19:29:39.646064109   Downloading websocket_client-1.6.2-py3-none-any.whl.metadata (7.5 kB)
# 2023/09/07 19:29:39.697832494 Collecting widgetsnbextension==4.0.8 (from -r python/requirements.txt (line 156))
# 2023/09/07 19:29:39.698105588   Obtaining dependency information for widgetsnbextension==4.0.8 from https://files.pythonhosted.org/packages/8e/d4/d31b12ac0b87e8cc9fdb6ea1eb6596de405eaaa2f25606aaa755d0eebbc0/widgetsnbextension-4.0.8-py3-none-any.whl.metadata
# 2023/09/07 19:29:39.702158933   Downloading widgetsnbextension-4.0.8-py3-none-any.whl.metadata (1.6 kB)
# 2023/09/07 19:29:39.764301855 Collecting xgboost==1.7.6 (from -r python/requirements.txt (line 157))
# 2023/09/07 19:29:39.764621964   Obtaining dependency information for xgboost==1.7.6 from https://files.pythonhosted.org/packages/8c/3a/c9c5d4d5c49b132ef15ac7b5ccf56ef1c82efe36cd19414771762e97c00e/xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl.metadata
# 2023/09/07 19:29:39.766931683   Using cached xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl.metadata (1.9 kB)
# 2023/09/07 19:29:39.904170785 Collecting xxhash==3.2.0 (from -r python/requirements.txt (line 158))
# 2023/09/07 19:29:39.908065708   Using cached xxhash-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# 2023/09/07 19:29:39.912973106 Requirement already satisfied: yarl==1.9.2 in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 159)) (1.9.2)
# 2023/09/07 19:29:39.947053541 Collecting zipp==3.15.0 (from -r python/requirements.txt (line 160))
# 2023/09/07 19:29:39.949678790   Using cached zipp-3.15.0-py3-none-any.whl (6.8 kB)
# 2023/09/07 19:29:39.952142306 Requirement already satisfied: websockets in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 161)) (11.0.3)
# 2023/09/07 19:29:39.953403874 Requirement already satisfied: aiofiles in /opt/python/3.11.3/lib/python3.11/site-packages (from -r python/requirements.txt (line 162)) (22.1.0)
# 2023/09/07 19:29:41.062502055 Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from jupyter-events==0.7.0->-r python/requirements.txt (line 59)) (4.19.0)
# 2023/09/07 19:29:41.992314133 Requirement already satisfied: pip>=22.2 in ./python/env/lib/python3.11/site-packages (from pip-tools==6.13.0->-r python/requirements.txt (line 94)) (23.2.1)
# 2023/09/07 19:29:41.993562470 Requirement already satisfied: setuptools in ./python/env/lib/python3.11/site-packages (from pip-tools==6.13.0->-r python/requirements.txt (line 94)) (68.2.0)
# 2023/09/07 19:29:41.994421618 Requirement already satisfied: wheel in ./python/env/lib/python3.11/site-packages (from pip-tools==6.13.0->-r python/requirements.txt (line 94)) (0.41.2)
# 2023/09/07 19:29:43.487191877 Requirement already satisfied: rsconnect-python>=1.8.0 in /opt/python/3.11.3/lib/python3.11/site-packages (from vetiver==0.2.0->-r python/requirements.txt (line 151)) (1.19.0)
# 2023/09/07 19:29:43.857270783 INFO: pip is looking at multiple versions of jsonschema[format-nongpl] to determine which version is compatible with other requirements. This could take a while.
# 2023/09/07 19:29:44.135882516 WARNING: The candidate selected for download or install is a yanked version: 'scipy' candidate (version 1.11.0 at https://files.pythonhosted.org/packages/27/10/985c0902929a424c8e0483f16ee54f92fc5e4fa07fbd83a36f3aa469b3fe/scipy-1.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/scipy/) (requires-python:<3.13,>=3.9))
# 2023/09/07 19:29:44.135903245 Reason for being yanked: License Violation
# 2023/09/07 19:29:44.144409551 Using cached anyio-3.7.0-py3-none-any.whl (80 kB)
# 2023/09/07 19:29:44.148964536 Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# 2023/09/07 19:29:44.156622068 Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# 2023/09/07 19:29:44.163676246 Using cached atpublic-4.0-py3-none-any.whl (4.9 kB)
# 2023/09/07 19:29:44.175412135 Using cached black-23.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# 2023/09/07 19:29:44.180286167 Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# 2023/09/07 19:29:44.183049933 Using cached httpcore-0.17.2-py3-none-any.whl (72 kB)
# 2023/09/07 19:29:44.191760522 Using cached ibis_framework-6.0.0-py3-none-any.whl (1.5 MB)
# ...
# 2023/09/07 19:30:00.089803214   Attempting uninstall: async-timeout
# 2023/09/07 19:30:00.107759058     Found existing installation: async-timeout 4.0.3
# 2023/09/07 19:30:00.108567626     Not uninstalling async-timeout at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:00.108583260     Can't uninstall 'async-timeout'. No files were found to uninstall.
# 2023/09/07 19:30:00.128976135   Attempting uninstall: anyio
# 2023/09/07 19:30:00.169978773     Found existing installation: anyio 3.7.1
# 2023/09/07 19:30:00.170407199     Not uninstalling anyio at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:00.170670779     Can't uninstall 'anyio'. No files were found to uninstall.
# 2023/09/07 19:30:00.291137276   Attempting uninstall: SQLAlchemy
# 2023/09/07 19:30:00.384110903     Found existing installation: SQLAlchemy 2.0.19
# 2023/09/07 19:30:00.384600728     Not uninstalling sqlalchemy at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:00.384822077     Can't uninstall 'SQLAlchemy'. No files were found to uninstall.
# 2023/09/07 19:30:01.852964923   Attempting uninstall: scipy
# 2023/09/07 19:30:01.963514202     Found existing installation: scipy 1.11.1
# 2023/09/07 19:30:01.965391980     Not uninstalling scipy at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:01.965954963     Can't uninstall 'scipy'. No files were found to uninstall.
# 2023/09/07 19:30:06.088069971   Attempting uninstall: pydantic
# 2023/09/07 19:30:06.155126842     Found existing installation: pydantic 1.10.12
# 2023/09/07 19:30:06.155641815     Not uninstalling pydantic at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:06.155991777     Can't uninstall 'pydantic'. No files were found to uninstall.
# 2023/09/07 19:30:06.329410634   Attempting uninstall: plotly
# 2023/09/07 19:30:06.389704959     Found existing installation: plotly 5.16.0
# 2023/09/07 19:30:06.390201842     Not uninstalling plotly at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:06.390520924     Can't uninstall 'plotly'. No files were found to uninstall.
# 2023/09/07 19:30:14.389349478   Attempting uninstall: pip-tools
# 2023/09/07 19:30:14.433492419     Found existing installation: pip-tools 7.3.0
# 2023/09/07 19:30:14.433999388     Not uninstalling pip-tools at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:14.434333129     Can't uninstall 'pip-tools'. No files were found to uninstall.
# 2023/09/07 19:30:14.481744224   Attempting uninstall: pandas
# 2023/09/07 19:30:14.543962164     Found existing installation: pandas 1.5.3
# 2023/09/07 19:30:14.544430378     Not uninstalling pandas at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:14.544696515     Can't uninstall 'pandas'. No files were found to uninstall.
# 2023/09/07 19:30:19.699509443   Attempting uninstall: importlib-metadata
# 2023/09/07 19:30:19.796250263     Found existing installation: importlib-metadata 6.8.0
# 2023/09/07 19:30:19.796694897     Not uninstalling importlib-metadata at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:19.797242108     Can't uninstall 'importlib-metadata'. No files were found to uninstall.
# 2023/09/07 19:30:19.826632608   Attempting uninstall: httpcore
# 2023/09/07 19:30:19.876792940     Found existing installation: httpcore 0.17.3
# 2023/09/07 19:30:19.877325463     Not uninstalling httpcore at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:19.877591848     Can't uninstall 'httpcore'. No files were found to uninstall.
# 2023/09/07 19:30:22.728157827   Attempting uninstall: scikit-learn
# 2023/09/07 19:30:22.765494690     Found existing installation: scikit-learn 1.3.0
# 2023/09/07 19:30:22.766250010     Not uninstalling scikit-learn at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:22.766660701     Can't uninstall 'scikit-learn'. No files were found to uninstall.
# 2023/09/07 19:30:24.737885756   Attempting uninstall: jupyter_client
# 2023/09/07 19:30:24.774952068     Found existing installation: jupyter_client 7.4.9
# 2023/09/07 19:30:24.775393411     Not uninstalling jupyter-client at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:24.775758620     Can't uninstall 'jupyter_client'. No files were found to uninstall.
# 2023/09/07 19:30:24.847210026   Attempting uninstall: jsonschema
# 2023/09/07 19:30:24.877213413     Found existing installation: jsonschema 4.19.0
# 2023/09/07 19:30:24.877711541     Not uninstalling jsonschema at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:24.877991512     Can't uninstall 'jsonschema'. No files were found to uninstall.
# 2023/09/07 19:30:24.957278173   Attempting uninstall: argon2-cffi
# 2023/09/07 19:30:25.013767979     Found existing installation: argon2-cffi 21.3.0
# 2023/09/07 19:30:25.014231240     Not uninstalling argon2-cffi at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:25.014517304     Can't uninstall 'argon2-cffi'. No files were found to uninstall.
# 2023/09/07 19:30:25.030484710   Attempting uninstall: vetiver
# 2023/09/07 19:30:25.097024225     Found existing installation: vetiver 0.2.1
# 2023/09/07 19:30:25.097531059     Not uninstalling vetiver at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:25.097801107     Can't uninstall 'vetiver'. No files were found to uninstall.
# 2023/09/07 19:30:25.138373984   Attempting uninstall: ipywidgets
# 2023/09/07 19:30:25.231269425     Found existing installation: ipywidgets 7.7.5
# 2023/09/07 19:30:25.231777433     Not uninstalling ipywidgets at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:25.232261503     Can't uninstall 'ipywidgets'. No files were found to uninstall.
# 2023/09/07 19:30:25.360193584   Attempting uninstall: ipykernel
# 2023/09/07 19:30:25.510311259     Found existing installation: ipykernel 6.25.1
# 2023/09/07 19:30:25.510989987     Not uninstalling ipykernel at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:25.511362011     Can't uninstall 'ipykernel'. No files were found to uninstall.
# 2023/09/07 19:30:25.658557799   Attempting uninstall: qtconsole
# 2023/09/07 19:30:25.764889898     Found existing installation: qtconsole 5.4.3
# 2023/09/07 19:30:25.765373100     Not uninstalling qtconsole at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:25.765610116     Can't uninstall 'qtconsole'. No files were found to uninstall.
# 2023/09/07 19:30:25.869415758   Attempting uninstall: ibis-framework
# 2023/09/07 19:30:25.943614887     Found existing installation: ibis-framework 5.1.0
# 2023/09/07 19:30:25.944132898     Not uninstalling ibis-framework at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:25.944381493     Can't uninstall 'ibis-framework'. No files were found to uninstall.
# 2023/09/07 19:30:27.410742625   Attempting uninstall: nbconvert
# 2023/09/07 19:30:27.534122960     Found existing installation: nbconvert 7.7.3
# 2023/09/07 19:30:27.537225928     Not uninstalling nbconvert at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:27.538344299     Can't uninstall 'nbconvert'. No files were found to uninstall.
# 2023/09/07 19:30:27.669378428   Attempting uninstall: jupyter_server
# 2023/09/07 19:30:27.787637732     Found existing installation: jupyter-server 1.24.0
# 2023/09/07 19:30:27.791404534     Not uninstalling jupyter-server at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:27.791419424     Can't uninstall 'jupyter-server'. No files were found to uninstall.
# 2023/09/07 19:30:28.064246227   Attempting uninstall: jupyterlab
# 2023/09/07 19:30:28.174650580     Found existing installation: jupyterlab 3.6.5
# 2023/09/07 19:30:28.175091260     Not uninstalling jupyterlab at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:28.175336215     Can't uninstall 'jupyterlab'. No files were found to uninstall.
# 2023/09/07 19:30:28.570376628   Attempting uninstall: notebook
# 2023/09/07 19:30:28.622205505     Found existing installation: notebook 6.5.5
# 2023/09/07 19:30:28.622685922     Not uninstalling notebook at /opt/python/3.11.3/lib/python3.11/site-packages, outside environment /opt/rstudio-connect/mnt/app/python/env
# 2023/09/07 19:30:28.623068142     Can't uninstall 'notebook'. No files were found to uninstall.
# 2023/09/07 19:30:30.059227223 ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# 2023/09/07 19:30:30.059242976 typeguard 4.1.0 requires typing-extensions>=4.7.0; python_version < "3.12", but you have typing-extensions 4.6.3 which is incompatible.
# 2023/09/07 19:30:30.059310252 rsconnect-jupyter 1.8.0 requires notebook<7.0.0,>=6.1.5, but you have notebook 7.0.3 which is incompatible.
# 2023/09/07 19:30:30.059312488 workbench-jupyterlab 1.1.315 requires jupyter-server<2,>=1.6, but you have jupyter-server 2.7.3 which is incompatible.
# 2023/09/07 19:30:30.059490221 Successfully installed PyJWT-2.7.0 PyYAML-6.0 Pygments-2.15.1 QtPy-2.4.0 SQLAlchemy-2.0.18 anyio-3.7.0 argon2-cffi-23.1.0 async-lru-2.0.4 async-timeout-4.0.2 atpublic-4.0 black-23.7.0 certifi-2023.5.7 charset-normalizer-3.1.0 click-8.1.3 comm-0.1.3 debugpy-1.6.7 exceptiongroup-1.1.1 filelock-3.12.2 httpcore-0.17.2 ibis-framework-6.0.0 importlib-metadata-6.7.0 importlib-resources-5.12.0 ipykernel-6.23.3 ipywidgets-8.1.0 jedi-0.18.2 joblib-1.2.0 jsonschema-4.18.6 jupyter-lsp-2.2.0 jupyter_client-8.3.0 jupyter_server-2.7.3 jupyter_server_terminals-0.4.4 jupyterlab-4.0.5 jupyterlab-widgets-3.0.8 multipledispatch-1.0.0 nbconvert-7.8.0 nest-asyncio-1.5.6 notebook-7.0.3 numpy-1.25.0 overrides-7.4.0 pandas-2.0.2 pathspec-0.11.2 pip-tools-6.13.0 platformdirs-3.8.0 plotly-5.15.0 prompt-toolkit-3.0.38 psycopg2-2.9.6 pydantic-1.10.9 pyzmq-25.1.0 qtconsole-5.4.4 referencing-0.30.1 scikit-learn-1.2.2 scipy-1.11.0 soupsieve-2.5 sqlglot-17.3.0 tenacity-8.2.2 threadpoolctl-3.1.0 tokenize-rt-5.2.0
#  tomli-2.0.1 tornado-6.3.2 tqdm-4.65.0 typing_extensions-4.6.3 tzdata-2023.3 urllib3-2.0.3 vetiver-0.2.0 websocket-client-1.6.2 widgetsnbextension-4.0.8 xgboost-1.7.6 xxhash-3.2.0 zipp-3.15.0
# 2023/09/07 19:30:31.841733349 Packages in the environment: aiofiles==22.1.0, aiohttp==3.8.5, aiosignal==1.3.1, aiosqlite==0.19.0, anyio==3.7.0, appdirs==1.4.4, argcomplete==3.1.1, argon2-cffi==23.1.0, argon2-cffi-bindings==21.2.0, arrow==1.2.3, asgiref==3.7.2, asttokens==2.2.1, async-lru==2.0.4, async-timeout==4.0.2, atpublic==4.0, attrs==23.1.0, Babel==2.12.1, backcall==0.2.0, beautifulsoup4==4.12.2, bidict==0.22.1, black==23.7.0, bleach==6.0.0, branca==0.6.0, build==0.10.0, certifi==2023.5.7, cffi==1.15.1, charset-normalizer==3.1.0, click==8.1.3, comm==0.1.3, contextvars==2.4, contourpy==1.1.0, cycler==0.11.0, debugpy==1.6.7, decorator==5.1.1, defusedxml==0.7.1, entrypoints==0.4, exceptiongroup==1.1.1, executing==1.2.0, fastapi==0.98.0, fastjsonschema==2.18.0, filelock==3.12.2, fonttools==4.42.0, fqdn==1.5.1, frozenlist==1.4.0, fsspec==2023.6.0, greenlet==2.0.2, h11==0.14.0, htmltools==0.3.0, httpcore==0.17.2, httptools==0.6.0, httpx==0.24.1, humanize==4.7.0, ibis-framework==6.0.0, idna==3.4, immutables==0.
# 19, importlib-metadata==6.7.0, importlib-resources==5.12.0, ipykernel==6.23.3, ipyleaflet==0.17.3, ipython==8.14.0, ipython-genutils==0.2.0, ipywidgets==8.1.0, isoduration==20.11.0, jedi==0.18.2, Jinja2==3.1.2, joblib==1.2.0, json5==0.9.14, jsonpointer==2.4, jsonschema==4.18.6, jsonschema-specifications==2023.7.1, jupyter==1.0.0, jupyter-console==6.6.3, jupyter-events==0.7.0, jupyter-lsp==2.2.0, jupyter-ydoc==0.2.5, jupyter_client==8.3.0, jupyter_core==5.3.1, jupyter_server==2.7.3, jupyter_server_fileid==0.9.0, jupyter_server_proxy==4.0.0, jupyter_server_terminals==0.4.4, jupyter_server_ydoc==0.8.0, jupyterlab==4.0.5, jupyterlab-pygments==0.2.2, jupyterlab-widgets==3.0.8, jupyterlab_server==2.24.0, kiwisolver==1.4.4, linkify-it-py==2.0.2, markdown-it-py==3.0.0, MarkupSafe==2.1.3, matplotlib==3.7.2, matplotlib-inline==0.1.6, mdit-py-plugins==0.4.0, mdurl==0.1.2, mistune==3.0.1, multidict==6.0.4, multimethod==1.9.1, multipledispatch==1.0.0, mypy-extensions==1.0.0, nbclassic==1.0.0, nbclient==0.8.0, nbconvert==7
# .8.0, nbformat==5.9.2, nest-asyncio==1.5.6, notebook==7.0.3, notebook_shim==0.2.3, numpy==1.25.0, overrides==7.4.0, packaging==23.1, pandas==2.0.2, pandera==0.15.1, pandocfilters==1.5.0, parso==0.8.3, parsy==2.1, pathspec==0.11.2, pexpect==4.8.0, pickleshare==0.7.5, Pillow==10.0.0, pins==0.8.1, pip-tools==6.13.0, pipx==1.2.0, platformdirs==3.8.0, plotly==5.15.0, pooch==1.7.0, prometheus-client==0.17.1, prompt-toolkit==3.0.38, psutil==5.9.5, psycopg2==2.9.6, psycopg2-binary==2.9.6, ptyprocess==0.7.0, pure-eval==0.2.2, pyarrow==12.0.1, pycparser==2.21, pydantic==1.10.9, Pygments==2.15.1, PyJWT==2.7.0, pyparsing==3.0.9, pyproject_hooks==1.0.0, python-dateutil==2.8.2, python-dotenv==1.0.0, python-json-logger==2.0.7, python-multipart==0.0.6, pytz==2023.3, PyYAML==6.0, pyzmq==25.1.0, qtconsole==5.4.4, QtPy==2.4.0, referencing==0.30.1, requests==2.31.0, rfc3339-validator==0.1.4, rfc3986-validator==0.1.1, rich==13.4.2, rpds-py==0.9.2, rsconnect-jupyter==1.8.0, rsconnect-python==1.19.0, rsp-jupyter==1.5.0, scikit-lear
# n==1.2.2, scipy==1.11.0, semver==2.13.0, Send2Trash==1.8.2, shiny==0.4.0, shinyswatch==0.2.4, shinywidgets==0.2.1, simpervisor==1.0.0, six==1.16.0, sniffio==1.3.0, soupsieve==2.5, SQLAlchemy==2.0.18, sqlalchemy-views==0.3.2, sqlglot==17.3.0, stack-data==0.6.2, starlette==0.27.0, tenacity==8.2.2, terminado==0.17.1, threadpoolctl==3.1.0, tinycss2==1.2.1, tokenize-rt==5.2.0, tomli==2.0.1, toolz==0.12.0, tornado==6.3.2, tqdm==4.65.0, traitlets==5.9.0, traittypes==0.2.1, typeguard==4.1.0, typing-inspect==0.9.0, typing_extensions==4.6.3, tzdata==2023.3, uc-micro-py==1.0.2, uri-template==1.3.0, urllib3==2.0.3, userpath==1.9.0, uvicorn==0.22.0, uvloop==0.17.0, vetiver==0.2.0, watchfiles==0.19.0, wcwidth==0.2.6, webcolors==1.13, webencodings==0.5.1, websocket-client==1.6.2, websockets==11.0.3, widgetsnbextension==4.0.8, workbench-jupyterlab==1.1.315, wrapt==1.15.0, xgboost==1.7.6, XStatic-bootswatch==3.3.7.0, xxhash==3.2.0, xyzservices==2023.7.0, y-py==0.6.0, yarl==1.9.2, ypy-websocket==0.8.4, zipp==3.15.0,
# 2023/09/07 19:30:31.841866951 Creating lockfile: python/requirements.txt.lock
# Completed Python build against Python version: '3.11.3'
# Launching FastAPI application...
# Deployment completed successfully.
# 	 Dashboard content URL: https://connect.conf23workflows.training.posit.co/connect/#/apps/b9fe48dd-4e2d-4b92-8be7-331da686bd9e
# 	 Direct content URL: https://connect.conf23workflows.training.posit.co/content/b9fe48dd-4e2d-4b92-8be7-331da686bd9e/
