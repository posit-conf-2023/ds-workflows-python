# %%
# import required libraries
import os
import ibis
from dotenv import load_dotenv
import pandas as pd
import xgboost as xgb
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
import vetiver
import pins
import rsconnect
from datetime import datetime, timedelta

# %%
# setup local environment
load_dotenv()
# Out:
# True

# %%
# read inspection data from the database
con = ibis.postgres.connect(
    user="posit",
    password=os.environ["CONF23_DB_PASSWORD"],
    host=os.environ["CONF23_DB_HOST"],
    port=5432,
    database="conf23_python",
)

inspection_data = con.table("food_inspection_validated").to_pandas()

# %%
inspection_data
# Out:
#        inspection_id                          dba_name  \
# 0            2028690                        CHINA CAFE
# 1            2028768          NEW STONY SUMBARINE INC.
# 2            2028736                    BK'S FOOD, INC
# 3            2028718          LA UNICA FOOD MART, INC.
# 4            2028712  GT MARGIES MAXWELL STREET POLISH
# ...              ...                               ...
# 255135       2028642                      SAIGON LOTUS
# 255136       2028658                        PIZZA VINO
# 255137       2028677                     BEREKE, INC..
# 255138       2028674        NORTH WEST REGIONAL CENTER
# 255139       2028675               QUE RICO RESTAURANT
#
#                                  aka_name license_             facility_type  \
# 0                              CHINA CAFE  2419388                RESTAURANT
# 1                     NEW STONY SUBMARINE  2060138                RESTAURANT
# 2                               BK'S FOOD  2522198             GROCERY STORE
# 3                      LA UNICA FOOD MART      491  RESTAURANT/GROCERY STORE
# 4       GT MARGIES  MAXWELL STREET POLISH  2523680                RESTAURANT
# ...                                   ...      ...                       ...
# 255135                       SAIGON LOTUS  2523640                RESTAURANT
# 255136                         PIZZA VINO  2511390                RESTAURANT
# 255137                  BEREKE RESTAURANT  2241067                RESTAURANT
# 255138         NORTH WEST REGIONAL CENTER  1878473              GOLDEN DINER
# 255139                QUE RICO RESTAURANT  2152712                RESTAURANT
#
#                    risk    zip inspection_date        inspection_type  \
# 0         RISK 1 (HIGH)  60616      2017-04-20  CANVASS RE-INSPECTION
# 1         RISK 1 (HIGH)  60617      2017-04-21  CANVASS RE-INSPECTION
# 2       RISK 2 (MEDIUM)  60644      2017-04-21                LICENSE
# 3         RISK 1 (HIGH)  60660      2017-04-21                CANVASS
# 4         RISK 1 (HIGH)  60651      2017-04-21                LICENSE
# ...                 ...    ...             ...                    ...
# 255135    RISK 1 (HIGH)  60657      2017-04-20                LICENSE
# 255136     RISK 3 (LOW)  60638      2017-04-20                LICENSE
# 255137    RISK 1 (HIGH)  60625      2017-04-20                CANVASS
# 255138    RISK 1 (HIGH)  60618      2017-04-20              COMPLAINT
# 255139    RISK 1 (HIGH)  60657      2017-04-20                CANVASS
#
#                 results                                         violations
# 0                  PASS  {"33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTEN...
# 1                  PASS                                               None
# 2                  PASS                                               None
# 3                  FAIL  {"3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERAT...
# 4                  PASS                                               None
# ...                 ...                                                ...
# 255135        NOT READY                                               None
# 255136             FAIL                                               None
# 255137  OUT OF BUSINESS                                               None
# 255138             FAIL  {"18. NO EVIDENCE OF RODENT OR INSECT OUTER OP...
# 255139             FAIL  {"18. NO EVIDENCE OF RODENT OR INSECT OUTER OP...
#
# [255140 rows x 11 columns]

# %% [markdown]
# #### Exploratory Data Analysis

# %%
# (Uncomment to run some analysis)
#
# inspection_data.columns
# inspection_data.dtypes
# inspection_data.groupby("facility_type").count()["inspection_id"].sort_values(ascending=False)
# inspection_data.groupby("results").count()["inspection_id"]
# inspection_data['results'].unique()
# inspection_data.groupby("risk").count()["inspection_id"]
# inspection_data['violations']

# %% [markdown]
# #### Feature Engineering

# %%
inspection_data
# Out:
#        inspection_id                          dba_name  \
# 0            2028690                        CHINA CAFE
# 1            2028768          NEW STONY SUMBARINE INC.
# 2            2028736                    BK'S FOOD, INC
# 3            2028718          LA UNICA FOOD MART, INC.
# 4            2028712  GT MARGIES MAXWELL STREET POLISH
# ...              ...                               ...
# 255135       2028642                      SAIGON LOTUS
# 255136       2028658                        PIZZA VINO
# 255137       2028677                     BEREKE, INC..
# 255138       2028674        NORTH WEST REGIONAL CENTER
# 255139       2028675               QUE RICO RESTAURANT
#
#                                  aka_name license_             facility_type  \
# 0                              CHINA CAFE  2419388                RESTAURANT
# 1                     NEW STONY SUBMARINE  2060138                RESTAURANT
# 2                               BK'S FOOD  2522198             GROCERY STORE
# 3                      LA UNICA FOOD MART      491  RESTAURANT/GROCERY STORE
# 4       GT MARGIES  MAXWELL STREET POLISH  2523680                RESTAURANT
# ...                                   ...      ...                       ...
# 255135                       SAIGON LOTUS  2523640                RESTAURANT
# 255136                         PIZZA VINO  2511390                RESTAURANT
# 255137                  BEREKE RESTAURANT  2241067                RESTAURANT
# 255138         NORTH WEST REGIONAL CENTER  1878473              GOLDEN DINER
# 255139                QUE RICO RESTAURANT  2152712                RESTAURANT
#
#                    risk    zip inspection_date        inspection_type  \
# 0         RISK 1 (HIGH)  60616      2017-04-20  CANVASS RE-INSPECTION
# 1         RISK 1 (HIGH)  60617      2017-04-21  CANVASS RE-INSPECTION
# 2       RISK 2 (MEDIUM)  60644      2017-04-21                LICENSE
# 3         RISK 1 (HIGH)  60660      2017-04-21                CANVASS
# 4         RISK 1 (HIGH)  60651      2017-04-21                LICENSE
# ...                 ...    ...             ...                    ...
# 255135    RISK 1 (HIGH)  60657      2017-04-20                LICENSE
# 255136     RISK 3 (LOW)  60638      2017-04-20                LICENSE
# 255137    RISK 1 (HIGH)  60625      2017-04-20                CANVASS
# 255138    RISK 1 (HIGH)  60618      2017-04-20              COMPLAINT
# 255139    RISK 1 (HIGH)  60657      2017-04-20                CANVASS
#
#                 results                                         violations
# 0                  PASS  {"33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTEN...
# 1                  PASS                                               None
# 2                  PASS                                               None
# 3                  FAIL  {"3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERAT...
# 4                  PASS                                               None
# ...                 ...                                                ...
# 255135        NOT READY                                               None
# 255136             FAIL                                               None
# 255137  OUT OF BUSINESS                                               None
# 255138             FAIL  {"18. NO EVIDENCE OF RODENT OR INSECT OUTER OP...
# 255139             FAIL  {"18. NO EVIDENCE OF RODENT OR INSECT OUTER OP...
#
# [255140 rows x 11 columns]

# %%
# clean up input data for modelling

inspection_data_for_training = (
    inspection_data
    # remove NA licenses
    .loc[inspection_data["license_"] != 0]
    # select only Restaurant, Bakery, Grocery Store
    .loc[
        inspection_data["facility_type"].isin(["RESTAURANT", "BAKERY", "GROCERY STORE"])
    ]
    .pipe(
        lambda inspection_data: pd.get_dummies(
            inspection_data, columns=["facility_type"], prefix=[""], dtype=int
        )
    )
    .rename(
        columns={
            "_BAKERY": "BAKERY",
            "_RESTAURANT": "RESTAURANT",
            "_GROCERY STORE": "GROCERY_STORE",
        }
    )
    # filter out relavant inspection results
    .loc[inspection_data["results"].isin(["FAIL", "PASS", "PASS W/ CONDITIONS"])]
    # make Pass with Conditions results as Fail, since they are not completely pass
    .assign(results=(lambda x: x["results"].replace(["PASS W/ CONDITIONS"], "FAIL")))
    .assign(RESULTS=(lambda x: x["results"].map({"PASS": 1, "FAIL": 0}).astype(int)))
    .drop(columns=["results"])
    # filter out valid risk entries
    .loc[
        inspection_data["risk"].isin(
            ["RISK 1 (HIGH)", "RISK 2 (MEDIUM)", "RISK 3 (LOW)"]
        )
    ]
    # create dummy variables for risk
    .pipe(
        lambda inspection_data: pd.get_dummies(
            inspection_data, columns=["risk"], prefix=[""], dtype=int
        )
    )
    .rename(
        columns={
            "_RISK 1 (HIGH)": "HIGH_RISK",
            "_RISK 2 (MEDIUM)": "MEDIUM_RISK",
            "_RISK 3 (LOW)": "LOW_RISK",
        }
    )
    # sort results by business and inspection date
    .sort_values(by=["license_", "inspection_date"])
)

# %%
# count violations for each inspection
inspection_data_for_training["count_violations"] = (
    inspection_data_for_training["violations"]
    .apply(lambda x: len(x[1:-1].split('","')) if x is not None else None)
    .fillna(0)
)
# count cumilative violations for each date for a license
inspection_data_for_training["CUM_VIOLATIONS"] = inspection_data_for_training.groupby(
    ["license_"]
)["count_violations"].cumsum()

# %%
inspection_data_for_training
# Out:
#        inspection_id                        dba_name  \
# 107199        120273               QUITEFRANKLY,LTD.
# 109955         68320                     TACOS REYNA
# 112903         74431          MICHAEL'S FRESH MARKET
# 121726        335339               VRJ FOOD MART CO.
# 122804        428224  IRISH AMERICAN HERITAGE CENTER
# ...              ...                             ...
# 4126         2064867                   FALCO'S PIZZA
# 38461        2285869                   FALCO'S PIZZA
# 56540        2401917                   FALCO'S PIZZA
# 76496        2528308                   FALCO'S PIZZA
# 76709        2528447                   FALCO'S PIZZA
#
#                               aka_name license_    zip inspection_date  \
# 107199                   UPS CAFETERIA        0  60607      2010-01-06
# 109955                            None        0  60617      2010-03-02
# 112903          MICHAEL'S FRESH MARKET        0  60615      2010-05-03
# 121726               VRJ FOOD MART CO.        0  60637      2010-10-13
# 122804  IRISH AMERICAN HERITAGE CENTER        0  60630      2010-10-28
# ...                                ...      ...    ...             ...
# 4126                     FALCO'S PIZZA      990  60632      2017-06-23
# 38461                    FALCO'S PIZZA      990  60632      2019-04-26
# 56540                    FALCO'S PIZZA      990  60632      2020-10-01
# 76496                    FALCO'S PIZZA      990  60632      2021-08-20
# 76709                    FALCO'S PIZZA      990  60632      2021-08-24
#
#               inspection_type  \
# 107199                CANVASS
# 109955           CONSULTATION
# 112903           CONSULTATION
# 121726                CANVASS
# 122804            TAG REMOVAL
# ...                       ...
# 4126    CANVASS RE-INSPECTION
# 38461                 CANVASS
# 56540               COMPLAINT
# 76496                 CANVASS
# 76709   CANVASS RE-INSPECTION
#
#                                                violations  BAKERY  \
# 107199  {"33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTEN...       0
# 109955                                               None       0
# 112903  {"6. HANDS WASHED AND CLEANED, GOOD HYGIENIC P...       0
# 121726  {"9. WATER SOURCE: SAFE, HOT & COLD UNDER CITY...       0
# 122804  {"32. FOOD AND NON-FOOD CONTACT SURFACES PROPE...       0
# ...                                                   ...     ...
# 4126    {"32. FOOD AND NON-FOOD CONTACT SURFACES PROPE...       0
# 38461   {"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL...       0
# 56540   {"51. PLUMBING INSTALLED; PROPER BACKFLOW DEVI...       0
# 76496   {"16. FOOD-CONTACT SURFACES: CLEANED & SANITIZ...       0
# 76709   {"36. THERMOMETERS PROVIDED & ACCURATE - COMME...       0
#
#         GROCERY_STORE  RESTAURANT  RESULTS  HIGH_RISK  MEDIUM_RISK  LOW_RISK  \
# 107199              0           1        1          1            0         0
# 109955              0           1        0          1            0         0
# 112903              1           0        0          1            0         0
# 121726              1           0        0          0            1         0
# 122804              0           1        0          1            0         0
# ...               ...         ...      ...        ...          ...       ...
# 4126                0           1        1          1            0         0
# 38461               0           1        0          1            0         0
# 56540               0           1        1          1            0         0
# 76496               0           1        0          1            0         0
# 76709               0           1        1          1            0         0
#
#         count_violations  CUM_VIOLATIONS
# 107199               4.0             4.0
# 109955               0.0             4.0
# 112903               8.0            12.0
# 121726              13.0            25.0
# 122804               6.0            31.0
# ...                  ...             ...
# 4126                 3.0           100.0
# 38461               12.0           112.0
# 56540                3.0           115.0
# 76496                4.0           119.0
# 76709                3.0           122.0
#
# [179958 rows x 17 columns]

# %% [markdown]
# ##### Modelling

# %%
# Create training and test split
X = inspection_data_for_training.drop(
    columns=[
        "license_",
        "RESULTS",
        "inspection_id",
        "dba_name",
        "aka_name",
        "inspection_type",
        "violations",
        "count_violations",
        "inspection_date",
        "zip",
    ]
)
y = inspection_data_for_training[["RESULTS"]]

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Train a random forest model
clf = RandomForestClassifier(max_depth=10, random_state=0)
clf.fit(X_train, np.ravel(y_train))
# Out:
# RandomForestClassifier(max_depth=10, random_state=0)

# %%
# test predictions
y_pred = clf.predict(X_test)
mse = metrics.mean_squared_error(y_test, y_pred)

print(np.sqrt(mse))
# Out:
# 0.6348408414527528

# %% [markdown]
# ### Model deployment using Vetiver

# %%
# Create a vetiver model object

# %%
# Write the vetiver model as a pin for versioning
model_board = pins.board_connect(
    os.getenv("CONNECT_SERVER"),
    api_key=os.getenv("CONNECT_API_KEY"),
    allow_pickle_read=True
)
vetiver.vetiver_pin_write(model_board, model=v)
# Out:
# Model Cards provide a framework for transparent, responsible reporting.
#  Use the vetiver `.qmd` Quarto template as a place to start,
#  with vetiver.model_card()
# Writing pin:
# Name: 'gagan/inspection_results'
# Version: 20230802T155036Z-8ce58

# %%
# Deploy the vetiver model as an API on Posit Connect
rsc_server = os.getenv("CONNECT_SERVER")
rsc_key = os.getenv("CONNECT_API_KEY")
connect_server = rsconnect.api.RSConnectServer(url=rsc_server, api_key=rsc_key)


vetiver.deploy_rsconnect(
    connect_server=connect_server,
    board=model_board,
    pin_name="gagan/inspection_results",
)
# Out:
#     Warning: Capturing the environment using 'pip freeze'.
#              Consider creating a requirements.txt file instead.
# /usr/home/gagan/ds-workflows-python/materials/example/03-model-training/.venv/lib/python3.10/site-packages/vetiver/write_fastapi.py:21: UserWarning: Pinned vetiver model has no active version and no datetime on versions,
#               Do you need to check your pinned model?
#               Using version 77878
#   warnings.warn(
# Connect detected CLI commands and/or environment variables that overlap with stored credential.
# Check your environment variables (e.g. CONNECT_API_KEY) to make sure you want them to be used.
# Credential paremeters are taken with the following precedence: stored > CLI > environment.
# To ignore an environment variable, override it in the CLI with an empty string (e.g. -k '').
# Validating server... 	[OK]
# Validating app mode... 	[OK]
# Making bundle ... 	[OK]
# Deploying bundle ... 	[OK]
# Saving deployed information... 	[OK]
# Building FastAPI application...
# Bundle created with Python version 3.10.11 is compatible with environment Kubernetes::ghcr.io/rstudio/content-pro:r4.1.3-py3.10.11-ubuntu2204 with Python version 3.10.11 from /opt/python/3.10.11/bin/python3
# Bundle requested Python version 3.10.11; using /opt/python/3.10.11/bin/python3 from Kubernetes::ghcr.io/rstudio/content-pro:r4.1.3-py3.10.11-ubuntu2204 which has version 3.10.11
# Determining session server location ...
# 2023/07/30 20:31:02.052344346 [rsc-session] Content GUID: 7efa4a4d-e17b-4956-b9b3-37b6509be8c9
# 2023/07/30 20:31:02.127683662 [rsc-session] Content ID: 17474
# 2023/07/30 20:31:02.128437844 [rsc-session] Bundle ID: 77879
# Connecting to session server http://service-a77f5e70-3fc6-4367-b856-b05bb7ad233a.rstudio-connect:50734 ...
# Connected to session server http://service-a77f5e70-3fc6-4367-b856-b05bb7ad233a.rstudio-connect:50734
# 2023/07/30 20:31:02.328548034 Running on host: python-environment-restore-gtgqn-xhdhj
# 2023/07/30 20:31:02.658372116 Linux distribution: Ubuntu 22.04.2 LTS (jammy)
# 2023/07/30 20:31:02.664868147 Running as user: uid=999 gid=999 groups=999
# 2023/07/30 20:31:02.664888183 Connect version: 2023.05.0
# 2023/07/30 20:31:02.664931372 LANG: en_US.UTF-8
# 2023/07/30 20:31:02.664935673 Working directory: /opt/rstudio-connect/mnt/app
# 2023/07/30 20:31:02.664944433 Building environment using Python 3.10.11 (main, Jun  4 2023, 22:34:21) [GCC 11.3.0] at /opt/python/3.10.11/bin/python3
# 2023/07/30 20:31:02.700826915 Using cached environment: bEBNQn5UG0_wO82xYRx4-g
# 2023/07/30 20:31:08.565098350 Packages in the environment: aiofiles==23.1.0, anyio==3.7.0, appdirs==1.4.4, asttokens==2.2.1, atpublic==4.0, backcall==0.2.0, bidict==0.22.1, build==0.10.0, certifi==2023.5.7, charset-normalizer==3.1.0, click==8.1.3, comm==0.1.3, debugpy==1.6.7, decorator==5.1.1, exceptiongroup==1.1.1, executing==1.2.0, fastapi==0.98.0, filelock==3.12.2, fsspec==2023.6.0, greenlet==2.0.2, h11==0.14.0, httpcore==0.17.2, httpx==0.24.1, humanize==4.7.0, ibis-framework==6.0.0, idna==3.4, importlib-metadata==6.7.0, importlib-resources==5.12.0, ipykernel==6.23.3, ipython==8.14.0, jedi==0.18.2, Jinja2==3.1.2, joblib==1.2.0, jupyter_client==8.3.0, jupyter_core==5.3.1, markdown-it-py==3.0.0, MarkupSafe==2.1.3, matplotlib-inline==0.1.6, mdurl==0.1.2, multipledispatch==1.0.0, nest-asyncio==1.5.6, numpy==1.25.0, packaging==23.1, pandas==2.0.2, parso==0.8.3, parsy==2.1, pexpect==4.8.0, pickleshare==0.7.5, pins==0.8.1, pip-tools==6.13.0, platformdirs==3.8.0, plotly==5.15.0, pooch==1.7.0, prompt-toolkit==3.0.38, psutil==5.9.5, psycopg2==2.9.6, ptyprocess==0.7.0, pure-eval==0.2.2, pyarrow==12.0.1, pydantic==1.10.9, Pygments==2.15.1, PyJWT==2.7.0, pyproject_hooks==1.0.0, python-dateutil==2.8.2, python-dotenv==1.0.0, pytz==2023.3, PyYAML==6.0, pyzmq==25.1.0, requests==2.31.0, rich==13.4.2, rsconnect-python==1.19.0, scikit-learn==1.2.2, scipy==1.11.0, semver==2.13.0, six==1.16.0, sniffio==1.3.0, SQLAlchemy==2.0.18, sqlalchemy-views==0.3.2, sqlglot==17.3.0, stack-data==0.6.2, starlette==0.27.0, tenacity==8.2.2, threadpoolctl==3.1.0, tomli==2.0.1, toolz==0.12.0, tornado==6.3.2, tqdm==4.65.0, traitlets==5.9.0, typing_extensions==4.6.3, tzdata==2023.3, urllib3==2.0.3, uvicorn==0.22.0, vetiver==0.2.0, wcwidth==0.2.6, websockets==11.0.3, xgboost==1.7.6, xxhash==3.2.0, zipp==3.15.0,
# 2023/07/30 20:31:08.566781234 Creating lockfile: python/requirements.txt.lock
# session ping error: Get "http://service-a77f5e70-3fc6-4367-b856-b05bb7ad233a.rstudio-connect:50734/ping": dial tcp 10.100.181.126:50734: connect: connection refused
# Stopped session pings to http://service-a77f5e70-3fc6-4367-b856-b05bb7ad233a.rstudio-connect:50734
# Launching FastAPI application...
# Deployment completed successfully.
# 	 Dashboard content URL: https://colorado.posit.co/rsc/connect/#/apps/7efa4a4d-e17b-4956-b9b3-37b6509be8c9
# 	 Direct content URL: https://colorado.posit.co/rsc/content/7efa4a4d-e17b-4956-b9b3-37b6509be8c9/

# %% [markdown]
# #### Model monitoring

# %%
# Simulate multiple days of input data
data = X_test.copy()
data["RESULTS"] = y_test
data["date_obs"] = ""
data
# Out:
#         BAKERY  GROCERY_STORE  RESTAURANT  HIGH_RISK  MEDIUM_RISK  LOW_RISK  \
# 42587        0              0           1          1            0         0
# 247812       0              0           1          1            0         0
# 190834       0              0           1          1            0         0
# 83804        0              0           1          1            0         0
# 234767       0              0           1          1            0         0
# ...        ...            ...         ...        ...          ...       ...
# 46013        0              0           1          1            0         0
# 147108       0              0           1          0            1         0
# 25961        0              0           1          1            0         0
# 157777       0              0           1          0            1         0
# 4830         0              0           1          1            0         0
#
#         CUM_VIOLATIONS  RESULTS date_obs
# 42587             18.0        0
# 247812            39.0        1
# 190834             3.0        1
# 83804            129.0        0
# 234767            64.0        1
# ...                ...      ...      ...
# 46013             16.0        0
# 147108             4.0        1
# 25961             89.0        0
# 157777             5.0        1
# 4830              26.0        1
#
# [44990 rows x 9 columns]

# %%
endpoint = "https://colorado.posit.co/rsc/inspection_results/predict"
data["preds"] = vetiver.predict(endpoint, data).iloc[:, 0].values

# %%
# add last three dates
day_list = [
    (pd.Timestamp.today() - timedelta(days=2)).strftime("%Y-%m-%d"),
    (pd.Timestamp.today() - timedelta(days=1)).strftime("%Y-%m-%d"),
    (pd.Timestamp.today().strftime("%Y-%m-%d")),
]
day_list
# Out:
# ['2023-08-02', '2023-08-03', '2023-08-04']

# %%
data["date_obs"] = np.random.choice(day_list, size=len(data))

# %%
data
# Out:
#         BAKERY  GROCERY_STORE  RESTAURANT  HIGH_RISK  MEDIUM_RISK  LOW_RISK  \
# 42587        0              0           1          1            0         0
# 247812       0              0           1          1            0         0
# 190834       0              0           1          1            0         0
# 83804        0              0           1          1            0         0
# 234767       0              0           1          1            0         0
# ...        ...            ...         ...        ...          ...       ...
# 46013        0              0           1          1            0         0
# 147108       0              0           1          0            1         0
# 25961        0              0           1          1            0         0
# 157777       0              0           1          0            1         0
# 4830         0              0           1          1            0         0
#
#         CUM_VIOLATIONS  RESULTS    date_obs  preds
# 42587             18.0        0  2023-08-02      1
# 247812            39.0        1  2023-08-03      1
# 190834             3.0        1  2023-08-02      1
# 83804            129.0        0  2023-08-04      0
# 234767            64.0        1  2023-08-02      0
# ...                ...      ...         ...    ...
# 46013             16.0        0  2023-08-04      1
# 147108             4.0        1  2023-08-04      1
# 25961             89.0        0  2023-08-02      0
# 157777             5.0        1  2023-08-03      1
# 4830              26.0        1  2023-08-03      1
#
# [44990 rows x 10 columns]

# %%
# pin this dataset for use in model card
board.pin_write(data,"gagan/inspection_results_monitoring",type="parquet")
# Out:
# Writing pin:
# Name: 'gagan/inspection_results_monitoring'
# Version: 20230804T162655Z-80f1d
# Meta(title='inspection_results_monitoring: a pinned 44990 x 10 DataFrame', description=None, created='20230804T162655Z', pin_hash='80f1d6ba8242885c', file='inspection_results_monitoring.parquet', file_size=422651, type='parquet', api_version=1, version=VersionRaw(version='78050'), tags=None, name='gagan/inspection_results_monitoring', user={}, local={})

# %%
# define which metrics to track
metric_set = [metrics.mean_absolute_error, metrics.mean_squared_error, metrics.r2_score]

# choose time period to track over
td = timedelta(days=1)

# calculate metrics
original_metrics = vetiver.compute_metrics(
    data=data,
    date_var="date_obs",
    period=td,
    metric_set=metric_set,
    truth="RESULTS",
    estimate="preds",
)

# %%
original_metrics
# Out:
#        index      n               metric  estimate
# 0 2023-07-31  14980  mean_absolute_error  0.397463
# 1 2023-07-31  14980   mean_squared_error  0.397463
# 2 2023-07-31  14980             r2_score -0.638377
# 3 2023-08-01  15019  mean_absolute_error  0.403289
# 4 2023-08-01  15019   mean_squared_error  0.403289
# 5 2023-08-01  15019             r2_score -0.658787

# %%
# Write metrics as a pin
model_board.pin_write(original_metrics, "gagan/inspection_model_metrics", type="csv")
# Out:
# Writing pin:
# Name: 'gagan/inspection_model_metrics'
# Version: 20230802T173601Z-ec9a9
# Meta(title='inspection_model_metrics: a pinned 6 x 4 DataFrame', description=None, created='20230802T173601Z', pin_hash='ec9a94f9d83fc22e', file='inspection_model_metrics.csv', file_size=340, type='csv', api_version=1, version=VersionRaw(version='77969'), tags=None, name='gagan/inspection_model_metrics', user={}, local={})

# %%
# Model card
vetiver.model_card(path=".")
# Out:
# './model_card.qmd'
