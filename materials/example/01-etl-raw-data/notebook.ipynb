# %% [markdown]
# # Raw Data Ingestion
#
# This workshop will use data from the City of Chicago Open Data Portal: <https://data.cityofchicago.org>. The following datasets will be used:
#
# 1. Business license data: <https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr>
# 2. Food inspections: <https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5>

# %% [markdown]
# ## Setup

# %%
from urllib.parse import urlencode
import pins
import pandas as pd

# %%
pd.options.display.max_columns = 999

# %%
# Set up the board
board = pins.board_connect()
user_name = "sam.edwardes"

# %% [markdown]
# ## Data set (1): Business License Data
#
# <https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr>

# %% [markdown]
# **Step 1:** Gew the raw data from the data portal

# %%
base_url = "https://data.cityofchicago.org/resource/r5kz-chrr.csv"

params = {
    "$order": "id", 
    "$limit": 5_000_000
}

url = f"{base_url}?{urlencode(params)}"
print(url)
# Out:
# https://data.cityofchicago.org/resource/r5kz-chrr.csv?%24order=id&%24limit=5000000

# %%
# Read everything as a string so that the formatting is preserved. We will use 
# pandera later to convert everything to the correct type.
business_license_data = pd.read_csv(url, dtype=str)
business_license_data
# Out:
#                        id license_id account_number site_number  \
# 0        1000000-20020221    1000000         200001           1
# 1        1000049-20010816    1162772         200068           1
# 2        1000049-20020516    1233615          10141           2
# 3        1000049-20020816    1265665         200068           1
# 4        1000049-20030516    1342680          10141           2
# ...                   ...        ...            ...         ...
# 1104097     9999-20140916    2343163          26256           1
# 1104098     9999-20160916    2478055          26256           1
# 1104099     9999-20180916    2610578          26256           1
# 1104100     9999-20200916    2739432          26256           1
# 1104101     9999-20220916    2858021          26256           1
#
#                              legal_name          doing_business_as_name  \
# 0                           MARK BOSTON                COLORS IN MOTION
# 1                     ANTONIA CASTREJON           ILLUSIONS HAIR DESIGN
# 2             PEPE"S RETAIL MEATS, INC.              PEREZ MEXICAN FOOD
# 3                     ANTONIA CASTREJON           ILLUSIONS HAIR DESIGN
# 4             PEPE"S RETAIL MEATS, INC.              PEREZ MEXICAN FOOD
# ...                                 ...                             ...
# 1104097  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1104098  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1104099  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1104100  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1104101  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
#
#                            address     city state zip_code ward precinct  \
# 0                 6421 N DAMEN AVE  CHICAGO    IL    60645   50       28
# 1              3800 W DIVERSEY AVE  CHICAGO    IL    60647   31      999
# 2        853-855 W RANDOLPH ST 1ST  CHICAGO    IL    60607   27        1
# 3              3800 W DIVERSEY AVE  CHICAGO    IL    60647   31      999
# 4        853-855 W RANDOLPH ST 1ST  CHICAGO    IL    60607   27        1
# ...                            ...      ...   ...      ...  ...      ...
# 1104097       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
# 1104098       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
# 1104099       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
# 1104100       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
# 1104101       2616 W GRAND AVE 1ST  CHICAGO    IL    60612   36       17
#
#         ward_precinct police_district license_code        license_description  \
# 0               50-28              24         1011                Home Repair
# 1              31-999              25         1010   Limited Business License
# 2                27-1              12         1006  Retail Food Establishment
# 3              31-999              25         1010   Limited Business License
# 4                27-1              12         1006  Retail Food Establishment
# ...               ...             ...          ...                        ...
# 1104097         36-17              12         1010   Limited Business License
# 1104098         36-17              12         1010   Limited Business License
# 1104099         36-17              12         1010   Limited Business License
# 1104100         36-17              12         1010   Limited Business License
# 1104101         36-17              12         1010   Limited Business License
#
#         business_activity_id                 business_activity license_number  \
# 0                        NaN                               NaN        1000000
# 1                        NaN                               NaN        1000049
# 2                        775  Retail Sales of Perishable Foods        1000049
# 3                        NaN                               NaN        1000049
# 4                        775  Retail Sales of Perishable Foods        1000049
# ...                      ...                               ...            ...
# 1104097                  NaN                               NaN           9999
# 1104098                  NaN                               NaN           9999
# 1104099                  NaN                               NaN           9999
# 1104100                  NaN                               NaN           9999
# 1104101                  NaN                               NaN           9999
#
#         application_type application_created_date  \
# 0                  ISSUE  2000-06-19T00:00:00.000
# 1                  RENEW                      NaN
# 2                  RENEW                      NaN
# 3                  RENEW                      NaN
# 4                  RENEW                      NaN
# ...                  ...                      ...
# 1104097            RENEW                      NaN
# 1104098            RENEW                      NaN
# 1104099            RENEW                      NaN
# 1104100            RENEW                      NaN
# 1104101            RENEW                      NaN
#
#         application_requirements_complete             payment_date  \
# 0                 2002-02-15T00:00:00.000  2002-02-15T00:00:00.000
# 1                 2001-06-25T00:00:00.000  2001-08-20T00:00:00.000
# 2                 2002-03-27T00:00:00.000  2002-04-17T00:00:00.000
# 3                 2002-06-28T00:00:00.000  2002-08-13T00:00:00.000
# 4                 2003-03-25T00:00:00.000  2003-04-17T00:00:00.000
# ...                                   ...                      ...
# 1104097           2014-07-15T00:00:00.000  2014-12-26T00:00:00.000
# 1104098           2016-07-15T00:00:00.000  2016-09-08T00:00:00.000
# 1104099           2018-07-15T00:00:00.000  2018-09-10T00:00:00.000
# 1104100           2020-07-15T00:00:00.000  2020-08-05T00:00:00.000
# 1104101           2022-07-15T00:00:00.000  2022-08-08T00:00:00.000
#
#         conditional_approval       license_start_date  \
# 0                          N  2002-02-21T00:00:00.000
# 1                          N  2001-08-16T00:00:00.000
# 2                          N  2002-05-16T00:00:00.000
# 3                          N  2002-08-16T00:00:00.000
# 4                          N  2003-05-16T00:00:00.000
# ...                      ...                      ...
# 1104097                    N  2014-09-16T00:00:00.000
# 1104098                    N  2016-09-16T00:00:00.000
# 1104099                    N  2018-09-16T00:00:00.000
# 1104100                    N  2020-09-16T00:00:00.000
# 1104101                    N  2022-09-16T00:00:00.000
#
#                  expiration_date license_approved_for_issuance  \
# 0        2002-11-15T00:00:00.000       2002-02-21T00:00:00.000
# 1        2002-08-15T00:00:00.000       2001-08-20T00:00:00.000
# 2        2003-05-15T00:00:00.000       2002-04-17T00:00:00.000
# 3        2003-08-15T00:00:00.000       2002-08-13T00:00:00.000
# 4        2004-05-15T00:00:00.000       2003-04-17T00:00:00.000
# ...                          ...                           ...
# 1104097  2016-09-15T00:00:00.000       2014-12-26T00:00:00.000
# 1104098  2018-09-15T00:00:00.000       2016-09-08T00:00:00.000
# 1104099  2020-09-15T00:00:00.000       2018-09-10T00:00:00.000
# 1104100  2022-09-15T00:00:00.000       2020-08-05T00:00:00.000
# 1104101  2024-09-15T00:00:00.000       2022-08-08T00:00:00.000
#
#                      date_issued license_status license_status_change_date  \
# 0        2002-02-22T00:00:00.000            AAI                        NaN
# 1        2002-04-30T00:00:00.000            AAI                        NaN
# 2        2002-04-18T00:00:00.000            AAI                        NaN
# 3        2002-08-14T00:00:00.000            AAI                        NaN
# 4        2003-04-18T00:00:00.000            AAI                        NaN
# ...                          ...            ...                        ...
# 1104097  2014-12-29T00:00:00.000            AAI                        NaN
# 1104098  2016-09-09T00:00:00.000            AAI                        NaN
# 1104099  2018-09-11T00:00:00.000            AAI                        NaN
# 1104100  2020-08-06T00:00:00.000            AAI                        NaN
# 1104101  2022-09-13T00:00:00.000            AAI                        NaN
#
#          ssa      latitude      longitude  \
# 0        NaN  41.998514371  -87.680010905
# 1        NaN  41.931960333  -87.722150366
# 2        NaN  41.884261422  -87.649534131
# 3        NaN  41.931960333  -87.722150366
# 4        NaN  41.884261422  -87.649534131
# ...      ...           ...            ...
# 1104097  NaN  41.892720807  -87.692331754
# 1104098  NaN  41.892720807  -87.692331754
# 1104099  NaN  41.892720807  -87.692331754
# 1104100  NaN  41.892720807  -87.692331754
# 1104101  NaN  41.892720807  -87.692331754
#
#                                                 location
# 0         \n,  \n(41.99851437112669, -87.68001090539342)
# 1        \n,  \n(41.931960332638006, -87.72215036594574)
# 2          \n,  \n(41.88426142200001, -87.6495341312589)
# 3        \n,  \n(41.931960332638006, -87.72215036594574)
# 4          \n,  \n(41.88426142200001, -87.6495341312589)
# ...                                                  ...
# 1104097   \n,  \n(41.89272080716665, -87.69233175444906)
# 1104098   \n,  \n(41.89272080716665, -87.69233175444906)
# 1104099   \n,  \n(41.89272080716665, -87.69233175444906)
# 1104100   \n,  \n(41.89272080716665, -87.69233175444906)
# 1104101   \n,  \n(41.89272080716665, -87.69233175444906)
#
# [1104102 rows x 34 columns]

# %% [markdown]
# **Step 2:** Save as a pin to Connect

# %%
# Pin the data to Connect
pin_name = f"{user_name}/chicago-business-license-data-raw"

board.pin_write(
    business_license_data, 
    name=pin_name, 
    # Use arrow so that types are preserved
    type="arrow", 
    versioned=True,
    title="City of Chicago - Business License Data (RAW)"
)
# Out:
# Writing pin:
# Name: 'sam.edwardes/chicago-business-license-data-raw'
# Version: 20230626T113541Z-8311e
# Meta(title='City of Chicago - Business License Data (RAW)', description=None, created='20230626T113541Z', pin_hash='8311e270b4fa355a', file='chicago-business-license-data-raw.arrow', file_size=211331426, type='arrow', api_version=1, version=VersionRaw(version='76395'), tags=None, name='sam.edwardes/chicago-business-license-data-raw', user={}, local={})

# %%
board.pin_versions(pin_name)
# Out:
#   version
# 0   75833
# 1   75868
# 2   75871
# 3   76320
# 4   76392
# 5   76394
# 6   76395

# %% [markdown]
# ## Data set (2): Food inspections
#
# <https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5>

# %% [markdown]
# **Step 1:** Gew the raw data from the data portal

# %%
base_url = "https://data.cityofchicago.org/resource/4ijn-s7e5.csv"

params = {
    "$order": "inspection_date", 
    "$limit": 5_000_000
}

url = f"{base_url}?{urlencode(params)}"
print(url)
# Out:
# https://data.cityofchicago.org/resource/4ijn-s7e5.csv?%24order=inspection_date&%24limit=5000000

# %%
# Read everything as a string so that the formatting is preserved. We will use 
# pandera later to convert everything to the correct type.
food_inspection_data = pd.read_csv(url, dtype=str)
food_inspection_data
# Out:
#        inspection_id                            dba_name  \
# 0              70269                         mr.daniel's
# 1              52234                            Cafe 608
# 2              67733                           WOLCOTT'S
# 3              67738              MICHAEL'S ON MAIN CAFE
# 4              67732                           WOLCOTT'S
# ...              ...                                 ...
# 255658       2577663              WEST TOWN DAYCARE ,LLC
# 255659       2577673         MONTESSORI GIFTED PREP LLC.
# 255660       2577660  CHARMING CHILDREN LEARNING ACADEMY
# 255661       2577674                  BIRRIERIA DON LUIS
# 255662       2577672                         HAPPY LEMON
#
#                                   aka_name license_  \
# 0                              mr.daniel's  1899292
# 1                                 Cafe 608  2013328
# 2                                  TROQUET  1992040
# 3                   MICHAEL'S ON MAIN CAFE  2008948
# 4                                  TROQUET  1992039
# ...                                    ...      ...
# 255658              WEST TOWN DAYCARE, LLC  2570038
# 255659         MONTESSORI GIFTED PREP LLC.  2405576
# 255660  CHARMING CHILDREN LEARNING ACADEMY  2641758
# 255661                  BIRRIERIA DON LUIS  2796827
# 255662                         HAPPY LEMON  2862830
#
#                        facility_type             risk  \
# 0                         Restaurant    Risk 1 (High)
# 1                         Restaurant    Risk 1 (High)
# 2                         Restaurant    Risk 1 (High)
# 3                         Restaurant    Risk 1 (High)
# 4                         Restaurant    Risk 1 (High)
# ...                              ...              ...
# 255658  Children's Services Facility    Risk 1 (High)
# 255659  Children's Services Facility    Risk 1 (High)
# 255660  Children's Services Facility    Risk 1 (High)
# 255661                    Restaurant    Risk 1 (High)
# 255662                    Restaurant  Risk 2 (Medium)
#
#                          address     city state    zip  \
# 0            5645 W BELMONT AVE   CHICAGO    IL  60634
# 1               608 W BARRY AVE   CHICAGO    IL  60657
# 2           1834 W MONTROSE AVE   CHICAGO    IL  60613
# 3          8750 W BRYN WAWR AVE   CHICAGO    IL  60631
# 4           1834 W MONTROSE AVE   CHICAGO    IL  60613
# ...                          ...      ...   ...    ...
# 255658         2751 W CORTEZ ST   CHICAGO    IL  60622
# 255659        4754 N LEAVITT ST   CHICAGO    IL  60625
# 255660  3337-3341 W Chicago AVE   CHICAGO    IL  60651
# 255661          3544 E 106TH ST   CHICAGO    IL  60617
# 255662         1411 W TAYLOR ST   CHICAGO    IL  60607
#
#                 inspection_date        inspection_type results  \
# 0       2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 1       2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 2       2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 3       2010-01-04T00:00:00.000                License    Fail
# 4       2010-01-04T00:00:00.000  License Re-Inspection    Pass
# ...                         ...                    ...     ...
# 255658  2023-06-22T00:00:00.000                License    Pass
# 255659  2023-06-22T00:00:00.000                License    Pass
# 255660  2023-06-22T00:00:00.000  Canvass Re-Inspection    Pass
# 255661  2023-06-22T00:00:00.000  Canvass Re-Inspection    Pass
# 255662  2023-06-22T00:00:00.000  License Re-Inspection    Pass
#
#                                                violations            latitude  \
# 0                                                     NaN   41.93844282365204
# 1                                                     NaN  41.938006880423615
# 2                                                     NaN  41.961605669949854
# 3       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...                 NaN
# 4                                                     NaN  41.961605669949854
# ...                                                   ...                 ...
# 255658                                                NaN    41.9000918605704
# 255659  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...   41.96850906331291
# 255660  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...   41.89540586598236
# 255661  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...   41.70285190603626
# 255662  45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPER...   41.86922282497486
#
#                  longitude                                  location
# 0       -87.76831838068422   (41.93844282365204, -87.76831838068422)
# 1        -87.6447545707008   (41.938006880423615, -87.6447545707008)
# 2       -87.67596676683779  (41.961605669949854, -87.67596676683779)
# 3                      NaN                                       NaN
# 4       -87.67596676683779  (41.961605669949854, -87.67596676683779)
# ...                    ...                                       ...
# 255658  -87.69640926723595    (41.9000918605704, -87.69640926723595)
# 255659   -87.6841827473811    (41.96850906331291, -87.6841827473811)
# 255660  -87.71043217599598   (41.89540586598236, -87.71043217599598)
# 255661    -87.537139292445     (41.70285190603626, -87.537139292445)
# 255662  -87.66209718450791   (41.86922282497486, -87.66209718450791)
#
# [255663 rows x 17 columns]

# %% [markdown]
# **Step 2:** Save as a pin to Connect

# %%
pin_name = f"{user_name}/chicago-food-inspection-data-raw"

board.pin_write(
    food_inspection_data, 
    name=pin_name, 
    # Use arrow so that types are preserved
    type="arrow", 
    versioned=True,
    title="City of Chicago - Food Inspection Data (RAW)"
)
# Out:
# Writing pin:
# Name: 'sam.edwardes/chicago-food-inspection-data-raw'
# Version: 20230626T113641Z-542ac
# Meta(title='City of Chicago - Food Inspection Data (RAW)', description=None, created='20230626T113641Z', pin_hash='542ac8c1d4d82ca2', file='chicago-food-inspection-data-raw.arrow', file_size=104791362, type='arrow', api_version=1, version=VersionRaw(version='76396'), tags=None, name='sam.edwardes/chicago-food-inspection-data-raw', user={}, local={})

# %%
board.pin_versions(pin_name)
# Out:
#   version
# 0   75834
# 1   75872
# 2   76321
# 3   76393
# 4   76396
