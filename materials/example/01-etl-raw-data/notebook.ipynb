# %% [markdown]
# # Raw Data Ingestion
#
# This workshop will use data from the City of Chicago Open Data Portal: <https://data.cityofchicago.org>. The following datasets will be used:
#
# 1. Business license data: <https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr>
# 2. Food inspections: <https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5>

# %% [markdown]
# ## Setup

# %%
from urllib.parse import urlencode
import pins
import pandas as pd

# %%
pd.options.display.max_columns = 999

# %%
# Set up the board
board = pins.board_connect()
user_name = "sam.edwardes"

# %% [markdown]
# ## Data set (1): Business License Data
#
# <https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr>

# %% [markdown]
# **Step 1:** Gew the raw data from the data portal

# %%
base_url = "https://data.cityofchicago.org/resource/r5kz-chrr.csv"
params = {
    "$order": "id", 
    "$limit": 1_000
}
url = f"{base_url}?{urlencode(params)}"
print(url)
# Out:
# https://data.cityofchicago.org/resource/r5kz-chrr.csv?%24order=id&%24limit=1000

# %%
business_license_data = pd.read_csv(url)
business_license_data
# Out:
#                    id  license_id  account_number  site_number  \
# 0    1000000-20020221     1000000          200001            1
# 1    1000049-20010816     1162772          200068            1
# 2    1000049-20020516     1233615           10141            2
# 3    1000049-20020816     1265665          200068            1
# 4    1000049-20030516     1342680           10141            2
# ..                ...         ...             ...          ...
# 995  1000966-20020216     1215943          200860            1
# 996  1000966-20030216     1334986          200860            1
# 997  1000966-20040216     1477145          200860            1
# 998  1000966-20050216     1562532          200860            1
# 999  1000967-20020816     1265729          201200            1
#
#                     legal_name        doing_business_as_name  \
# 0                  MARK BOSTON              COLORS IN MOTION
# 1            ANTONIA CASTREJON         ILLUSIONS HAIR DESIGN
# 2    PEPE"S RETAIL MEATS, INC.            PEREZ MEXICAN FOOD
# 3            ANTONIA CASTREJON         ILLUSIONS HAIR DESIGN
# 4    PEPE"S RETAIL MEATS, INC.            PEREZ MEXICAN FOOD
# ..                         ...                           ...
# 995        CHAUNDEL D SAMMARCO           CHAUNDEL D.SAMMARCO
# 996        CHAUNDEL D SAMMARCO           CHAUNDEL D.SAMMARCO
# 997        CHAUNDEL D SAMMARCO           CHAUNDEL D.SAMMARCO
# 998        CHAUNDEL D SAMMARCO           CHAUNDEL D.SAMMARCO
# 999  ABDULLAH'S MECHANICAL PIP  ABDULLAH'S MECHANICAL PIPING
#
#                        address         city state  zip_code  ...  \
# 0             6421 N DAMEN AVE      CHICAGO    IL     60645  ...
# 1          3800 W DIVERSEY AVE      CHICAGO    IL     60647  ...
# 2    853-855 W RANDOLPH ST 1ST      CHICAGO    IL     60607  ...
# 3          3800 W DIVERSEY AVE      CHICAGO    IL     60647  ...
# 4    853-855 W RANDOLPH ST 1ST      CHICAGO    IL     60607  ...
# ..                         ...          ...   ...       ...  ...
# 995        3705  WONDERLAKE RD  WONDER LAKE    IL     60007  ...
# 996        3705  WONDERLAKE RD  WONDER LAKE    IL     60007  ...
# 997        3705  WONDERLAKE RD  WONDER LAKE    IL     60007  ...
# 998        3705  WONDERLAKE RD  WONDER LAKE    IL     60007  ...
# 999         1100 S KOSTNER AVE      CHICAGO    IL     60624  ...
#
#           license_start_date          expiration_date  \
# 0    2002-02-21T00:00:00.000  2002-11-15T00:00:00.000
# 1    2001-08-16T00:00:00.000  2002-08-15T00:00:00.000
# 2    2002-05-16T00:00:00.000  2003-05-15T00:00:00.000
# 3    2002-08-16T00:00:00.000  2003-08-15T00:00:00.000
# 4    2003-05-16T00:00:00.000  2004-05-15T00:00:00.000
# ..                       ...                      ...
# 995  2002-02-16T00:00:00.000  2003-02-15T00:00:00.000
# 996  2003-02-16T00:00:00.000  2004-02-15T00:00:00.000
# 997  2004-02-16T00:00:00.000  2005-02-15T00:00:00.000
# 998  2005-02-16T00:00:00.000  2006-02-15T00:00:00.000
# 999  2002-08-16T00:00:00.000  2003-08-15T00:00:00.000
#
#     license_approved_for_issuance              date_issued  license_status  \
# 0         2002-02-21T00:00:00.000  2002-02-22T00:00:00.000             AAI
# 1         2001-08-20T00:00:00.000  2002-04-30T00:00:00.000             AAI
# 2         2002-04-17T00:00:00.000  2002-04-18T00:00:00.000             AAI
# 3         2002-08-13T00:00:00.000  2002-08-14T00:00:00.000             AAI
# 4         2003-04-17T00:00:00.000  2003-04-18T00:00:00.000             AAI
# ..                            ...                      ...             ...
# 995                           NaN  2003-02-20T00:00:00.000             AAI
# 996                           NaN  2003-12-22T00:00:00.000             AAI
# 997                           NaN  2004-02-17T00:00:00.000             AAI
# 998                           NaN  2005-02-14T00:00:00.000             AAI
# 999       2002-09-24T00:00:00.000  2002-09-25T00:00:00.000             AAI
#
#     license_status_change_date  ssa   latitude  longitude  \
# 0                          NaN  NaN  41.998514 -87.680011
# 1                          NaN  NaN  41.931960 -87.722150
# 2                          NaN  NaN  41.884261 -87.649534
# 3                          NaN  NaN  41.931960 -87.722150
# 4                          NaN  NaN  41.884261 -87.649534
# ..                         ...  ...        ...        ...
# 995                        NaN  NaN        NaN        NaN
# 996                        NaN  NaN        NaN        NaN
# 997                        NaN  NaN        NaN        NaN
# 998                        NaN  NaN        NaN        NaN
# 999                        NaN  NaN  41.867800 -87.735173
#
#                                             location
# 0     \n,  \n(41.99851437112669, -87.68001090539342)
# 1    \n,  \n(41.931960332638006, -87.72215036594574)
# 2      \n,  \n(41.88426142200001, -87.6495341312589)
# 3    \n,  \n(41.931960332638006, -87.72215036594574)
# 4      \n,  \n(41.88426142200001, -87.6495341312589)
# ..                                               ...
# 995                                              NaN
# 996                                              NaN
# 997                                              NaN
# 998                                              NaN
# 999  \n,  \n(41.867800247721604, -87.73517309682629)
#
# [1000 rows x 34 columns]

# %% [markdown]
# **Step 2:** Save as a pin to Connect

# %%
# Pin the data to Connect
pin_name = f"{user_name}/chicago-business-license-data-raw"
board.pin_write(
    business_license_data, 
    name=pin_name, 
    type="csv",
    versioned=True,
    title="City of Chicago - Business License Data (RAW)"
)
# Out:
# Writing pin:
# Name: 'sam.edwardes/chicago-business-license-data-raw'
# Version: 20230614T073813Z-3077d
# Meta(title='City of Chicago - Business License Data (RAW)', description=None, created='20230614T073813Z', pin_hash='3077d25fefb568da', file='chicago-business-license-data-raw.csv', file_size=425766, type='csv', api_version=1, version=VersionRaw(version='75871'), tags=None, name='sam.edwardes/chicago-business-license-data-raw', user={}, local={})

# %%
board.pin_versions(pin_name)
# Out:
#   version
# 0   75833
# 1   75868
# 2   75871

# %% [markdown]
# ## Data set (2): Food inspections
#
# <https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5>

# %% [markdown]
# **Step 1:** Gew the raw data from the data portal

# %%
base_url = "https://data.cityofchicago.org/resource/4ijn-s7e5.csv"
params = {
    "$order": "inspection_date", 
    "$limit": 1_000
}
url = f"{base_url}?{urlencode(params)}"
print(url)
# Out:
# https://data.cityofchicago.org/resource/4ijn-s7e5.csv?%24order=inspection_date&%24limit=1000

# %%
food_inspection_data = pd.read_csv(url)
food_inspection_data
# Out:
#      inspection_id                        dba_name  \
# 0            67757    DUNKIN DONUTS/BASKIN-ROBBINS
# 1            67732                       WOLCOTT'S
# 2            67738          MICHAEL'S ON MAIN CAFE
# 3           104236                      TEMPO CAFE
# 4            67733                       WOLCOTT'S
# ..             ...                             ...
# 995          78279                    55TH MAXWELL
# 996          78278  RAINBOW BEACH NURSING CENT INC
# 997          58273                            BITE
# 998          98349           TRASPASADA RESTAURANT
# 999         112288  Monadnock Tobacco Mart Express
#
#                            aka_name  license_ facility_type             risk  \
# 0      DUNKIN DONUTS/BASKIN-ROBBINS   1380279    Restaurant  Risk 2 (Medium)
# 1                           TROQUET   1992039    Restaurant    Risk 1 (High)
# 2            MICHAEL'S ON MAIN CAFE   2008948    Restaurant    Risk 1 (High)
# 3                        TEMPO CAFE     80916    Restaurant    Risk 1 (High)
# 4                           TROQUET   1992040    Restaurant    Risk 1 (High)
# ..                              ...       ...           ...              ...
# 995                    55TH MAXWELL   1947631    Restaurant  Risk 2 (Medium)
# 996  RAINBOW BEACH NURSING CENT INC     13682           NaN    Risk 1 (High)
# 997                            BITE     51992    Restaurant    Risk 1 (High)
# 998           TRASPASADA RESTAURANT   1334442    Restaurant    Risk 1 (High)
# 999  Monadnock Tobacco Mart Express   2016888           NaN     Risk 3 (Low)
#
#                     address     city state      zip          inspection_date  \
# 0        100 W RANDOLPH ST   CHICAGO    IL  60601.0  2010-01-04T00:00:00.000
# 1      1834 W MONTROSE AVE   CHICAGO    IL  60613.0  2010-01-04T00:00:00.000
# 2     8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0  2010-01-04T00:00:00.000
# 3          6 E CHESTNUT ST   CHICAGO    IL  60611.0  2010-01-04T00:00:00.000
# 4      1834 W MONTROSE AVE   CHICAGO    IL  60613.0  2010-01-04T00:00:00.000
# ..                      ...      ...   ...      ...                      ...
# 995    323 E GARFIELD BLVD   CHICAGO    IL  60637.0  2010-01-25T00:00:00.000
# 996    7325 S EXCHANGE AVE   CHICAGO    IL  60649.0  2010-01-25T00:00:00.000
# 997     1039 N WESTERN AVE   CHICAGO    IL  60622.0  2010-01-25T00:00:00.000
# 998  3144 N CALIFORNIA AVE   CHICAGO    IL  60618.0  2010-01-25T00:00:00.000
# 999      53 W Jackson BLVD   CHICAGO    IL  60604.0  2010-01-25T00:00:00.000
#
#            inspection_type results  \
# 0              Tag Removal    Pass
# 1    License Re-Inspection    Pass
# 2                  License    Fail
# 3                  Canvass    Fail
# 4    License Re-Inspection    Pass
# ..                     ...     ...
# 995              Complaint    Fail
# 996        Out of Business    Fail
# 997                Canvass    Fail
# 998              Complaint    Pass
# 999                License    Fail
#
#                                             violations   latitude  longitude  \
# 0                                                  NaN  41.884586 -87.631010
# 1                                                  NaN  41.961606 -87.675967
# 2    18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...        NaN        NaN
# 3    18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431 -87.628009
# 4                                                  NaN  41.961606 -87.675967
# ..                                                 ...        ...        ...
# 995  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.794329 -87.618291
# 996                                                NaN  41.762169 -87.562641
# 997  29. PREVIOUS MINOR VIOLATION(S) CORRECTED 7-42...  41.900528 -87.686816
# 998  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.938946 -87.697956
# 999                                                NaN  41.878051 -87.629781
#
#                                      location
# 0     (41.88458626715456, -87.63101044588599)
# 1    (41.961605669949854, -87.67596676683779)
# 2                                         NaN
# 3      (41.89843137207629, -87.6280091630558)
# 4    (41.961605669949854, -87.67596676683779)
# ..                                        ...
# 995  (41.794329105990776, -87.61829143863345)
# 996  (41.762168766250305, -87.56264124442326)
# 997    (41.90052793259093, -87.6868161338336)
# 998  (41.938946248449454, -87.69795617571842)
# 999  (41.878050680824906, -87.62978100842273)
#
# [1000 rows x 17 columns]

# %% [markdown]
# **Step 2:** Save as a pin to Connect

# %%
pin_name = f"{user_name}/chicago-food-inspection-data-raw"
board.pin_write(
    food_inspection_data, 
    name=pin_name, 
    type="csv",
    versioned=True,
    title="City of Chicago - Food Inspection Data (RAW)"
)
# Out:
# Writing pin:
# Name: 'sam.edwardes/chicago-food-inspection-data-raw'
# Version: 20230614T073820Z-72e74
# Meta(title='City of Chicago - Food Inspection Data (RAW)', description=None, created='20230614T073820Z', pin_hash='72e740edfdc4f318', file='chicago-food-inspection-data-raw.csv', file_size=1326352, type='csv', api_version=1, version=VersionRaw(version='75872'), tags=None, name='sam.edwardes/chicago-food-inspection-data-raw', user={}, local={})

# %%
board.pin_versions(pin_name)
# Out:
#   version
# 0   75834
# 1   75872
