# %% [markdown]
# # Raw Data Ingestion
#
# This workshop will use data from the City of Chicago Open Data Portal: <https://data.cityofchicago.org>. The following datasets will be used:
#
# 1. Business license data: <https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr>
# 2. Food inspections: <https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5>

# %% [markdown]
# ## Setup

# %%
from urllib.parse import urlencode
import pins
import pandas as pd

# %%
pd.options.display.max_columns = 999

# %%
# Set up the board
board = pins.board_connect()
user_name = "sam.edwardes"

# %% [markdown]
# ## Data set (1): Business License Data
#
# <https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr>

# %% [markdown]
# **Step 1:** Gew the raw data from the data portal

# %%
base_url = "https://data.cityofchicago.org/resource/r5kz-chrr.csv"
params = {
    "$order": "id", 
    "$limit": 5_000_000
}
url = f"{base_url}?{urlencode(params)}"
print(url)
# Out:
# https://data.cityofchicago.org/resource/r5kz-chrr.csv?%24order=id&%24limit=5000000

# %%
business_license_data = pd.read_csv(url)
business_license_data
# Out:
# /var/folders/x4/583bns3n4gbddql2dsv7jyc40000gp/T/ipykernel_6919/1526117863.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   business_license_data = pd.read_csv(url)
#                        id  license_id  account_number  site_number  \
# 0        1000000-20020221     1000000          200001            1
# 1        1000049-20010816     1162772          200068            1
# 2        1000049-20020516     1233615           10141            2
# 3        1000049-20020816     1265665          200068            1
# 4        1000049-20030516     1342680           10141            2
# ...                   ...         ...             ...          ...
# 1103959     9999-20140916     2343163           26256            1
# 1103960     9999-20160916     2478055           26256            1
# 1103961     9999-20180916     2610578           26256            1
# 1103962     9999-20200916     2739432           26256            1
# 1103963     9999-20220916     2858021           26256            1
#
#                              legal_name          doing_business_as_name  \
# 0                           MARK BOSTON                COLORS IN MOTION
# 1                     ANTONIA CASTREJON           ILLUSIONS HAIR DESIGN
# 2             PEPE"S RETAIL MEATS, INC.              PEREZ MEXICAN FOOD
# 3                     ANTONIA CASTREJON           ILLUSIONS HAIR DESIGN
# 4             PEPE"S RETAIL MEATS, INC.              PEREZ MEXICAN FOOD
# ...                                 ...                             ...
# 1103959  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1103960  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1103961  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1103962  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
# 1103963  CHURCH & CHAPEL METAL ARTS INC  CHURCH & CHAPEL METAL ARTS INC
#
#                            address     city state zip_code  ward  precinct  \
# 0                 6421 N DAMEN AVE  CHICAGO    IL    60645  50.0      28.0
# 1              3800 W DIVERSEY AVE  CHICAGO    IL    60647  31.0     999.0
# 2        853-855 W RANDOLPH ST 1ST  CHICAGO    IL    60607  27.0       1.0
# 3              3800 W DIVERSEY AVE  CHICAGO    IL    60647  31.0     999.0
# 4        853-855 W RANDOLPH ST 1ST  CHICAGO    IL    60607  27.0       1.0
# ...                            ...      ...   ...      ...   ...       ...
# 1103959       2616 W GRAND AVE 1ST  CHICAGO    IL    60612  36.0      17.0
# 1103960       2616 W GRAND AVE 1ST  CHICAGO    IL    60612  36.0      17.0
# 1103961       2616 W GRAND AVE 1ST  CHICAGO    IL    60612  36.0      17.0
# 1103962       2616 W GRAND AVE 1ST  CHICAGO    IL    60612  36.0      17.0
# 1103963       2616 W GRAND AVE 1ST  CHICAGO    IL    60612  36.0      17.0
#
#         ward_precinct  police_district  license_code  \
# 0               50-28             24.0          1011
# 1              31-999             25.0          1010
# 2                27-1             12.0          1006
# 3              31-999             25.0          1010
# 4                27-1             12.0          1006
# ...               ...              ...           ...
# 1103959         36-17             12.0          1010
# 1103960         36-17             12.0          1010
# 1103961         36-17             12.0          1010
# 1103962         36-17             12.0          1010
# 1103963         36-17             12.0          1010
#
#                license_description business_activity_id  \
# 0                      Home Repair                  NaN
# 1         Limited Business License                  NaN
# 2        Retail Food Establishment                  775
# 3         Limited Business License                  NaN
# 4        Retail Food Establishment                  775
# ...                            ...                  ...
# 1103959   Limited Business License                  NaN
# 1103960   Limited Business License                  NaN
# 1103961   Limited Business License                  NaN
# 1103962   Limited Business License                  NaN
# 1103963   Limited Business License                  NaN
#
#                         business_activity  license_number application_type  \
# 0                                     NaN       1000000.0            ISSUE
# 1                                     NaN       1000049.0            RENEW
# 2        Retail Sales of Perishable Foods       1000049.0            RENEW
# 3                                     NaN       1000049.0            RENEW
# 4        Retail Sales of Perishable Foods       1000049.0            RENEW
# ...                                   ...             ...              ...
# 1103959                               NaN          9999.0            RENEW
# 1103960                               NaN          9999.0            RENEW
# 1103961                               NaN          9999.0            RENEW
# 1103962                               NaN          9999.0            RENEW
# 1103963                               NaN          9999.0            RENEW
#
#         application_created_date application_requirements_complete  \
# 0        2000-06-19T00:00:00.000           2002-02-15T00:00:00.000
# 1                            NaN           2001-06-25T00:00:00.000
# 2                            NaN           2002-03-27T00:00:00.000
# 3                            NaN           2002-06-28T00:00:00.000
# 4                            NaN           2003-03-25T00:00:00.000
# ...                          ...                               ...
# 1103959                      NaN           2014-07-15T00:00:00.000
# 1103960                      NaN           2016-07-15T00:00:00.000
# 1103961                      NaN           2018-07-15T00:00:00.000
# 1103962                      NaN           2020-07-15T00:00:00.000
# 1103963                      NaN           2022-07-15T00:00:00.000
#
#                     payment_date conditional_approval  \
# 0        2002-02-15T00:00:00.000                    N
# 1        2001-08-20T00:00:00.000                    N
# 2        2002-04-17T00:00:00.000                    N
# 3        2002-08-13T00:00:00.000                    N
# 4        2003-04-17T00:00:00.000                    N
# ...                          ...                  ...
# 1103959  2014-12-26T00:00:00.000                    N
# 1103960  2016-09-08T00:00:00.000                    N
# 1103961  2018-09-10T00:00:00.000                    N
# 1103962  2020-08-05T00:00:00.000                    N
# 1103963  2022-08-08T00:00:00.000                    N
#
#               license_start_date          expiration_date  \
# 0        2002-02-21T00:00:00.000  2002-11-15T00:00:00.000
# 1        2001-08-16T00:00:00.000  2002-08-15T00:00:00.000
# 2        2002-05-16T00:00:00.000  2003-05-15T00:00:00.000
# 3        2002-08-16T00:00:00.000  2003-08-15T00:00:00.000
# 4        2003-05-16T00:00:00.000  2004-05-15T00:00:00.000
# ...                          ...                      ...
# 1103959  2014-09-16T00:00:00.000  2016-09-15T00:00:00.000
# 1103960  2016-09-16T00:00:00.000  2018-09-15T00:00:00.000
# 1103961  2018-09-16T00:00:00.000  2020-09-15T00:00:00.000
# 1103962  2020-09-16T00:00:00.000  2022-09-15T00:00:00.000
# 1103963  2022-09-16T00:00:00.000  2024-09-15T00:00:00.000
#
#         license_approved_for_issuance              date_issued license_status  \
# 0             2002-02-21T00:00:00.000  2002-02-22T00:00:00.000            AAI
# 1             2001-08-20T00:00:00.000  2002-04-30T00:00:00.000            AAI
# 2             2002-04-17T00:00:00.000  2002-04-18T00:00:00.000            AAI
# 3             2002-08-13T00:00:00.000  2002-08-14T00:00:00.000            AAI
# 4             2003-04-17T00:00:00.000  2003-04-18T00:00:00.000            AAI
# ...                               ...                      ...            ...
# 1103959       2014-12-26T00:00:00.000  2014-12-29T00:00:00.000            AAI
# 1103960       2016-09-08T00:00:00.000  2016-09-09T00:00:00.000            AAI
# 1103961       2018-09-10T00:00:00.000  2018-09-11T00:00:00.000            AAI
# 1103962       2020-08-05T00:00:00.000  2020-08-06T00:00:00.000            AAI
# 1103963       2022-08-08T00:00:00.000  2022-09-13T00:00:00.000            AAI
#
#         license_status_change_date  ssa   latitude  longitude  \
# 0                              NaN  NaN  41.998514 -87.680011
# 1                              NaN  NaN  41.931960 -87.722150
# 2                              NaN  NaN  41.884261 -87.649534
# 3                              NaN  NaN  41.931960 -87.722150
# 4                              NaN  NaN  41.884261 -87.649534
# ...                            ...  ...        ...        ...
# 1103959                        NaN  NaN  41.892721 -87.692332
# 1103960                        NaN  NaN  41.892721 -87.692332
# 1103961                        NaN  NaN  41.892721 -87.692332
# 1103962                        NaN  NaN  41.892721 -87.692332
# 1103963                        NaN  NaN  41.892721 -87.692332
#
#                                                 location
# 0         \n,  \n(41.99851437112669, -87.68001090539342)
# 1        \n,  \n(41.931960332638006, -87.72215036594574)
# 2          \n,  \n(41.88426142200001, -87.6495341312589)
# 3        \n,  \n(41.931960332638006, -87.72215036594574)
# 4          \n,  \n(41.88426142200001, -87.6495341312589)
# ...                                                  ...
# 1103959   \n,  \n(41.89272080716665, -87.69233175444906)
# 1103960   \n,  \n(41.89272080716665, -87.69233175444906)
# 1103961   \n,  \n(41.89272080716665, -87.69233175444906)
# 1103962   \n,  \n(41.89272080716665, -87.69233175444906)
# 1103963   \n,  \n(41.89272080716665, -87.69233175444906)
#
# [1103964 rows x 34 columns]

# %% [markdown]
# **Step 2:** Save as a pin to Connect

# %%
# Pin the data to Connect
pin_name = f"{user_name}/chicago-business-license-data-raw"
board.pin_write(
    business_license_data, 
    name=pin_name, 
    type="csv",
    versioned=True,
    title="City of Chicago - Business License Data (RAW)"
)
# Out:
# Writing pin:
# Name: 'sam.edwardes/chicago-business-license-data-raw'
# Version: 20230623T081519Z-6f53f
# Meta(title='City of Chicago - Business License Data (RAW)', description=None, created='20230623T081519Z', pin_hash='6f53fa77d317f57c', file='chicago-business-license-data-raw.csv', file_size=476524752, type='csv', api_version=1, version=VersionRaw(version='76320'), tags=None, name='sam.edwardes/chicago-business-license-data-raw', user={}, local={})

# %%
board.pin_versions(pin_name)
# Out:
#   version
# 0   75833
# 1   75868
# 2   75871
# 3   76320

# %% [markdown]
# ## Data set (2): Food inspections
#
# <https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5>

# %% [markdown]
# **Step 1:** Gew the raw data from the data portal

# %%
base_url = "https://data.cityofchicago.org/resource/4ijn-s7e5.csv"
params = {
    "$order": "inspection_date", 
    "$limit": 5_000_000
}
url = f"{base_url}?{urlencode(params)}"
print(url)
# Out:
# https://data.cityofchicago.org/resource/4ijn-s7e5.csv?%24order=inspection_date&%24limit=5000000

# %%
food_inspection_data = pd.read_csv(url)
food_inspection_data
# Out:
#         inspection_id                                 dba_name  \
# 0               70269                              mr.daniel's
# 1               67732                                WOLCOTT'S
# 2               67733                                WOLCOTT'S
# 3               52234                                 Cafe 608
# 4               67738                   MICHAEL'S ON MAIN CAFE
# ...               ...                                      ...
# 255658        2577684  CHICAGO EATS SWEET HONEY TEA & LEMONADE
# 255659        2577672                              HAPPY LEMON
# 255660        2577669                              AVY'S PIZZA
# 255661        2577674                       BIRRIERIA DON LUIS
# 255662        2577660       CHARMING CHILDREN LEARNING ACADEMY
#
#                                        aka_name   license_  \
# 0                                   mr.daniel's  1899292.0
# 1                                       TROQUET  1992039.0
# 2                                       TROQUET  1992040.0
# 3                                      Cafe 608  2013328.0
# 4                        MICHAEL'S ON MAIN CAFE  2008948.0
# ...                                         ...        ...
# 255658  CHICAGO EATS SWEET HONEY TEA & LEMONADE  2812716.0
# 255659                              HAPPY LEMON  2862830.0
# 255660                              AVY'S PIZZA  2113336.0
# 255661                       BIRRIERIA DON LUIS  2796827.0
# 255662       CHARMING CHILDREN LEARNING ACADEMY  2641758.0
#
#                        facility_type             risk  \
# 0                         Restaurant    Risk 1 (High)
# 1                         Restaurant    Risk 1 (High)
# 2                         Restaurant    Risk 1 (High)
# 3                         Restaurant    Risk 1 (High)
# 4                         Restaurant    Risk 1 (High)
# ...                              ...              ...
# 255658                    Restaurant  Risk 2 (Medium)
# 255659                    Restaurant  Risk 2 (Medium)
# 255660                    Restaurant    Risk 1 (High)
# 255661                    Restaurant    Risk 1 (High)
# 255662  Children's Services Facility    Risk 1 (High)
#
#                          address     city state      zip  \
# 0            5645 W BELMONT AVE   CHICAGO    IL  60634.0
# 1           1834 W MONTROSE AVE   CHICAGO    IL  60613.0
# 2           1834 W MONTROSE AVE   CHICAGO    IL  60613.0
# 3               608 W BARRY AVE   CHICAGO    IL  60657.0
# 4          8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0
# ...                          ...      ...   ...      ...
# 255658        4100 W MADISON ST   CHICAGO    IL  60624.0
# 255659         1411 W TAYLOR ST   CHICAGO    IL  60607.0
# 255660         9917 S EWING AVE   CHICAGO    IL  60617.0
# 255661          3544 E 106TH ST   CHICAGO    IL  60617.0
# 255662  3337-3341 W Chicago AVE   CHICAGO    IL  60651.0
#
#                 inspection_date        inspection_type results  \
# 0       2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 1       2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 2       2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 3       2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 4       2010-01-04T00:00:00.000                License    Fail
# ...                         ...                    ...     ...
# 255658  2023-06-22T00:00:00.000                Canvass    Pass
# 255659  2023-06-22T00:00:00.000  License Re-Inspection    Pass
# 255660  2023-06-22T00:00:00.000  Canvass Re-Inspection    Pass
# 255661  2023-06-22T00:00:00.000  Canvass Re-Inspection    Pass
# 255662  2023-06-22T00:00:00.000  Canvass Re-Inspection    Pass
#
#                                                violations   latitude  \
# 0                                                     NaN  41.938443
# 1                                                     NaN  41.961606
# 2                                                     NaN  41.961606
# 3                                                     NaN  41.938007
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...        NaN
# ...                                                   ...        ...
# 255658  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.880804
# 255659  45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPER...  41.869223
# 255660  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  41.715244
# 255661  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...  41.702852
# 255662  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.895406
#
#         longitude                                  location
# 0      -87.768318   (41.93844282365204, -87.76831838068422)
# 1      -87.675967  (41.961605669949854, -87.67596676683779)
# 2      -87.675967  (41.961605669949854, -87.67596676683779)
# 3      -87.644755   (41.938006880423615, -87.6447545707008)
# 4             NaN                                       NaN
# ...           ...                                       ...
# 255658 -87.728244   (41.880804158176524, -87.7282444216966)
# 255659 -87.662097   (41.86922282497486, -87.66209718450791)
# 255660 -87.535130   (41.71524399093076, -87.53513029319586)
# 255661 -87.537139     (41.70285190603626, -87.537139292445)
# 255662 -87.710432   (41.89540586598236, -87.71043217599598)
#
# [255663 rows x 17 columns]

# %% [markdown]
# **Step 2:** Save as a pin to Connect

# %%
pin_name = f"{user_name}/chicago-food-inspection-data-raw"
board.pin_write(
    food_inspection_data, 
    name=pin_name, 
    type="csv",
    versioned=True,
    title="City of Chicago - Food Inspection Data (RAW)"
)
# Out:
# Writing pin:
# Name: 'sam.edwardes/chicago-food-inspection-data-raw'
# Version: 20230623T081632Z-e4de3
# Meta(title='City of Chicago - Food Inspection Data (RAW)', description=None, created='20230623T081632Z', pin_hash='e4de384f69e9216d', file='chicago-food-inspection-data-raw.csv', file_size=290067766, type='csv', api_version=1, version=VersionRaw(version='76321'), tags=None, name='sam.edwardes/chicago-food-inspection-data-raw', user={}, local={})

# %%
board.pin_versions(pin_name)
# Out:
#   version
# 0   75834
# 1   75872
# 2   76321
